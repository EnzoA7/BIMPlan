# %% [markdown]
# # Inicialização

# %%
import numpy as np
import pandas as pd
import ifcopenshell
import ifcopenshell.util.element
import ifcopenshell.util.selector
import ifcopenshell.api.sequence
# Out:
# Note: API not available due to missing dependencies: geometry.add_door_representation - No module named 'mathutils'
# Note: API not available due to missing dependencies: geometry.add_railing_representation - No module named 'mathutils'
# Note: API not available due to missing dependencies: geometry.add_representation - No module named 'bpy'
# Note: API not available due to missing dependencies: geometry.add_window_representation - No module named 'mathutils'
# Note: API not available due to missing dependencies: grid.create_axis_curve - No module named 'mathutils'
# Note: API not available due to missing dependencies: sequence.recalculate_schedule - No module named 'networkx'

# %%
### pendencias
# 1. Verificar como separar no QiBuilder o que está em prumada, aéreo, embutido em parede
# 2. Categorizar os itens entre prumada, ramal, subcoletor, reservação, etc.
######

# %% [markdown]
# # Funções

# %% [markdown]
# ## Gera combinações

# %%
# gera combinações para criar a EAP
def criar_combinacoes(niveis, *args):
    """Cria combinações de níveis, com o objetivo de gerar EAP e descrição do item da EAP."""
    # Cria um DataFrame auxiliar com todas as combinações
    combinacoes = pd.MultiIndex.from_product(args, names=niveis).to_frame(index=False)

    # Gera a coluna EAP
    combinacoes["EAP"] = (
        combinacoes.apply(lambda row: SEPARADOR_EAP.join([str(np.where(arg == row.iloc[i])[0][0] + 1) for i, arg in enumerate (args)]
                                                        ), axis=1)
    )

    # Gera a descrição
    combinacoes["descrição"] = combinacoes.loc[:, combinacoes.columns != "EAP"].apply(lambda row: SEPARADOR_DESCRICAO.join(row.astype(str)), axis=1)
    
    return combinacoes

# %% [markdown]
# ## Incrementa EAP

# %%
# Função para incrementar o valor de uma string de EAP
def incrementar_eap(string, posicao, incremento):
    partes = string.split(".") # divide a string em partes
    partes[posicao] = str(int(partes[posicao]) + incremento) # incrementa o elemento na posição
    return ".".join(partes) # junta novamente a string

# %% [markdown]
# # IFC

# %% [markdown]
# ## IFC QiBuilder

# %%
FILE_PATH = "./modelo/FERNANDA E FILIPE-PE-HID-IFC.ifc"
model = ifcopenshell.open(FILE_PATH)

# %%
# Classes IFC
classes_unicas = set()
for entidade in model:
    classes_unicas.add(entidade.is_a())

# %%
# dicionário para armazenar as quantidades dos elementos
dict_quantitativo = {
    "pavimento": [],
    "rede": [],
    "item": [],
    "quantidade": [],
    "ID": [],
}
# pega as classes IFC que tem no arquivo
for classe in classes_unicas:
    elementos = model.by_type(classe)
    for elemento in elementos:
        # propriedades e quantidades da classe IFC
        psets_and_qtos = ifcopenshell.util.element.get_psets(elemento)
        
        # como o IFC é do QiBuilder, ele exporta em um conjunto específico
        if 'AltoQi_QiBuilder-Itens_Associados' in psets_and_qtos: 
            for item, quantidade in psets_and_qtos['AltoQi_QiBuilder-Itens_Associados'].items():
                if item != "id": # remove o id
                    pavimento = ifcopenshell.util.element.get_container(elemento)[2]
                    rede = psets_and_qtos["Identificação_Elemento"]['Rede']
                    
                    dict_quantitativo["pavimento"].append(pavimento)
                    dict_quantitativo["rede"].append(rede)
                    dict_quantitativo["item"].append(item)
                    dict_quantitativo["quantidade"].append(quantidade)
                    dict_quantitativo["ID"].append(elemento.GlobalId)

# cria o dataframe no pandas
df_quantitativo = pd.DataFrame(dict_quantitativo)

# %%
df_quantitativo
# Out:
#      pavimento                       rede  \
# 0       TER NA  Alimentação (Piscina-FIL)
# 1       TER NA  Alimentação (Piscina-FIL)
# 2       TER NA  Alimentação (Piscina-FIL)
# 3       TER NA  Alimentação (Piscina-FIL)
# 4       TER NA  Alimentação (Piscina-FIL)
# ..         ...                        ...
# 552  COBERTURA                Água quente
# 553  COBERTURA                Água quente
# 554  COBERTURA                Água quente
# 555     TER NA                 Ventilação
# 556     TER NA                 Ventilação
#
#                                                   item  quantidade  \
# 0    Metais - Registro esfera VS compacto soldável ...         1.0
# 1    Metais - Registro esfera VS compacto soldável ...         1.0
# 2       Metais - Valvula de retenção vertical - 1.1/2"         1.0
# 3    PVC rígido soldável - Adapt sold.curto c/bolsa...         2.0
# 4    Metais - Registro esfera VS compacto soldável ...         1.0
# ..                                                 ...         ...
# 552            Placa Solar - Solis - New Trópicos 2000         1.0
# 553            Placa Solar - Solis - New Trópicos 2000         1.0
# 554            Placa Solar - Solis - New Trópicos 2000         1.0
# 555        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 556        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
#
#                          ID
# 0    1yH6iSt2HEAwhBHmpEW48R
# 1    23vghV9i5E69JyH8cCXCzC
# 2    3Xe7iW2cXEUfq5MHSwOCQP
# 3    3Xe7iW2cXEUfq5MHSwOCQP
# 4    3mVMY5yAD9uAhX6Sme9ohP
# ..                      ...
# 552  1K8ErAvxDEhuVB3L0$rilu
# 553  2gUdsZucfD09_ho9YhCYi8
# 554  1HEBKtuuD6PhkNQxhOCT7h
# 555  2c8JUCCDjFr8EWB5NyNC1Q
# 556  3hPDKMePT1yAVb4qJWCNuJ
#
# [557 rows x 5 columns]

# %%
# quantitativo agrupado para conferência
df_quantitativo_agrupado = df_quantitativo.groupby(["pavimento", "rede", "item"], as_index=False)["quantidade"].sum()

# %%
df_quantitativo_agrupado

# %%
df_quantitativo_agrupado.to_excel("lista de materiais.xlsx")

# %% [markdown]
# ## IFC TQS-Revit-IFC

# %%
FILE_PATH = "./modelo/789-EST-EX-001-MOD-GER-XX-MODELO_3D_GERAL-R01-IFC4.ifc"
model = ifcopenshell.open(FILE_PATH)

# %%
# Classes IFC
classes_unicas = set()
for entidade in model:
    classes_unicas.add(entidade.is_a())

# %%
# dicionário para armazenar as quantidades dos elementos
dict_quantitativo = {
    "pavimento": [],
    "junta": [],
    "elemento": [],
    "tipo": [],
    "codigo": [],
    "comprimento (cm)": [],
    "largura (cm)": [],
    "altura (cm)": [],
    "área (m²)": [],
    "volume (m³)": [],
    "GlobalID": [],
}

# remove as classes tipos e pavimento
classe_a_remover = ["IfcBeamType", "IfcColumnType", "IfcBuildingStorey"]
classes_unicas = [classe for classe in classes_unicas if classe not in classe_a_remover]

# função para adicionar os elementos no dicionário
def add_element_to_dict(pavimento, junta, elemento, tipo, codigo, comprimento, largura, altura, area, volume, global_id):
    dict_quantitativo["pavimento"].append(pavimento)
    dict_quantitativo["junta"].append(junta)
    dict_quantitativo["elemento"].append(elemento)
    dict_quantitativo["tipo"].append(tipo)
    dict_quantitativo["codigo"].append(codigo)
    dict_quantitativo["comprimento (cm)"].append(comprimento)
    dict_quantitativo["largura (cm)"].append(largura)
    dict_quantitativo["altura (cm)"].append(altura)
    dict_quantitativo["área (m²)"].append(area)
    dict_quantitativo["volume (m³)"].append(volume)
    dict_quantitativo["GlobalID"].append(global_id)

# mapemaneto dos parâmetros de cada uma das classes para o dicionário
class_handlers = {
    "IfcSlab": lambda psets_and_qtos, pavimento, junta: (
        ("Cortina" if psets_and_qtos["Dados de identidade"]["Titulo"] == "CORTINA" else psets_and_qtos["Dados de identidade"]["Tipo Elemento"],
         "" if psets_and_qtos["Dados de identidade"]["Titulo"] == "CORTINA" else psets_and_qtos["Dados"]["Tipo"],
         psets_and_qtos["Dados de identidade"]["Titulo"],
         "",
         "",
         "" if psets_and_qtos["Dados de identidade"]["Titulo"] == 'CORTINA' or psets_and_qtos["Dados"]["Tipo"] == "Nerv T" else psets_and_qtos["Dados"]["Altura_cm"],
         psets_and_qtos["Qto_SlabBaseQuantities"]["NetArea"],
         psets_and_qtos["Qto_SlabBaseQuantities"]["NetVolume"])
    ),
    "IfcBeam": lambda psets_and_qtos, pavimento, junta: (
        (psets_and_qtos["Dados de identidade"]["Tipo Elemento"],
         "",
         psets_and_qtos["Dados de identidade"]["Titulo"],
         psets_and_qtos["Qto_BeamBaseQuantities"]["Length"],
         psets_and_qtos["Dados"]["Largura_cm"],
         psets_and_qtos["Dados"]["Altura_cm"],
         "",
         psets_and_qtos["Qto_BeamBaseQuantities"]["NetVolume"])
    ),
    "IfcColumn": lambda psets_and_qtos, pavimento, junta: (
        (psets_and_qtos["Dados de identidade"]["Tipo Elemento"],
         "",
         psets_and_qtos["Dados de identidade"]["Titulo"],
         psets_and_qtos["Qto_ColumnBaseQuantities"]["Length"],
         psets_and_qtos["Dados"]["Largura_cm"] if psets_and_qtos["Dados"]["Secao"].startswith("R") else psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
         psets_and_qtos["Dados"]["Altura_cm"] if psets_and_qtos["Dados"]["Secao"].startswith("R") else "",
         psets_and_qtos["Qto_ColumnBaseQuantities"]["OuterSurfaceArea"],
         psets_and_qtos["Qto_ColumnBaseQuantities"]["NetVolume"])
    ),
    "IfcWallStandardCase": lambda psets_and_qtos, pavimento, junta: (
        ("Cortina",
         "",
         "",
         psets_and_qtos["Qto_WallBaseQuantities"]["Length"],
         psets_and_qtos["Qto_WallBaseQuantities"]["Width"],
         psets_and_qtos["Qto_WallBaseQuantities"]["Height"],
         psets_and_qtos["Qto_WallBaseQuantities"]["NetSideArea"],
         psets_and_qtos["Qto_WallBaseQuantities"]["NetVolume"])
    ),
}

# Processa os elementos
for classe in classes_unicas:
    elementos = model.by_type(classe)
    for elemento in elementos:
        psets_and_qtos = ifcopenshell.util.element.get_psets(elemento)
        if 'Cotas' in psets_and_qtos and 'Volume' in psets_and_qtos["Cotas"]:
            pavimento = ifcopenshell.util.element.get_container(elemento)[2]
            junta = psets_and_qtos["My_Data"]["Junta"]
            handler = class_handlers.get(classe)

            if handler:
                print(elemento.GlobalId)
                print()
                results = handler(psets_and_qtos, pavimento, junta)
                add_element_to_dict(pavimento, junta, *results, elemento.GlobalId)

            else:
                print(f"Classe não considerada: {classe}, GlobalId: {elemento.GlobalId}")

        elif 'Cotas' in psets_and_qtos:
            print(f"Erro de modelagem, GlobalId: {elemento.GlobalId}")

df_quantitativo = pd.DataFrame(dict_quantitativo)
# Out:
# 0$TvfvQWT3UPXp$fNe6P3J
#
# 0$TvfvQWT3UPXp$fNe6P2Q
#
# 0$TvfvQWT3UPXp$fNe6P0F
#
# 0$TvfvQWT3UPXp$fNe6PV9
#
# 0$TvfvQWT3UPXp$fNe6Ond
#
# 0$TvfvQWT3UPXp$fNe6P1J
#
# 0$TvfvQWT3UPXp$fNe6OpT
#
# 0vkyWjqLn1CxlLegVyhPKA
#
# 0vkyWjqLn1CxlLegVyhPK5
#
# 0vkyWjqLn1CxlLegVyhPKP
#
# 0vkyWjqLn1CxlLegVyhPKK
#
# 0vkyWjqLn1CxlLegVyhPLw
#
# 0vkyWjqLn1CxlLegVyhPLF
#
# 0vkyWjqLn1CxlLegVyhPLq
#
# 0vkyWjqLn1CxlLegVyhOtu
#
# 0vkyWjqLn1CxlLegVyhOtz
#
# 0vkyWjqLn1CxlLegVyhPL7
#
# 0vkyWjqLn1CxlLegVyhPMW
#
# 0vkyWjqLn1CxlLegVyhPM9
#
# 0vkyWjqLn1CxlLegVyhPNi
#
# 0vkyWjqLn1CxlLegVyhPN3
#
# 0vkyWjqLn1CxlLegVyhPG5
#
# 0vkyWjqLn1CxlLegVyhPGT
#
# 0vkyWjqLn1CxlLegVyhPGP
#
# 0vkyWjqLn1CxlLegVyhPHC
#
# 0vkyWjqLn1CxlLegVyhPHY
#
# 0vkyWjqLn1CxlLegVyhPNB
#
# 0vkyWjqLn1CxlLegVyhPNy
#
# 0vkyWjqLn1CxlLegVyhPHV
#
# 0vkyWjqLn1CxlLegVyhPIh
#
# 0vkyWjqLn1CxlLegVyhPHG
#
# 0vkyWjqLn1CxlLegVyhPHL
#
# 0vkyWjqLn1CxlLegVyhPHi
#
# 0vkyWjqLn1CxlLegVyhPNI
#
# 0vkyWjqLn1CxlLegVyhPNM
#
# 0vkyWjqLn1CxlLegVyhPNQ
#
# 0vkyWjqLn1CxlLegVyhPNa
#
# 0vkyWjqLn1CxlLegVyhPLa
#
# 0vkyWjqLn1CxlLegVyhPLe
#
# 0vkyWjqLn1CxlLegVyhPLi
#
# 0vkyWjqLn1CxlLegVyhPKG
#
# 0vkyWjqLn1CxlLegVyhO2m
#
# 0vkyWjqLn1CxlLegVyhO2r
#
# 0vkyWjqLn1CxlLegVyhO2w
#
# 0vkyWjqLn1CxlLegVyhO2$
#
# 0vkyWjqLn1CxlLegVyhO1_
#
# 0vkyWjqLn1CxlLegVyhO1g
#
# 0vkyWjqLn1CxlLegVyhO1k
#
# 0vkyWjqLn1CxlLegVyhO0I
#
# 0vkyWjqLn1CxlLegVyhO0e
#
# 0vkyWjqLn1CxlLegVyhO7K
#
# 0vkyWjqLn1CxlLegVyhO7O
#
# 0vkyWjqLn1CxlLegVyhO74
#
# 0vkyWjqLn1CxlLegVyhO$F
#
# 0vkyWjqLn1CxlLegVyhO$t
#
# 0vkyWjqLn1CxlLegVyhO$x
#
# 0vkyWjqLn1CxlLegVyhO$$
#
# 0vkyWjqLn1CxlLegVyhOmO
#
# 0vkyWjqLn1CxlLegVyhOmT
#
# 0vkyWjqLn1CxlLegVyhOm2
#
# 0vkyWjqLn1CxlLegVyhOmj
#
# 0vkyWjqLn1CxlLegVyhOtU
#
# 0vkyWjqLn1CxlLegVyhOt2
#
# 0vkyWjqLn1CxlLegVyhOtX
#
# 0vkyWjqLn1CxlLegVyhOtb
#
# 0vkyWjqLn1CxlLegVyhOtg
#
# 0vkyWjqLn1CxlLegVyhOtl
#
# 0vkyWjqLn1CxlLegVyhOsK
#
# 0vkyWjqLn1CxlLegVyhR7B
#
# 0vkyWjqLn1CxlLegVyhRUZ
#
# 0vkyWjqLn1CxlLegVyhRUd
#
# 0vkyWjqLn1CxlLegVyhRUi
#
# 0vkyWjqLn1CxlLegVyhRT0
#
# 0vkyWjqLn1CxlLegVyhRTt
#
# 0vkyWjqLn1CxlLegVyhRTx
#
# 0vkyWjqLn1CxlLegVyhRT$
#
# 0vkyWjqLn1CxlLegVyhRS6
#
# 0vkyWjqLn1CxlLegVyhRSA
#
# 0vkyWjqLn1CxlLegVyhRSE
#
# 0vkyWjqLn1CxlLegVyhRSo
#
# 0vkyWjqLn1CxlLegVyhPIH
#
# 0vkyWjqLn1CxlLegVyhPJi
#
# 0vkyWjqLn1CxlLegVyhPJt
#
# 0vkyWjqLn1CxlLegVyhPJy
#
# 0vkyWjqLn1CxlLegVyhPGH
#
# 0vkyWjqLn1CxlLegVyhPGL
#
# 0vkyWjqLn1CxlLegVyhPG1
#
# 0vkyWjqLn1CxlLegVyhPNe
#
# 0vkyWjqLn1CxlLegVyhPMG
#
# 0vkyWjqLn1CxlLegVyhPLB
#
# 0vkyWjqLn1CxlLegVyhPKT
#
# 0vkyWjqLn1CxlLegVyhPK1
#
# 0vkyWjqLn1CxlLegVyhPJC
#
# 0vkyWjqLn1CxlLegVyhPJ0
#
# 0vkyWjqLn1CxlLegVyhPJ5
#
# 0vkyWjqLn1CxlLegVyhPS$
#
# 0vkyWjqLn1CxlLegVyhPSw
#
# 0vkyWjqLn1CxlLegVyhPH5
#
# 0vkyWjqLn1CxlLegVyhPN7
#
# 0vkyWjqLn1CxlLegVyhPp0
#
# 0vkyWjqLn1CxlLegVyhO9i
#
# 0vkyWjqLn1CxlLegVyhO8M
#
# 0vkyWjqLn1CxlLegVyhOF8
#
# 0vkyWjqLn1CxlLegVyhOFu
#
# 0vkyWjqLn1CxlLegVyhODX
#
# 0vkyWjqLn1CxlLegVyhODc
#
# 0vkyWjqLn1CxlLegVyhOn9
#
# 0vkyWjqLn1CxlLegVyhOmW
#
# 0vkyWjqLn1CxlLegVyhROq
#
# 0vkyWjqLn1CxlLegVyhRVT
#
# 2jO$d2Li5ECB0Bpfl6g$3i
#
# 0vkyWjqLn1CxlLegVyhPSE
#
# 0vkyWjqLn1CxlLegVyhPS4
#
# 0vkyWjqLn1CxlLegVyhPSN
#
# 0vkyWjqLn1CxlLegVyhPTt
#
# 0vkyWjqLn1CxlLegVyhPTd
#
# 0vkyWjqLn1CxlLegVyhPSH
#
# 0vkyWjqLn1CxlLegVyhPIV
#
# 0vkyWjqLn1CxlLegVyhPI4
#
# 0vkyWjqLn1CxlLegVyhPID
#
# 0vkyWjqLn1CxlLegVyhPIo
#
# 0vkyWjqLn1CxlLegVyhPIw
#
# 0vkyWjqLn1CxlLegVyhPIa
#
# 0vkyWjqLn1CxlLegVyhPHQ
#
# 0vkyWjqLn1CxlLegVyhPHo
#
# 0vkyWjqLn1CxlLegVyhPHu
#
# 0vkyWjqLn1CxlLegVyhPHz
#
# 0vkyWjqLn1CxlLegVyhPGE
#
# 0vkyWjqLn1CxlLegVyhPGo
#
# 0vkyWjqLn1CxlLegVyhPGx
#
# 0vkyWjqLn1CxlLegVyhPG$
#
# 0vkyWjqLn1CxlLegVyhPGd
#
# 0vkyWjqLn1CxlLegVyhPGk
#
# 0vkyWjqLn1CxlLegVyhPNU
#
# 0vkyWjqLn1CxlLegVyhPNm
#
# 0vkyWjqLn1CxlLegVyhPNq
#
# 0vkyWjqLn1CxlLegVyhPNu
#
# 0vkyWjqLn1CxlLegVyhO8C
#
# 0vkyWjqLn1CxlLegVyhO8s
#
# 0vkyWjqLn1CxlLegVyhO3V
#
# 0vkyWjqLn1CxlLegVyhO26
#
# 0vkyWjqLn1CxlLegVyhO2B
#
# 0vkyWjqLn1CxlLegVyhO10
#
# 0vkyWjqLn1CxlLegVyhO1Y
#
# 0vkyWjqLn1CxlLegVyhO7S
#
# 0vkyWjqLn1CxlLegVyhO70
#
# 0vkyWjqLn1CxlLegVyhOnL
#
# 0vkyWjqLn1CxlLegVyhOnV
#
# 0vkyWjqLn1CxlLegVyhOnp
#
# 0vkyWjqLn1CxlLegVyhOnz
#
# 0vkyWjqLn1CxlLegVyhOne
#
# 0vkyWjqLn1CxlLegVyhOnl
#
# 0vkyWjqLn1CxlLegVyhOm6
#
# 0vkyWjqLn1CxlLegVyhOmt
#
# 0vkyWjqLn1CxlLegVyhOme
#
# 0vkyWjqLn1CxlLegVyhOtM
#
# 0vkyWjqLn1CxlLegVyhOtQ
#
# 0vkyWjqLn1CxlLegVyhOtA
#
# 0vkyWjqLn1CxlLegVyhR7V
#
# 0vkyWjqLn1CxlLegVyhROR
#
# 0vkyWjqLn1CxlLegVyhRO5
#
# 0vkyWjqLn1CxlLegVyhRUo
#
# 0vkyWjqLn1CxlLegVyhRUs
#
# 0vkyWjqLn1CxlLegVyhRUw
#
# 0vkyWjqLn1CxlLegVyhRT9
#
# 0vkyWjqLn1CxlLegVyhRTE
#
# 0vkyWjqLn1CxlLegVyhRTo
#
# 0vkyWjqLn1CxlLegVyhRSH
#
# 0vkyWjqLn1CxlLegVyhRSL
#
# 0vkyWjqLn1CxlLegVyhRSP
#
# 0vkyWjqLn1CxlLegVyhPTo
#
# 0vkyWjqLn1CxlLegVyhPSe
#
# 0vkyWjqLn1CxlLegVyhPSj
#
# 0vkyWjqLn1CxlLegVyhPJo
#
# 0vkyWjqLn1CxlLegVyhOFS
#
# 0vkyWjqLn1CxlLegVyhOEg
#
# 0vkyWjqLn1CxlLegVyhODy
#
# 0vkyWjqLn1CxlLegVyhOCS
#
# 0vkyWjqLn1CxlLegVyhOC1
#
# 0vkyWjqLn1CxlLegVyhOoC
#
# 2jO$d2Li5ECB0Bpfl6g$2s
#
# 2jO$d2Li5ECB0Bpfl6g$2V
#
# 0vkyWjqLn1CxlLegVyhPT7
#
# 0vkyWjqLn1CxlLegVyhPT2
#
# 0vkyWjqLn1CxlLegVyhPTT
#
# 0vkyWjqLn1CxlLegVyhPTy
#
# 0vkyWjqLn1CxlLegVyhPTX
#
# 0vkyWjqLn1CxlLegVyhPTi
#
# 0vkyWjqLn1CxlLegVyhPS9
#
# 0vkyWjqLn1CxlLegVyhPJI
#
# 0vkyWjqLn1CxlLegVyhPJW
#
# 0vkyWjqLn1CxlLegVyhPJd
#
# 0vkyWjqLn1CxlLegVyhPIQ
#
# 0vkyWjqLn1CxlLegVyhPI9
#
# 0vkyWjqLn1CxlLegVyhPIt
#
# 0vkyWjqLn1CxlLegVyhPIW
#
# 0vkyWjqLn1CxlLegVyhPGA
#
# 0vkyWjqLn1CxlLegVyhPGt
#
# 0vkyWjqLn1CxlLegVyhPGa
#
# 0vkyWjqLn1CxlLegVyhPGg
#
# 0vkyWjqLn1CxlLegVyhPMQ
#
# 0vkyWjqLn1CxlLegVyhPM3
#
# 0vkyWjqLn1CxlLegVyhPME
#
# 0vkyWjqLn1CxlLegVyhPLI
#
# 0vkyWjqLn1CxlLegVyhPKE
#
# 0vkyWjqLn1CxlLegVyhO8n
#
# 0vkyWjqLn1CxlLegVyhO8d
#
# 0vkyWjqLn1CxlLegVyhOFH
#
# 0vkyWjqLn1CxlLegVyhOFM
#
# 0vkyWjqLn1CxlLegVyhOF1
#
# 0vkyWjqLn1CxlLegVyhOEI
#
# 0vkyWjqLn1CxlLegVyhOEy
#
# 0vkyWjqLn1CxlLegVyhOEc
#
# 0vkyWjqLn1CxlLegVyhOCv
#
# 0vkyWjqLn1CxlLegVyhO3Q
#
# 0vkyWjqLn1CxlLegVyhO34
#
# 0vkyWjqLn1CxlLegVyhO3W
#
# 0vkyWjqLn1CxlLegVyhO3b
#
# 0vkyWjqLn1CxlLegVyhO3g
#
# 0vkyWjqLn1CxlLegVyhO3l
#
# 0vkyWjqLn1CxlLegVyhO21
#
# 0vkyWjqLn1CxlLegVyhO2a
#
# 0vkyWjqLn1CxlLegVyhO18
#
# 0vkyWjqLn1CxlLegVyhO1C
#
# 0vkyWjqLn1CxlLegVyhO1m
#
# 0vkyWjqLn1CxlLegVyhO1q
#
# 0vkyWjqLn1CxlLegVyhO1u
#
# 0vkyWjqLn1CxlLegVyhO0M
#
# 0vkyWjqLn1CxlLegVyhO0n
#
# 0vkyWjqLn1CxlLegVyhO0r
#
# 0vkyWjqLn1CxlLegVyhO0v
#
# 0vkyWjqLn1CxlLegVyhO0z
#
# 0vkyWjqLn1CxlLegVyhO7G
#
# 0vkyWjqLn1CxlLegVyhO$4
#
# 0vkyWjqLn1CxlLegVyhO$p
#
# 0vkyWjqLn1CxlLegVyhO$Y
#
# 0vkyWjqLn1CxlLegVyhOoH
#
# 0vkyWjqLn1CxlLegVyhOoS
#
# 0vkyWjqLn1CxlLegVyhOnP
#
# 0vkyWjqLn1CxlLegVyhOnE
#
# 0vkyWjqLn1CxlLegVyhOnv
#
# 0vkyWjqLn1CxlLegVyhOmp
#
# 0vkyWjqLn1CxlLegVyhOma
#
# 0vkyWjqLn1CxlLegVyhOt6
#
# 0vkyWjqLn1CxlLegVyhOtE
#
# 0vkyWjqLn1CxlLegVyhOsx
#
# 0vkyWjqLn1CxlLegVyhOsh
#
# 0vkyWjqLn1CxlLegVyhOrL
#
# 0vkyWjqLn1CxlLegVyhOrP
#
# 0vkyWjqLn1CxlLegVyhOrU
#
# 0vkyWjqLn1CxlLegVyhOr3
#
# 0vkyWjqLn1CxlLegVyhR7F
#
# 0vkyWjqLn1CxlLegVyhRPd
#
# 0vkyWjqLn1CxlLegVyhRV2
#
# 0vkyWjqLn1CxlLegVyhRVl
#
# 0vkyWjqLn1CxlLegVyhRTM
#
# 0vkyWjqLn1CxlLegVyhRT5
#
# 0vkyWjqLn1CxlLegVyhRTa
#
# 0vkyWjqLn1CxlLegVyhRST
#
# 0vkyWjqLn1CxlLegVyhRSx
#
# 2jO$d2Li5ECB0Bpfl6g$TY
#
# 2jO$d2Li5ECB0Bpfl6g$Tn
#
# 2jO$d2Li5ECB0Bpfl6g$TA
#
# 2jO$d2Li5ECB0Bpfl6g$T7
#
# 2jO$d2Li5ECB0Bpfl6g$TK
#
# 2jO$d2Li5ECB0Bpfl6g$TH
#
# 2jO$d2Li5ECB0Bpfl6g$22
#
# 2jO$d2Li5ECB0Bpfl6g$2J
#
# 2jO$d2Li5ECB0Bpfl6g$3r
#
# 2R1y4oivn6hghSJG$FCZgv
#
# 2R1y4oivn6hghSJG$FCZgy
#
# 2Oxg6QEEPEEg8a34mOHP8r
#
# 0vkyWjqLn1CxlLegVyhPTG
#
# 0vkyWjqLn1CxlLegVyhPUh
#
# 0vkyWjqLn1CxlLegVyhPTK
#
# 0vkyWjqLn1CxlLegVyhPTP
#
# 0vkyWjqLn1CxlLegVyhPTC
#
# 0vkyWjqLn1CxlLegVyhPSV
#
# 0vkyWjqLn1CxlLegVyhPSp
#
# 0vkyWjqLn1CxlLegVyhPSZ
#
# 0vkyWjqLn1CxlLegVyhPJP
#
# 0vkyWjqLn1CxlLegVyhPIL
#
# 0vkyWjqLn1CxlLegVyhPHc
#
# 0vkyWjqLn1CxlLegVyhPNW
#
# 0vkyWjqLn1CxlLegVyhPML
#
# 0vkyWjqLn1CxlLegVyhPMU
#
# 0vkyWjqLn1CxlLegVyhPMp
#
# 0vkyWjqLn1CxlLegVyhPMx
#
# 0vkyWjqLn1CxlLegVyhPMd
#
# 0vkyWjqLn1CxlLegVyhPMi
#
# 0vkyWjqLn1CxlLegVyhPLM
#
# 0vkyWjqLn1CxlLegVyhPLR
#
# 0vkyWjqLn1CxlLegVyhPL2
#
# 0vkyWjqLn1CxlLegVyhPL_
#
# 0vkyWjqLn1CxlLegVyhOA_
#
# 0vkyWjqLn1CxlLegVyhOAb
#
# 0vkyWjqLn1CxlLegVyhOAg
#
# 0vkyWjqLn1CxlLegVyhO9O
#
# 0vkyWjqLn1CxlLegVyhO9T
#
# 0vkyWjqLn1CxlLegVyhO93
#
# 0vkyWjqLn1CxlLegVyhO98
#
# 0vkyWjqLn1CxlLegVyhO9F
#
# 0vkyWjqLn1CxlLegVyhO9q
#
# 0vkyWjqLn1CxlLegVyhO9v
#
# 0vkyWjqLn1CxlLegVyhO9_
#
# 0vkyWjqLn1CxlLegVyhO8H
#
# 0vkyWjqLn1CxlLegVyhO8R
#
# 0vkyWjqLn1CxlLegVyhO82
#
# 0vkyWjqLn1CxlLegVyhO87
#
# 0vkyWjqLn1CxlLegVyhO8Y
#
# 0vkyWjqLn1CxlLegVyhO8i
#
# 0vkyWjqLn1CxlLegVyhOFD
#
# 0vkyWjqLn1CxlLegVyhOFo
#
# 0vkyWjqLn1CxlLegVyhOFz
#
# 0vkyWjqLn1CxlLegVyhOFZ
#
# 0vkyWjqLn1CxlLegVyhOFe
#
# 0vkyWjqLn1CxlLegVyhOEN
#
# 0vkyWjqLn1CxlLegVyhOES
#
# 0vkyWjqLn1CxlLegVyhOE1
#
# 0vkyWjqLn1CxlLegVyhOE9
#
# 0vkyWjqLn1CxlLegVyhOEE
#
# 0vkyWjqLn1CxlLegVyhOEo
#
# 0vkyWjqLn1CxlLegVyhOEt
#
# 0vkyWjqLn1CxlLegVyhOEX
#
# 0vkyWjqLn1CxlLegVyhOEl
#
# 0vkyWjqLn1CxlLegVyhODM
#
# 0vkyWjqLn1CxlLegVyhODT
#
# 0vkyWjqLn1CxlLegVyhOD5
#
# 0vkyWjqLn1CxlLegVyhODC
#
# 0vkyWjqLn1CxlLegVyhODo
#
# 0vkyWjqLn1CxlLegVyhODt
#
# 0vkyWjqLn1CxlLegVyhODh
#
# 0vkyWjqLn1CxlLegVyhOCI
#
# 0vkyWjqLn1CxlLegVyhOCN
#
# 0vkyWjqLn1CxlLegVyhOC5
#
# 0vkyWjqLn1CxlLegVyhOCA
#
# 0vkyWjqLn1CxlLegVyhOCF
#
# 0vkyWjqLn1CxlLegVyhOCq
#
# 0vkyWjqLn1CxlLegVyhOCW
#
# 0vkyWjqLn1CxlLegVyhOCb
#
# 0vkyWjqLn1CxlLegVyhOCh
#
# 0vkyWjqLn1CxlLegVyhO3G
#
# 0vkyWjqLn1CxlLegVyhO3L
#
# 0vkyWjqLn1CxlLegVyhO39
#
# 0vkyWjqLn1CxlLegVyhO3E
#
# 0vkyWjqLn1CxlLegVyhO3q
#
# 0vkyWjqLn1CxlLegVyhO3w
#
# 0vkyWjqLn1CxlLegVyhO2S
#
# 0vkyWjqLn1CxlLegVyhO2f
#
# 0vkyWjqLn1CxlLegVyhO2k
#
# 0vkyWjqLn1CxlLegVyhO1K
#
# 0vkyWjqLn1CxlLegVyhO1Q
#
# 0vkyWjqLn1CxlLegVyhO14
#
# 0vkyWjqLn1CxlLegVyhO0Q
#
# 0vkyWjqLn1CxlLegVyhO0V
#
# 0vkyWjqLn1CxlLegVyhO05
#
# 0vkyWjqLn1CxlLegVyhO0B
#
# 0vkyWjqLn1CxlLegVyhO0i
#
# 0vkyWjqLn1CxlLegVyhO7A
#
# 0vkyWjqLn1CxlLegVyhO7m
#
# 0vkyWjqLn1CxlLegVyhO7r
#
# 0vkyWjqLn1CxlLegVyhO7x
#
# 0vkyWjqLn1CxlLegVyhO7W
#
# 0vkyWjqLn1CxlLegVyhO7c
#
# 0vkyWjqLn1CxlLegVyhO7i
#
# 0vkyWjqLn1CxlLegVyhO6H
#
# 0vkyWjqLn1CxlLegVyhO6N
#
# 0vkyWjqLn1CxlLegVyhO6S
#
# 0vkyWjqLn1CxlLegVyhO61
#
# 0vkyWjqLn1CxlLegVyhO66
#
# 0vkyWjqLn1CxlLegVyhO$A
#
# 0vkyWjqLn1CxlLegVyhO$c
#
# 0vkyWjqLn1CxlLegVyhOpi
#
# 0vkyWjqLn1CxlLegVyhOoM
#
# 0vkyWjqLn1CxlLegVyhOo2
#
# 0vkyWjqLn1CxlLegVyhOo7
#
# 0vkyWjqLn1CxlLegVyhOon
#
# 0vkyWjqLn1CxlLegVyhOos
#
# 0vkyWjqLn1CxlLegVyhOox
#
# 0vkyWjqLn1CxlLegVyhOoW
#
# 0vkyWjqLn1CxlLegVyhOob
#
# 0vkyWjqLn1CxlLegVyhOoh
#
# 0vkyWjqLn1CxlLegVyhOnG
#
# 0vkyWjqLn1CxlLegVyhOn4
#
# 0vkyWjqLn1CxlLegVyhOnZ
#
# 0vkyWjqLn1CxlLegVyhOmJ
#
# 0vkyWjqLn1CxlLegVyhOmA
#
# 0vkyWjqLn1CxlLegVyhOmE
#
# 0vkyWjqLn1CxlLegVyhOmy
#
# 0vkyWjqLn1CxlLegVyhOtH
#
# 0vkyWjqLn1CxlLegVyhOto
#
# 0vkyWjqLn1CxlLegVyhOsP
#
# 0vkyWjqLn1CxlLegVyhOsT
#
# 0vkyWjqLn1CxlLegVyhOs2
#
# 0vkyWjqLn1CxlLegVyhOs5
#
# 0vkyWjqLn1CxlLegVyhOsA
#
# 0vkyWjqLn1CxlLegVyhOsm
#
# 0vkyWjqLn1CxlLegVyhOsr
#
# 0vkyWjqLn1CxlLegVyhOs$
#
# 0vkyWjqLn1CxlLegVyhOsb
#
# 0vkyWjqLn1CxlLegVyhOrG
#
# 0vkyWjqLn1CxlLegVyhR73
#
# 0vkyWjqLn1CxlLegVyhR77
#
# 0vkyWjqLn1CxlLegVyhR7p
#
# 0vkyWjqLn1CxlLegVyhRP5
#
# 0vkyWjqLn1CxlLegVyhRP9
#
# 0vkyWjqLn1CxlLegVyhRPF
#
# 0vkyWjqLn1CxlLegVyhRPz
#
# 0vkyWjqLn1CxlLegVyhRPY
#
# 0vkyWjqLn1CxlLegVyhRPl
#
# 0vkyWjqLn1CxlLegVyhROM
#
# 0vkyWjqLn1CxlLegVyhROU
#
# 0vkyWjqLn1CxlLegVyhROA
#
# 0vkyWjqLn1CxlLegVyhROF
#
# 0vkyWjqLn1CxlLegVyhROv
#
# 0vkyWjqLn1CxlLegVyhROW
#
# 0vkyWjqLn1CxlLegVyhROb
#
# 0vkyWjqLn1CxlLegVyhROf
#
# 0vkyWjqLn1CxlLegVyhROl
#
# 0vkyWjqLn1CxlLegVyhRVK
#
# 0vkyWjqLn1CxlLegVyhRVO
#
# 0vkyWjqLn1CxlLegVyhRV7
#
# 0vkyWjqLn1CxlLegVyhRVD
#
# 0vkyWjqLn1CxlLegVyhRVt
#
# 0vkyWjqLn1CxlLegVyhRVx
#
# 0vkyWjqLn1CxlLegVyhRV$
#
# 0vkyWjqLn1CxlLegVyhRVa
#
# 0vkyWjqLn1CxlLegVyhRVg
#
# 0vkyWjqLn1CxlLegVyhRUK
#
# 0vkyWjqLn1CxlLegVyhRUO
#
# 0vkyWjqLn1CxlLegVyhRUS
#
# 0vkyWjqLn1CxlLegVyhRU0
#
# 0vkyWjqLn1CxlLegVyhRU4
#
# 0vkyWjqLn1CxlLegVyhRTH
#
# 0vkyWjqLn1CxlLegVyhRTS
#
# 0vkyWjqLn1CxlLegVyhRTi
#
# 0vkyWjqLn1CxlLegVyhRSs
#
# 0vkyWjqLn1CxlLegVyhRS$
#
# 0vkyWjqLn1CxlLegVyhRSa
#
# 0vkyWjqLn1CxlLegVyhRSe
#
# 0vkyWjqLn1CxlLegVyhRSk
#
# 0vkyWjqLn1CxlLegVyhRJI
#
# 2jO$d2Li5ECB0Bpfl6g$T_
#
# 2jO$d2Li5ECB0Bpfl6g$Tx
#
# 2jO$d2Li5ECB0Bpfl6g$Tq
#
# 2jO$d2Li5ECB0Bpfl6g$T0
#
# 2jO$d2Li5ECB0Bpfl6g$TS
#
# 2jO$d2Li5ECB0Bpfl6g$TR
#
# 2jO$d2Li5ECB0Bpfl6g$2g
#
# 2jO$d2Li5ECB0Bpfl6g$2d
#
# 2jO$d2Li5ECB0Bpfl6g$2W
#
# 2jO$d2Li5ECB0Bpfl6g$2z
#
# 2jO$d2Li5ECB0Bpfl6g$2p
#
# Erro de modelagem, GlobalId: 2jO$d2Li5ECB0Bpfl6g$2C
# 2jO$d2Li5ECB0Bpfl6g$29
#
# 2jO$d2Li5ECB0Bpfl6g$2P
#
# 2jO$d2Li5ECB0Bpfl6g$3f
#
# 2jO$d2Li5ECB0Bpfl6g$3Y
#
# 2jO$d2Li5ECB0Bpfl6g$3$
#
# 2jO$d2Li5ECB0Bpfl6g$3u
#
# 2jO$d2Li5ECB0Bpfl6g$7c
#
# 2jO$d2Li5ECB0Bpfl6g$4M
#
# 2jO$d2Li5ECB0Bpfl6g$Ag
#
# 2R1y4oivn6hghSJG$FCYNB
#
# 2R1y4oivn6hghSJG$FCYLF
#
# 2R1y4oivn6hghSJG$FCYL2
#
# 2R1y4oivn6hghSJG$FCYL5
#
# 2R1y4oivn6hghSJG$FCYLO
#
# 2R1y4oivn6hghSJG$FCYLJ
#
# 2R1y4oivn6hghSJG$FCYLN
#
# 2R1y4oivn6hghSJG$FCZgg
#
# 2R1y4oivn6hghSJG$FCZgj
#
# 2R1y4oivn6hghSJG$FCZgX
#
# 2R1y4oivn6hghSJG$FCZgb
#
# 2R1y4oivn6hghSJG$FCZgt
#
# 2R1y4oivn6hghSJG$FCZgA
#
# 2R1y4oivn6hghSJG$FCZgE
#
# 2R1y4oivn6hghSJG$FCZg2
#
# 2R1y4oivn6hghSJG$FCZg5
#
# 2R1y4oivn6hghSJG$FCZgP
#
# 0$TvfvQWT3UPXp$fNe6PWw
#
# 1hs8EA$Yv9YPuWrkU0DYUF
#
# 1hs8EA$Yv9YPuWrkU0DY4v
#
# 2QSZAU7bTBNwjejK5NsP2B
#
# 0vkyWjqLn1CxlLegVyhPyk
#
# 0vkyWjqLn1CxlLegVyhPys
#
# 0vkyWjqLn1CxlLegVyhPy4
#
# 0vkyWjqLn1CxlLegVyhPyR
#
# 0vkyWjqLn1CxlLegVyhPyI
#
# 0vkyWjqLn1CxlLegVyhPzf
#
# 0vkyWjqLn1CxlLegVyhPzW
#
# 0vkyWjqLn1CxlLegVyhPzt
#
# 0vkyWjqLn1CxlLegVyhPzE
#
# 0vkyWjqLn1CxlLegVyhPz5
#
# 0vkyWjqLn1CxlLegVyhPzS
#
# 0vkyWjqLn1CxlLegVyhPzH
#
# 0vkyWjqLn1CxlLegVyhP_d
#
# 0vkyWjqLn1CxlLegVyhP_t
#
# 0vkyWjqLn1CxlLegVyhP$T
#
# 0vkyWjqLn1CxlLegVyhP$L
#
# 0vkyWjqLn1CxlLegVyhPuj
#
# 0vkyWjqLn1CxlLegVyhPub
#
# 0vkyWjqLn1CxlLegVyhPuI
#
# 0vkyWjqLn1CxlLegVyhPvO
#
# 0vkyWjqLn1CxlLegVyhPwe
#
# 0vkyWjqLn1CxlLegVyhPbl
#
# 0vkyWjqLn1CxlLegVyhPbd
#
# 0vkyWjqLn1CxlLegVyhPb$
#
# 0vkyWjqLn1CxlLegVyhPbt
#
# 0vkyWjqLn1CxlLegVyhPbF
#
# 0vkyWjqLn1CxlLegVyhPdE
#
# 0vkyWjqLn1CxlLegVyhPWd
#
# 0vkyWjqLn1CxlLegVyhPW_
#
# 0vkyWjqLn1CxlLegVyhPW4
#
# 0vkyWjqLn1CxlLegVyhPWP
#
# 0vkyWjqLn1CxlLegVyhPZK
#
# 0vkyWjqLn1CxlLegVyhPii
#
# 0vkyWjqLn1CxlLegVyhPia
#
# 0vkyWjqLn1CxlLegVyhPiq
#
# 0vkyWjqLn1CxlLegVyhPkv
#
# 0vkyWjqLn1CxlLegVyhPkI
#
# 0vkyWjqLn1CxlLegVyhPle
#
# 0vkyWjqLn1CxlLegVyhPlz
#
# 0vkyWjqLn1CxlLegVyhPlq
#
# 0vkyWjqLn1CxlLegVyhPl6
#
# 0vkyWjqLn1CxlLegVyhPel
#
# 0vkyWjqLn1CxlLegVyhPe9
#
# 0vkyWjqLn1CxlLegVyhPf1
#
# 0vkyWjqLn1CxlLegVyhPfI
#
# 0vkyWjqLn1CxlLegVyhPgS
#
# 0vkyWjqLn1CxlLegVyhPhj
#
# 0vkyWjqLn1CxlLegVyhPKh
#
# 0vkyWjqLn1CxlLegVyhPKY
#
# 0vkyWjqLn1CxlLegVyhPKv
#
# 0$TvfvQWT3UPXp$fNe6PDk
#
# 0$TvfvQWT3UPXp$fNe6P5v
#
# 3_7yiTIpf3Se084qNIStC7
#
# 3_7yiTIpf3Se084qNIStCC
#
# 3_7yiTIpf3Se084qNIStFr
#
# 0UHAxoGVvD8v2kyxoGk9KL
#
# 2R1y4oivn6hghSJG$FCZk8
#
# 2R1y4oivn6hghSJG$FCZkn
#
# 2R1y4oivn6hghSJG$FCZkZ
#
# 2R1y4oivn6hghSJG$FCZfK
#
# 2R1y4oivn6hghSJG$FCZf6
#
# 2R1y4oivn6hghSJG$FCZfF
#
# 2R1y4oivn6hghSJG$FCZeO
#
# 2R1y4oivn6hghSJG$FCZhE
#
# 2jO$d2Li5ECB0Bpfl6g$17
#
# 2jO$d2Li5ECB0Bpfl6g$1E
#
# 2jO$d2Li5ECB0Bpfl6g$1v
#
# 2jO$d2Li5ECB0Bpfl6g$1W
#
# 2jO$d2Li5ECB0Bpfl6g$0I
#
# 2jO$d2Li5ECB0Bpfl6g$0T
#
# 2jO$d2Li5ECB0Bpfl6g$04
#
# 2jO$d2Li5ECB0Bpfl6g$0w
#
# 2jO$d2Li5ECB0Bpfl6g$0f
#
# 2jO$d2Li5ECB0Bpfl6g$3G
#
# 2jO$d2Li5ECB0Bpfl6g$Uo
#
# 2jO$d2Li5ECB0Bpfl6g$U$
#
# 2jO$d2Li5ECB0Bpfl6g$PE
#
# 2jO$d2Li5ECB0Bpfl6g$OD
#
# 0vkyWjqLn1CxlLegVyhRkh
#
# 0vkyWjqLn1CxlLegVyhRk_
#
# 0vkyWjqLn1CxlLegVyhRlp
#
# 0vkyWjqLn1CxlLegVyhRlB
#
# 0vkyWjqLn1CxlLegVyhRl3
#
# 0vkyWjqLn1CxlLegVyhReh
#
# 0vkyWjqLn1CxlLegVyhReO
#
# 0vkyWjqLn1CxlLegVyhRfq
#
# 0vkyWjqLn1CxlLegVyhRfB
#
# 0vkyWjqLn1CxlLegVyhRg1
#
# 0vkyWjqLn1CxlLegVyhRgH
#
# 0vkyWjqLn1CxlLegVyhRhf
#
# 0vkyWjqLn1CxlLegVyhRKc
#
# 0vkyWjqLn1CxlLegVyhRK1
#
# 0vkyWjqLn1CxlLegVyhRKO
#
# 0vkyWjqLn1CxlLegVyhRMj
#
# 0vkyWjqLn1CxlLegVyhRMb
#
# 0vkyWjqLn1CxlLegVyhRMr
#
# 0vkyWjqLn1CxlLegVyhRMD
#
# 0vkyWjqLn1CxlLegVyhRM5
#
# 0vkyWjqLn1CxlLegVyhRGk
#
# 0vkyWjqLn1CxlLegVyhRGb
#
# 0vkyWjqLn1CxlLegVyhRGm
#
# 0vkyWjqLn1CxlLegVyhRG5
#
# 0vkyWjqLn1CxlLegVyhRGG
#
# 0vkyWjqLn1CxlLegVyhRHE
#
# 0vkyWjqLn1CxlLegVyhRH5
#
# 0vkyWjqLn1CxlLegVyhRHS
#
# 0vkyWjqLn1CxlLegVyhRHJ
#
# 0vkyWjqLn1CxlLegVyhRIf
#
# 0vkyWjqLn1CxlLegVyhRID
#
# 0vkyWjqLn1CxlLegVyhRI4
#
# 0vkyWjqLn1CxlLegVyhRIQ
#
# 0vkyWjqLn1CxlLegVyhRIG
#
# 0vkyWjqLn1CxlLegVyhRJY
#
# 0vkyWjqLn1CxlLegVyhR7J
#
# 0vkyWjqLn1CxlLegVyhR0g
#
# 0vkyWjqLn1CxlLegVyhR0X
#
# 0vkyWjqLn1CxlLegVyhR0F
#
# 0vkyWjqLn1CxlLegVyhR02
#
# 0vkyWjqLn1CxlLegVyhR1G
#
# 0vkyWjqLn1CxlLegVyhR2e
#
# 0vkyWjqLn1CxlLegVyhR2m
#
# 0vkyWjqLn1CxlLegVyhR3z
#
# 0vkyWjqLn1CxlLegVyhRCG
#
# 0vkyWjqLn1CxlLegVyhRDe
#
# 0vkyWjqLn1CxlLegVyhRDu
#
# 0vkyWjqLn1CxlLegVyhRDm
#
# 0vkyWjqLn1CxlLegVyhREr
#
# 0vkyWjqLn1CxlLegVyhREK
#
# 0vkyWjqLn1CxlLegVyhRFh
#
# 0vkyWjqLn1CxlLegVyhR8q
#
# 0vkyWjqLn1CxlLegVyhR8C
#
# 0vkyWjqLn1CxlLegVyhR84
#
# 0vkyWjqLn1CxlLegVyhR8K
#
# 0vkyWjqLn1CxlLegVyhR9i
#
# 0vkyWjqLn1CxlLegVyhR9P
#
# 0vkyWjqLn1CxlLegVyhRAu
#
# 0vkyWjqLn1CxlLegVyhRAF
#
# 0vkyWjqLn1CxlLegVyhRA2
#
# 0vkyWjqLn1CxlLegVyhRAO
#
# 0vkyWjqLn1CxlLegVyhRB9
#
# 0vkyWjqLn1CxlLegVyhRBL
#
# 0vkyWjqLn1CxlLegVyhOq0
#
# 0vkyWjqLn1CxlLegVyhOrd
#
# 0vkyWjqLn1CxlLegVyhOrs
#
# 0vkyWjqLn1CxlLegVyhO$1
#
# 0vkyWjqLn1CxlLegVyhO$N
#
# 0vkyWjqLn1CxlLegVyhOub
#
# 0vkyWjqLn1CxlLegVyhOuD
#
# 0vkyWjqLn1CxlLegVyhOxy
#
# 0vkyWjqLn1CxlLegVyhOxC
#
# 0vkyWjqLn1CxlLegVyhOx4
#
# 0vkyWjqLn1CxlLegVyhOxK
#
# 0vkyWjqLn1CxlLegVyhObR
#
# 0vkyWjqLn1CxlLegVyhOcE
#
# 0vkyWjqLn1CxlLegVyhOY3
#
# 0vkyWjqLn1CxlLegVyhOYR
#
# 0vkyWjqLn1CxlLegVyhOYJ
#
# 0vkyWjqLn1CxlLegVyhOZh
#
# 0vkyWjqLn1CxlLegVyhOZZ
#
# 0vkyWjqLn1CxlLegVyhOZx
#
# 0vkyWjqLn1CxlLegVyhOjq
#
# 0vkyWjqLn1CxlLegVyhOjP
#
# 0vkyWjqLn1CxlLegVyhOkd
#
# 0vkyWjqLn1CxlLegVyhOfa
#
# 0vkyWjqLn1CxlLegVyhOfy
#
# 0vkyWjqLn1CxlLegVyhOfq
#
# 0vkyWjqLn1CxlLegVyhOfC
#
# 0vkyWjqLn1CxlLegVyhOf4
#
# 0vkyWjqLn1CxlLegVyhOfS
#
# 0vkyWjqLn1CxlLegVyhOKw
#
# 0vkyWjqLn1CxlLegVyhOK7
#
# 0vkyWjqLn1CxlLegVyhOKT
#
# 0vkyWjqLn1CxlLegVyhOKJ
#
# 0vkyWjqLn1CxlLegVyhOL8
#
# 0vkyWjqLn1CxlLegVyhOLN
#
# 0vkyWjqLn1CxlLegVyhOQB
#
# 0vkyWjqLn1CxlLegVyhOQP
#
# 0vkyWjqLn1CxlLegVyhOQG
#
# 0vkyWjqLn1CxlLegVyhORd
#
# 0vkyWjqLn1CxlLegVyhOR_
#
# 0vkyWjqLn1CxlLegVyhORr
#
# 0vkyWjqLn1CxlLegVyhORC
#
# 0vkyWjqLn1CxlLegVyhOR3
#
# 0vkyWjqLn1CxlLegVyhO4d
#
# 0vkyWjqLn1CxlLegVyhO4_
#
# 0vkyWjqLn1CxlLegVyhO45
#
# 0vkyWjqLn1CxlLegVyhO4S
#
# 0vkyWjqLn1CxlLegVyhO5D
#
# 0vkyWjqLn1CxlLegVyhO53
#
# 0vkyWjqLn1CxlLegVyhO5P
#
# 0vkyWjqLn1CxlLegVyhO5G
#
# 0vkyWjqLn1CxlLegVyhO6q
#
# 0vkyWjqLn1CxlLegVyhPyD
#
# 0vkyWjqLn1CxlLegVyhP$D
#
# 0vkyWjqLn1CxlLegVyhP$5
#
# 0vkyWjqLn1CxlLegVyhPvB
#
# 0vkyWjqLn1CxlLegVyhPv2
#
# 0vkyWjqLn1CxlLegVyhPwz
#
# 0vkyWjqLn1CxlLegVyhPb7
#
# 0vkyWjqLn1CxlLegVyhPZS
#
# 0vkyWjqLn1CxlLegVyhPf_
#
# 0vkyWjqLn1CxlLegVyhPgW
#
# 0vkyWjqLn1CxlLegVyhPgE
#
# 0vkyWjqLn1CxlLegVyhPhK
#
# 0vkyWjqLn1CxlLegVyhOuk
#
# 0UHAxoGVvD8v2kyxoGk9LE
#
# 0vkyWjqLn1CxlLegVyhOcW
#
# 0vkyWjqLn1CxlLegVyhOxS
#
# 0vkyWjqLn1CxlLegVyhOxq
#
# 0vkyWjqLn1CxlLegVyhR2u
#
# 0vkyWjqLn1CxlLegVyhR2W
#
# 0vkyWjqLn1CxlLegVyhR1O
#
# 0vkyWjqLn1CxlLegVyhR0u
#
# 0vkyWjqLn1CxlLegVyhRlJ
#
# 0vkyWjqLn1CxlLegVyhRlR
#
# 0vkyWjqLn1CxlLegVyhRF_
#
# 0vkyWjqLn1CxlLegVyhRD8
#
# 0vkyWjqLn1CxlLegVyhRDW
#
# 0vkyWjqLn1CxlLegVyhR3Q
#
# 0vkyWjqLn1CxlLegVyhRhv
#
# 0vkyWjqLn1CxlLegVyhRhX
#
# 0vkyWjqLn1CxlLegVyhRgP
#
# 0vkyWjqLn1CxlLegVyhPiy
#
# 0vkyWjqLn1CxlLegVyhPWq
#
# 0vkyWjqLn1CxlLegVyhOhL
#
# 0vkyWjqLn1CxlLegVyhR8S
#
# 0vkyWjqLn1CxlLegVyhRNo
#
# 0vkyWjqLn1CxlLegVyhRMz
#
# 0vkyWjqLn1CxlLegVyhPpS
#
# 0vkyWjqLn1CxlLegVyhO5s
#
# 0vkyWjqLn1CxlLegVyhO5e
#
# 0vkyWjqLn1CxlLegVyhO4o
#
# 0vkyWjqLn1CxlLegVyhORG
#
# 0vkyWjqLn1CxlLegVyhORP
#
# 0vkyWjqLn1CxlLegVyhOQx
#
# 0vkyWjqLn1CxlLegVyhOM8
#
# 0vkyWjqLn1CxlLegVyhOqi
#
# 0vkyWjqLn1CxlLegVyhR7S
#
# 0vkyWjqLn1CxlLegVyhRIs
#
# 0vkyWjqLn1CxlLegVyhRI$
#
# 0vkyWjqLn1CxlLegVyhRHt
#
# 0vkyWjqLn1CxlLegVyhRGx
#
# 2R1y4oivn6hghSJG$FCZkw
#
# 2R1y4oivn6hghSJG$FCZfT
#
# 2R1y4oivn6hghSJG$FCZef
#
# 2jO$d2Li5ECB0Bpfl6g$1h
#
# 2jO$d2Li5ECB0Bpfl6g$0n
#
# 0vkyWjqLn1CxlLegVyhPnA
#
# 0vkyWjqLn1CxlLegVyhPn6
#
# 0vkyWjqLn1CxlLegVyhPn4
#
# 0vkyWjqLn1CxlLegVyhPn2
#
# 0vkyWjqLn1CxlLegVyhPnU
#
# 0vkyWjqLn1CxlLegVyhPnQ
#
# 0vkyWjqLn1CxlLegVyhPt5
#
# 0vkyWjqLn1CxlLegVyhPsM
#
# 0vkyWjqLn1CxlLegVyhPru
#
# 0vkyWjqLn1CxlLegVyhPnM
#
# 0vkyWjqLn1CxlLegVyhPnI
#
# 0vkyWjqLn1CxlLegVyhPoj
#
# 0vkyWjqLn1CxlLegVyhPoh
#
# 0vkyWjqLn1CxlLegVyhPoe
#
# 0vkyWjqLn1CxlLegVyhPoX
#
# 0vkyWjqLn1CxlLegVyhPo$
#
# 0vkyWjqLn1CxlLegVyhPoz
#
# 0vkyWjqLn1CxlLegVyhPov
#
# 0vkyWjqLn1CxlLegVyhPor
#
# 0vkyWjqLn1CxlLegVyhPsu
#
# 0vkyWjqLn1CxlLegVyhPrC
#
# 0vkyWjqLn1CxlLegVyhPoC
#
# 0vkyWjqLn1CxlLegVyhPoA
#
# 0vkyWjqLn1CxlLegVyhPo8
#
# 0vkyWjqLn1CxlLegVyhPo5
#
# 0vkyWjqLn1CxlLegVyhPoV
#
# 0vkyWjqLn1CxlLegVyhPoR
#
# 0vkyWjqLn1CxlLegVyhPoH
#
# 0vkyWjqLn1CxlLegVyhPoE
#
# 0vkyWjqLn1CxlLegVyhPnv
#
# 0vkyWjqLn1CxlLegVyhPnY
#
# 0vkyWjqLn1CxlLegVyhPmO
#
# 0vkyWjqLn1CxlLegVyhPt0
#
# 0vkyWjqLn1CxlLegVyhPtq
#
# 0vkyWjqLn1CxlLegVyhPtz
#
# 0vkyWjqLn1CxlLegVyhPtY
#
# 0vkyWjqLn1CxlLegVyhPtd
#
# 0vkyWjqLn1CxlLegVyhOB4
#
# 0vkyWjqLn1CxlLegVyhOBA
#
# 0vkyWjqLn1CxlLegVyhOBF
#
# 0vkyWjqLn1CxlLegVyhOBe
#
# 0vkyWjqLn1CxlLegVyhR5g
#
# 0vkyWjqLn1CxlLegVyhR48
#
# 0vkyWjqLn1CxlLegVyhR4m
#
# 0vkyWjqLn1CxlLegVyhR4j
#
# 0vkyWjqLn1CxlLegVyhRRH
#
# 0vkyWjqLn1CxlLegVyhRRL
#
# 0vkyWjqLn1CxlLegVyhRRB
#
# 0vkyWjqLn1CxlLegVyhRRF
#
# 0vkyWjqLn1CxlLegVyhRRp
#
# 0vkyWjqLn1CxlLegVyhRRx
#
# 0vkyWjqLn1CxlLegVyhRR$
#
# 0vkyWjqLn1CxlLegVyhRRd
#
# 0vkyWjqLn1CxlLegVyhRRl
#
# 0vkyWjqLn1CxlLegVyhRQJ
#
# 0vkyWjqLn1CxlLegVyhRQN
#
# 0vkyWjqLn1CxlLegVyhRQ7
#
# 0vkyWjqLn1CxlLegVyhRPU
#
# 0vkyWjqLn1CxlLegVyhPpl
#
# 0vkyWjqLn1CxlLegVyhPpa
#
# 0vkyWjqLn1CxlLegVyhPpW
#
# 0vkyWjqLn1CxlLegVyhPpx
#
# 0vkyWjqLn1CxlLegVyhPpv
#
# 0vkyWjqLn1CxlLegVyhPpo
#
# 0vkyWjqLn1CxlLegVyhPpE
#
# 0vkyWjqLn1CxlLegVyhPpr
#
# 0vkyWjqLn1CxlLegVyhPpj
#
# 0vkyWjqLn1CxlLegVyhPo3
#
# 0vkyWjqLn1CxlLegVyhPn_
#
# 0vkyWjqLn1CxlLegVyhPnd
#
# 0vkyWjqLn1CxlLegVyhPnh
#
# 0vkyWjqLn1CxlLegVyhPnl
#
# 0vkyWjqLn1CxlLegVyhPm$
#
# 0vkyWjqLn1CxlLegVyhPmZ
#
# 0vkyWjqLn1CxlLegVyhPmi
#
# 0vkyWjqLn1CxlLegVyhPtK
#
# 0vkyWjqLn1CxlLegVyhPtO
#
# 0vkyWjqLn1CxlLegVyhPtS
#
# 0vkyWjqLn1CxlLegVyhPtm
#
# 0vkyWjqLn1CxlLegVyhPtv
#
# 0vkyWjqLn1CxlLegVyhPrZ
#
# 0vkyWjqLn1CxlLegVyhOB0
#
# 0vkyWjqLn1CxlLegVyhOBq
#
# 0vkyWjqLn1CxlLegVyhR58
#
# 0vkyWjqLn1CxlLegVyhR5C
#
# 0vkyWjqLn1CxlLegVyhR5r
#
# 0vkyWjqLn1CxlLegVyhR5v
#
# 0vkyWjqLn1CxlLegVyhR5z
#
# 0vkyWjqLn1CxlLegVyhR5X
#
# 0vkyWjqLn1CxlLegVyhR5b
#
# 0vkyWjqLn1CxlLegVyhR5k
#
# 0vkyWjqLn1CxlLegVyhR44
#
# 0vkyWjqLn1CxlLegVyhR4C
#
# 0vkyWjqLn1CxlLegVyhR4e
#
# 0vkyWjqLn1CxlLegVyhRR7
#
# 0vkyWjqLn1CxlLegVyhRRt
#
# 0vkyWjqLn1CxlLegVyhRRZ
#
# 0vkyWjqLn1CxlLegVyhRRh
#
# 0vkyWjqLn1CxlLegVyhRQB
#
# 0vkyWjqLn1CxlLegVyhRQk
#
# 0vkyWjqLn1CxlLegVyhRPI
#
# 0vkyWjqLn1CxlLegVyhRPQ
#
# 0vkyWjqLn1CxlLegVyhPp6
#
# 0vkyWjqLn1CxlLegVyhPUY
#
# 0vkyWjqLn1CxlLegVyhPUW
#
# 0vkyWjqLn1CxlLegVyhPU_
#
# 0vkyWjqLn1CxlLegVyhPUy
#
# 0vkyWjqLn1CxlLegVyhPUv
#
# 0vkyWjqLn1CxlLegVyhPUt
#
# 0vkyWjqLn1CxlLegVyhPUr
#
# 0vkyWjqLn1CxlLegVyhPUp
#
# 0vkyWjqLn1CxlLegVyhPUF
#
# 0vkyWjqLn1CxlLegVyhPUB
#
# 0vkyWjqLn1CxlLegVyhPU7
#
# 0vkyWjqLn1CxlLegVyhPUV
#
# 0vkyWjqLn1CxlLegVyhPUR
#
# 0vkyWjqLn1CxlLegVyhPUN
#
# 0vkyWjqLn1CxlLegVyhPUJ
#
# 0vkyWjqLn1CxlLegVyhPUH
#
# 0vkyWjqLn1CxlLegVyhPVk
#
# 0vkyWjqLn1CxlLegVyhPVg
#
# 0vkyWjqLn1CxlLegVyhPVe
#
# 0vkyWjqLn1CxlLegVyhPVZ
#
# 0vkyWjqLn1CxlLegVyhPVX
#
# 0vkyWjqLn1CxlLegVyhPV_
#
# 0vkyWjqLn1CxlLegVyhPVx
#
# 0vkyWjqLn1CxlLegVyhPVv
#
# 0vkyWjqLn1CxlLegVyhPVt
#
# 0vkyWjqLn1CxlLegVyhPVn
#
# 0vkyWjqLn1CxlLegVyhPVF
#
# 0vkyWjqLn1CxlLegVyhPV6
#
# 0vkyWjqLn1CxlLegVyhPV4
#
# 0vkyWjqLn1CxlLegVyhPV0
#
# 0vkyWjqLn1CxlLegVyhPVT
#
# 0vkyWjqLn1CxlLegVyhPVR
#
# 0vkyWjqLn1CxlLegVyhPVP
#
# 0vkyWjqLn1CxlLegVyhPVL
#
# 0vkyWjqLn1CxlLegVyhPVG
#
# 0vkyWjqLn1CxlLegVyhPOi
#
# 0vkyWjqLn1CxlLegVyhPOg
#
# 0vkyWjqLn1CxlLegVyhPOd
#
# 0vkyWjqLn1CxlLegVyhPOb
#
# 0vkyWjqLn1CxlLegVyhPOZ
#
# 0vkyWjqLn1CxlLegVyhPOx
#
# 0vkyWjqLn1CxlLegVyhPOv
#
# 0vkyWjqLn1CxlLegVyhPOt
#
# 0vkyWjqLn1CxlLegVyhPOq
#
# 0vkyWjqLn1CxlLegVyhPOo
#
# 0vkyWjqLn1CxlLegVyhPOm
#
# 0vkyWjqLn1CxlLegVyhPOE
#
# 0vkyWjqLn1CxlLegVyhPOB
#
# 0vkyWjqLn1CxlLegVyhPO5
#
# 0vkyWjqLn1CxlLegVyhPO1
#
# 0vkyWjqLn1CxlLegVyhPOP
#
# 0vkyWjqLn1CxlLegVyhPOL
#
# 0vkyWjqLn1CxlLegVyhP1r
#
# 0vkyWjqLn1CxlLegVyhP1p
#
# 0vkyWjqLn1CxlLegVyhP1F
#
# 0vkyWjqLn1CxlLegVyhP15
#
# 0vkyWjqLn1CxlLegVyhP11
#
# 0vkyWjqLn1CxlLegVyhP1Q
#
# 0vkyWjqLn1CxlLegVyhP1M
#
# 0vkyWjqLn1CxlLegVyhP1I
#
# 0vkyWjqLn1CxlLegVyhP2h
#
# 0vkyWjqLn1CxlLegVyhP2d
#
# 0vkyWjqLn1CxlLegVyhP2W
#
# 0vkyWjqLn1CxlLegVyhP2y
#
# 0vkyWjqLn1CxlLegVyhP2u
#
# 0vkyWjqLn1CxlLegVyhP2q
#
# 0vkyWjqLn1CxlLegVyhP2n
#
# 0vkyWjqLn1CxlLegVyhP2E
#
# 0vkyWjqLn1CxlLegVyhP2C
#
# 0vkyWjqLn1CxlLegVyhP2A
#
# 0vkyWjqLn1CxlLegVyhP28
#
# 0vkyWjqLn1CxlLegVyhP23
#
# 0vkyWjqLn1CxlLegVyhP21
#
# 0vkyWjqLn1CxlLegVyhP2V
#
# 0vkyWjqLn1CxlLegVyhP2Q
#
# 0vkyWjqLn1CxlLegVyhP2O
#
# 0vkyWjqLn1CxlLegVyhP2M
#
# 0vkyWjqLn1CxlLegVyhP2I
#
# 0vkyWjqLn1CxlLegVyhP3k
#
# 0vkyWjqLn1CxlLegVyhP3c
#
# 0vkyWjqLn1CxlLegVyhP3W
#
# 0vkyWjqLn1CxlLegVyhP3y
#
# 0vkyWjqLn1CxlLegVyhP3u
#
# 0vkyWjqLn1CxlLegVyhP3q
#
# 0vkyWjqLn1CxlLegVyhP3F
#
# 0vkyWjqLn1CxlLegVyhP3D
#
# 0vkyWjqLn1CxlLegVyhP3B
#
# 0vkyWjqLn1CxlLegVyhP38
#
# 0vkyWjqLn1CxlLegVyhP34
#
# 0vkyWjqLn1CxlLegVyhP30
#
# 0vkyWjqLn1CxlLegVyhP3S
#
# 0vkyWjqLn1CxlLegVyhP3M
#
# 0vkyWjqLn1CxlLegVyhPCk
#
# 0vkyWjqLn1CxlLegVyhPCg
#
# 0vkyWjqLn1CxlLegVyhPCd
#
# 0vkyWjqLn1CxlLegVyhPCa
#
# 0vkyWjqLn1CxlLegVyhPCX
#
# 0vkyWjqLn1CxlLegVyhPC$
#
# 0vkyWjqLn1CxlLegVyhPCt
#
# 0vkyWjqLn1CxlLegVyhPCq
#
# 0vkyWjqLn1CxlLegVyhPCE
#
# 0vkyWjqLn1CxlLegVyhPCB
#
# 0vkyWjqLn1CxlLegVyhPC2
#
# 0vkyWjqLn1CxlLegVyhPCV
#
# 0vkyWjqLn1CxlLegVyhPCO
#
# 0vkyWjqLn1CxlLegVyhPCK
#
# 0vkyWjqLn1CxlLegVyhPDg
#
# 0vkyWjqLn1CxlLegVyhPDc
#
# 0vkyWjqLn1CxlLegVyhPDj
#
# 0vkyWjqLn1CxlLegVyhPCG
#
# 0vkyWjqLn1CxlLegVyhPCR
#
# 0vkyWjqLn1CxlLegVyhPC5
#
# 0vkyWjqLn1CxlLegVyhPC8
#
# 0vkyWjqLn1CxlLegVyhPCn
#
# 0vkyWjqLn1CxlLegVyhPCx
#
# 0vkyWjqLn1CxlLegVyhP3H
#
# 0vkyWjqLn1CxlLegVyhP3g
#
# 0vkyWjqLn1CxlLegVyhP2S
#
# 0vkyWjqLn1CxlLegVyhP25
#
# 0vkyWjqLn1CxlLegVyhP2Z
#
# 0vkyWjqLn1CxlLegVyhP2l
#
# 0vkyWjqLn1CxlLegVyhP1U
#
# 0vkyWjqLn1CxlLegVyhP19
#
# 0vkyWjqLn1CxlLegVyhP1t
#
# 0vkyWjqLn1CxlLegVyhPOT
#
# 0vkyWjqLn1CxlLegVyhPO7
#
# 0vkyWjqLn1CxlLegVyhPO9
#
# 0vkyWjqLn1CxlLegVyhPOz
#
# 0vkyWjqLn1CxlLegVyhPOW
#
# 0vkyWjqLn1CxlLegVyhPOk
#
# 0vkyWjqLn1CxlLegVyhPV2
#
# 0vkyWjqLn1CxlLegVyhPVA
#
# 0vkyWjqLn1CxlLegVyhPVD
#
# 0vkyWjqLn1CxlLegVyhPVq
#
# 0vkyWjqLn1CxlLegVyhPVb
#
# 0vkyWjqLn1CxlLegVyhPVi
#
# 0vkyWjqLn1CxlLegVyhPU3
#
# 0vkyWjqLn1CxlLegVyhPUn
#
# 0vkyWjqLn1CxlLegVyhPUa
#
# 0vkyWjqLn1CxlLegVyhPUc
#
# 0vkyWjqLn1CxlLegVyhPpt
#
# 0vkyWjqLn1CxlLegVyhPpz
#
# 0vkyWjqLn1CxlLegVyhPpe
#
# 0vkyWjqLn1CxlLegVyhPpg
#
# 0vkyWjqLn1CxlLegVyhPoL
#
# 0vkyWjqLn1CxlLegVyhPom
#
# 0vkyWjqLn1CxlLegVyhPoa
#
# 0vkyWjqLn1CxlLegVyhPol
#
# 0vkyWjqLn1CxlLegVyhPnE
#
# 0vkyWjqLn1CxlLegVyhPno
#
# 0vkyWjqLn1CxlLegVyhPnq
#
# 0vkyWjqLn1CxlLegVyhPns
#
# 0vkyWjqLn1CxlLegVyhPnx
#
# 0vkyWjqLn1CxlLegVyhPnW
#
# 0vkyWjqLn1CxlLegVyhPna
#
# 0vkyWjqLn1CxlLegVyhPnf
#
# 0vkyWjqLn1CxlLegVyhPnj
#
# 0vkyWjqLn1CxlLegVyhPmH
#
# 0vkyWjqLn1CxlLegVyhPmJ
#
# 0vkyWjqLn1CxlLegVyhPmL
#
# 0vkyWjqLn1CxlLegVyhPmQ
#
# 0vkyWjqLn1CxlLegVyhPmT
#
# 0vkyWjqLn1CxlLegVyhPm1
#
# 0vkyWjqLn1CxlLegVyhPm4
#
# 0vkyWjqLn1CxlLegVyhPm6
#
# 0vkyWjqLn1CxlLegVyhPm9
#
# 0vkyWjqLn1CxlLegVyhPmF
#
# 0vkyWjqLn1CxlLegVyhPmp
#
# 0vkyWjqLn1CxlLegVyhPmt
#
# 0vkyWjqLn1CxlLegVyhPmx
#
# 0vkyWjqLn1CxlLegVyhPmX
#
# 0vkyWjqLn1CxlLegVyhPmb
#
# 0vkyWjqLn1CxlLegVyhPmd
#
# 0vkyWjqLn1CxlLegVyhPmf
#
# 0vkyWjqLn1CxlLegVyhPmk
#
# 0vkyWjqLn1CxlLegVyhPtG
#
# 0vkyWjqLn1CxlLegVyhPtI
#
# 0vkyWjqLn1CxlLegVyhPtM
#
# 0vkyWjqLn1CxlLegVyhPtQ
#
# 0vkyWjqLn1CxlLegVyhPtU
#
# 0vkyWjqLn1CxlLegVyhPt2
#
# 0vkyWjqLn1CxlLegVyhPt7
#
# 0vkyWjqLn1CxlLegVyhPtA
#
# 0vkyWjqLn1CxlLegVyhPtC
#
# 0vkyWjqLn1CxlLegVyhPtE
#
# 0vkyWjqLn1CxlLegVyhPto
#
# 0vkyWjqLn1CxlLegVyhPts
#
# 0vkyWjqLn1CxlLegVyhPtx
#
# 0vkyWjqLn1CxlLegVyhPt$
#
# 0vkyWjqLn1CxlLegVyhPta
#
# 0vkyWjqLn1CxlLegVyhPtf
#
# 0vkyWjqLn1CxlLegVyhPtk
#
# 0vkyWjqLn1CxlLegVyhPsI
#
# 0vkyWjqLn1CxlLegVyhPsO
#
# 0vkyWjqLn1CxlLegVyhPsR
#
# 0vkyWjqLn1CxlLegVyhPsT
#
# 0vkyWjqLn1CxlLegVyhPsV
#
# 0vkyWjqLn1CxlLegVyhPs1
#
# 0vkyWjqLn1CxlLegVyhPs3
#
# 0vkyWjqLn1CxlLegVyhPs7
#
# 0vkyWjqLn1CxlLegVyhPsB
#
# 0vkyWjqLn1CxlLegVyhPsF
#
# 0vkyWjqLn1CxlLegVyhPsn
#
# 0vkyWjqLn1CxlLegVyhPsp
#
# 0vkyWjqLn1CxlLegVyhPss
#
# 0vkyWjqLn1CxlLegVyhPsw
#
# 0vkyWjqLn1CxlLegVyhPsz
#
# 0vkyWjqLn1CxlLegVyhPs$
#
# 0vkyWjqLn1CxlLegVyhPsX
#
# 0vkyWjqLn1CxlLegVyhPsc
#
# 0vkyWjqLn1CxlLegVyhPsg
#
# 0vkyWjqLn1CxlLegVyhPsk
#
# 0vkyWjqLn1CxlLegVyhPrG
#
# 0vkyWjqLn1CxlLegVyhPrI
#
# 0vkyWjqLn1CxlLegVyhPrL
#
# 0vkyWjqLn1CxlLegVyhPrP
#
# 0vkyWjqLn1CxlLegVyhPrT
#
# 0vkyWjqLn1CxlLegVyhPrV
#
# 0vkyWjqLn1CxlLegVyhPr1
#
# 0vkyWjqLn1CxlLegVyhPr3
#
# 0vkyWjqLn1CxlLegVyhPr5
#
# 0vkyWjqLn1CxlLegVyhPr7
#
# 0vkyWjqLn1CxlLegVyhPr9
#
# 0vkyWjqLn1CxlLegVyhPrE
#
# 0vkyWjqLn1CxlLegVyhPrn
#
# 0vkyWjqLn1CxlLegVyhPrp
#
# 0vkyWjqLn1CxlLegVyhPrr
#
# 0vkyWjqLn1CxlLegVyhPrw
#
# 0vkyWjqLn1CxlLegVyhPrz
#
# 0vkyWjqLn1CxlLegVyhPr$
#
# 0vkyWjqLn1CxlLegVyhPrX
#
# 0vkyWjqLn1CxlLegVyhPrb
#
# 0vkyWjqLn1CxlLegVyhPrf
#
# 0vkyWjqLn1CxlLegVyhPrj
#
# 0vkyWjqLn1CxlLegVyhPqH
#
# 0vkyWjqLn1CxlLegVyhPqL
#
# 0vkyWjqLn1CxlLegVyhPqP
#
# 0vkyWjqLn1CxlLegVyhPqV
#
# 0vkyWjqLn1CxlLegVyhPq3
#
# 0vkyWjqLn1CxlLegVyhPq9
#
# 0vkyWjqLn1CxlLegVyhPqD
#
# 0vkyWjqLn1CxlLegVyhPqn
#
# 0vkyWjqLn1CxlLegVyhPqr
#
# 0vkyWjqLn1CxlLegVyhPqv
#
# 0vkyWjqLn1CxlLegVyhPqz
#
# 0vkyWjqLn1CxlLegVyhPqX
#
# 0vkyWjqLn1CxlLegVyhPqb
#
# 0vkyWjqLn1CxlLegVyhPqf
#
# 0vkyWjqLn1CxlLegVyhPqj
#
# 0vkyWjqLn1CxlLegVyhPql
#
# 0vkyWjqLn1CxlLegVyhOBH
#
# 0vkyWjqLn1CxlLegVyhOBK
#
# 0vkyWjqLn1CxlLegVyhOBM
#
# 0vkyWjqLn1CxlLegVyhOBP
#
# 0vkyWjqLn1CxlLegVyhOBR
#
# 0vkyWjqLn1CxlLegVyhOBT
#
# 0vkyWjqLn1CxlLegVyhOB2
#
# 0vkyWjqLn1CxlLegVyhOB6
#
# 0vkyWjqLn1CxlLegVyhOBC
#
# 0vkyWjqLn1CxlLegVyhOBn
#
# 0vkyWjqLn1CxlLegVyhOBs
#
# 0vkyWjqLn1CxlLegVyhOBu
#
# 0vkyWjqLn1CxlLegVyhOBw
#
# 0vkyWjqLn1CxlLegVyhOBz
#
# 0vkyWjqLn1CxlLegVyhOB$
#
# 0vkyWjqLn1CxlLegVyhOBY
#
# 0vkyWjqLn1CxlLegVyhOBa
#
# 0vkyWjqLn1CxlLegVyhOBg
#
# 0vkyWjqLn1CxlLegVyhOBj
#
# 0vkyWjqLn1CxlLegVyhOBl
#
# 0vkyWjqLn1CxlLegVyhOAM
#
# 0vkyWjqLn1CxlLegVyhOAO
#
# 0vkyWjqLn1CxlLegVyhOAR
#
# 0vkyWjqLn1CxlLegVyhOAV
#
# 0vkyWjqLn1CxlLegVyhOA3
#
# 0vkyWjqLn1CxlLegVyhOA7
#
# 0vkyWjqLn1CxlLegVyhOAB
#
# 0vkyWjqLn1CxlLegVyhOAF
#
# 0vkyWjqLn1CxlLegVyhOAn
#
# 0vkyWjqLn1CxlLegVyhOAp
#
# 0vkyWjqLn1CxlLegVyhOAr
#
# 0vkyWjqLn1CxlLegVyhOAt
#
# 0vkyWjqLn1CxlLegVyhOAv
#
# 0vkyWjqLn1CxlLegVyhOAx
#
# 0vkyWjqLn1CxlLegVyhO$h
#
# 0vkyWjqLn1CxlLegVyhO$j
#
# 0vkyWjqLn1CxlLegVyhO_G
#
# 0vkyWjqLn1CxlLegVyhO_I
#
# 0vkyWjqLn1CxlLegVyhO_L
#
# 0vkyWjqLn1CxlLegVyhO_N
#
# 0vkyWjqLn1CxlLegVyhO_P
#
# 0vkyWjqLn1CxlLegVyhO_R
#
# 0vkyWjqLn1CxlLegVyhO_T
#
# 0vkyWjqLn1CxlLegVyhO_V
#
# 0vkyWjqLn1CxlLegVyhO_1
#
# 0vkyWjqLn1CxlLegVyhO_3
#
# 0vkyWjqLn1CxlLegVyhO_5
#
# 0vkyWjqLn1CxlLegVyhO_7
#
# 0vkyWjqLn1CxlLegVyhO_9
#
# 0vkyWjqLn1CxlLegVyhO_D
#
# 0vkyWjqLn1CxlLegVyhO_m
#
# 0vkyWjqLn1CxlLegVyhO_p
#
# 0vkyWjqLn1CxlLegVyhO_r
#
# 0vkyWjqLn1CxlLegVyhO_u
#
# 0vkyWjqLn1CxlLegVyhO_x
#
# 0vkyWjqLn1CxlLegVyhO_z
#
# 0vkyWjqLn1CxlLegVyhO_$
#
# 0vkyWjqLn1CxlLegVyhO_X
#
# 0vkyWjqLn1CxlLegVyhO_Z
#
# 0vkyWjqLn1CxlLegVyhO_b
#
# 0vkyWjqLn1CxlLegVyhO_d
#
# 0vkyWjqLn1CxlLegVyhO_f
#
# 0vkyWjqLn1CxlLegVyhO_h
#
# 0vkyWjqLn1CxlLegVyhO_j
#
# 0vkyWjqLn1CxlLegVyhO_l
#
# 0vkyWjqLn1CxlLegVyhOzH
#
# 0vkyWjqLn1CxlLegVyhOzJ
#
# 0vkyWjqLn1CxlLegVyhOzL
#
# 0vkyWjqLn1CxlLegVyhOzN
#
# 0vkyWjqLn1CxlLegVyhOzP
#
# 0vkyWjqLn1CxlLegVyhOzS
#
# 0vkyWjqLn1CxlLegVyhOzU
#
# 0vkyWjqLn1CxlLegVyhOz1
#
# 0vkyWjqLn1CxlLegVyhOz3
#
# 0vkyWjqLn1CxlLegVyhOz6
#
# 0vkyWjqLn1CxlLegVyhOz8
#
# 0vkyWjqLn1CxlLegVyhOzA
#
# 0vkyWjqLn1CxlLegVyhOzC
#
# 0vkyWjqLn1CxlLegVyhOzE
#
# 0vkyWjqLn1CxlLegVyhOzm
#
# 0vkyWjqLn1CxlLegVyhOzp
#
# 0vkyWjqLn1CxlLegVyhOzr
#
# 0vkyWjqLn1CxlLegVyhOzu
#
# 0vkyWjqLn1CxlLegVyhOzw
#
# 0vkyWjqLn1CxlLegVyhOzy
#
# 0vkyWjqLn1CxlLegVyhOz$
#
# 0vkyWjqLn1CxlLegVyhOzX
#
# 0vkyWjqLn1CxlLegVyhOza
#
# 0vkyWjqLn1CxlLegVyhOzc
#
# 0vkyWjqLn1CxlLegVyhOze
#
# 0vkyWjqLn1CxlLegVyhOzi
#
# 0vkyWjqLn1CxlLegVyhOzk
#
# 0vkyWjqLn1CxlLegVyhOyG
#
# 0vkyWjqLn1CxlLegVyhOyI
#
# 0vkyWjqLn1CxlLegVyhOyK
#
# 0vkyWjqLn1CxlLegVyhOyM
#
# 0vkyWjqLn1CxlLegVyhOyP
#
# 0vkyWjqLn1CxlLegVyhOyR
#
# 0vkyWjqLn1CxlLegVyhOyT
#
# 0vkyWjqLn1CxlLegVyhOyV
#
# 0vkyWjqLn1CxlLegVyhOy4
#
# 0vkyWjqLn1CxlLegVyhOy8
#
# 0vkyWjqLn1CxlLegVyhOyA
#
# 0vkyWjqLn1CxlLegVyhOyC
#
# 0vkyWjqLn1CxlLegVyhOyF
#
# 0vkyWjqLn1CxlLegVyhOyn
#
# 0vkyWjqLn1CxlLegVyhOyp
#
# 0vkyWjqLn1CxlLegVyhOys
#
# 0vkyWjqLn1CxlLegVyhOyv
#
# 0vkyWjqLn1CxlLegVyhOyx
#
# 0vkyWjqLn1CxlLegVyhOyz
#
# 0vkyWjqLn1CxlLegVyhOy$
#
# 0vkyWjqLn1CxlLegVyhOyX
#
# 0vkyWjqLn1CxlLegVyhOyZ
#
# 0vkyWjqLn1CxlLegVyhOyb
#
# 0vkyWjqLn1CxlLegVyhOye
#
# 0vkyWjqLn1CxlLegVyhOyg
#
# 0vkyWjqLn1CxlLegVyhOyj
#
# 0vkyWjqLn1CxlLegVyhOpG
#
# 0vkyWjqLn1CxlLegVyhOpI
#
# 0vkyWjqLn1CxlLegVyhOpK
#
# 0vkyWjqLn1CxlLegVyhOpN
#
# 0vkyWjqLn1CxlLegVyhOpQ
#
# 0vkyWjqLn1CxlLegVyhOpS
#
# 0vkyWjqLn1CxlLegVyhOpU
#
# 0vkyWjqLn1CxlLegVyhOp2
#
# 0vkyWjqLn1CxlLegVyhOp6
#
# 0vkyWjqLn1CxlLegVyhOp8
#
# 0vkyWjqLn1CxlLegVyhOpA
#
# 0vkyWjqLn1CxlLegVyhOpC
#
# 0vkyWjqLn1CxlLegVyhOpF
#
# 0vkyWjqLn1CxlLegVyhOpn
#
# 0vkyWjqLn1CxlLegVyhOpp
#
# 0vkyWjqLn1CxlLegVyhOpr
#
# 0vkyWjqLn1CxlLegVyhOpu
#
# 0vkyWjqLn1CxlLegVyhOpw
#
# 0vkyWjqLn1CxlLegVyhOpy
#
# 0vkyWjqLn1CxlLegVyhOp_
#
# 0vkyWjqLn1CxlLegVyhOpX
#
# 0vkyWjqLn1CxlLegVyhOpa
#
# 0vkyWjqLn1CxlLegVyhOpc
#
# 0vkyWjqLn1CxlLegVyhOpe
#
# 0vkyWjqLn1CxlLegVyhOpg
#
# 0vkyWjqLn1CxlLegVyhR7t
#
# 0vkyWjqLn1CxlLegVyhR7x
#
# 0vkyWjqLn1CxlLegVyhR7$
#
# 0vkyWjqLn1CxlLegVyhR7Z
#
# 0vkyWjqLn1CxlLegVyhR7f
#
# 0vkyWjqLn1CxlLegVyhR7j
#
# 0vkyWjqLn1CxlLegVyhR6H
#
# 0vkyWjqLn1CxlLegVyhR6J
#
# 0vkyWjqLn1CxlLegVyhR6L
#
# 0vkyWjqLn1CxlLegVyhR6N
#
# 0vkyWjqLn1CxlLegVyhR6P
#
# 0vkyWjqLn1CxlLegVyhR6R
#
# 0vkyWjqLn1CxlLegVyhR6T
#
# 0vkyWjqLn1CxlLegVyhR6V
#
# 0vkyWjqLn1CxlLegVyhR62
#
# 0vkyWjqLn1CxlLegVyhR64
#
# 0vkyWjqLn1CxlLegVyhR66
#
# 0vkyWjqLn1CxlLegVyhR68
#
# 0vkyWjqLn1CxlLegVyhR6A
#
# 0vkyWjqLn1CxlLegVyhR6C
#
# 0vkyWjqLn1CxlLegVyhR6E
#
# 0vkyWjqLn1CxlLegVyhR6m
#
# 0vkyWjqLn1CxlLegVyhR6o
#
# 0vkyWjqLn1CxlLegVyhR6q
#
# 0vkyWjqLn1CxlLegVyhR6t
#
# 0vkyWjqLn1CxlLegVyhR6v
#
# 0vkyWjqLn1CxlLegVyhR6x
#
# 0vkyWjqLn1CxlLegVyhR6z
#
# 0vkyWjqLn1CxlLegVyhR6$
#
# 0vkyWjqLn1CxlLegVyhR6X
#
# 0vkyWjqLn1CxlLegVyhR6Z
#
# 0vkyWjqLn1CxlLegVyhR6b
#
# 0vkyWjqLn1CxlLegVyhR6d
#
# 0vkyWjqLn1CxlLegVyhR6f
#
# 0vkyWjqLn1CxlLegVyhR6i
#
# 0vkyWjqLn1CxlLegVyhR6k
#
# 0vkyWjqLn1CxlLegVyhR5H
#
# 0vkyWjqLn1CxlLegVyhR5J
#
# 0vkyWjqLn1CxlLegVyhR5M
#
# 0vkyWjqLn1CxlLegVyhR5O
#
# 0vkyWjqLn1CxlLegVyhR5Q
#
# 0vkyWjqLn1CxlLegVyhR5S
#
# 0vkyWjqLn1CxlLegVyhR5U
#
# 0vkyWjqLn1CxlLegVyhR50
#
# 0vkyWjqLn1CxlLegVyhR52
#
# 0vkyWjqLn1CxlLegVyhR54
#
# 0vkyWjqLn1CxlLegVyhR5A
#
# 0vkyWjqLn1CxlLegVyhR5E
#
# 0vkyWjqLn1CxlLegVyhR5m
#
# 0vkyWjqLn1CxlLegVyhR5t
#
# 0vkyWjqLn1CxlLegVyhR5x
#
# 0vkyWjqLn1CxlLegVyhR5$
#
# 0vkyWjqLn1CxlLegVyhR5Z
#
# 0vkyWjqLn1CxlLegVyhR5d
#
# 0vkyWjqLn1CxlLegVyhR5i
#
# 0vkyWjqLn1CxlLegVyhR4G
#
# 0vkyWjqLn1CxlLegVyhR4J
#
# 0vkyWjqLn1CxlLegVyhR4L
#
# 0vkyWjqLn1CxlLegVyhR4N
#
# 0vkyWjqLn1CxlLegVyhR4Q
#
# 0vkyWjqLn1CxlLegVyhR4S
#
# 0vkyWjqLn1CxlLegVyhR4V
#
# 0vkyWjqLn1CxlLegVyhR41
#
# 0vkyWjqLn1CxlLegVyhR46
#
# 0vkyWjqLn1CxlLegVyhR4A
#
# 0vkyWjqLn1CxlLegVyhR4E
#
# 0vkyWjqLn1CxlLegVyhR4o
#
# 0vkyWjqLn1CxlLegVyhR4q
#
# 0vkyWjqLn1CxlLegVyhR4s
#
# 0vkyWjqLn1CxlLegVyhR4u
#
# 0vkyWjqLn1CxlLegVyhR4x
#
# 0vkyWjqLn1CxlLegVyhR4z
#
# 0vkyWjqLn1CxlLegVyhR4W
#
# 0vkyWjqLn1CxlLegVyhR4a
#
# 0vkyWjqLn1CxlLegVyhR4g
#
# 0vkyWjqLn1CxlLegVyhR4l
#
# 0vkyWjqLn1CxlLegVyhRRJ
#
# 0vkyWjqLn1CxlLegVyhRRN
#
# 0vkyWjqLn1CxlLegVyhRRP
#
# 0vkyWjqLn1CxlLegVyhRRR
#
# 0vkyWjqLn1CxlLegVyhRRT
#
# 0vkyWjqLn1CxlLegVyhRR0
#
# 0vkyWjqLn1CxlLegVyhRR2
#
# 0vkyWjqLn1CxlLegVyhRR4
#
# 0vkyWjqLn1CxlLegVyhRR9
#
# 0vkyWjqLn1CxlLegVyhRRD
#
# 0vkyWjqLn1CxlLegVyhRRn
#
# 0vkyWjqLn1CxlLegVyhRRr
#
# 0vkyWjqLn1CxlLegVyhRRv
#
# 0vkyWjqLn1CxlLegVyhRRz
#
# 0vkyWjqLn1CxlLegVyhRRX
#
# 0vkyWjqLn1CxlLegVyhRRb
#
# 0vkyWjqLn1CxlLegVyhRRf
#
# 0vkyWjqLn1CxlLegVyhRRj
#
# 0vkyWjqLn1CxlLegVyhRQH
#
# 0vkyWjqLn1CxlLegVyhRQL
#
# 0vkyWjqLn1CxlLegVyhRQP
#
# 0vkyWjqLn1CxlLegVyhRQR
#
# 0vkyWjqLn1CxlLegVyhRQT
#
# 0vkyWjqLn1CxlLegVyhRQ0
#
# 0vkyWjqLn1CxlLegVyhRQ2
#
# 0vkyWjqLn1CxlLegVyhRQ4
#
# 0vkyWjqLn1CxlLegVyhRQ9
#
# 0vkyWjqLn1CxlLegVyhRQD
#
# 0vkyWjqLn1CxlLegVyhRQF
#
# 0vkyWjqLn1CxlLegVyhRQn
#
# 0vkyWjqLn1CxlLegVyhRQq
#
# 0vkyWjqLn1CxlLegVyhRQs
#
# 0vkyWjqLn1CxlLegVyhRQv
#
# 0vkyWjqLn1CxlLegVyhRQy
#
# 0vkyWjqLn1CxlLegVyhRQ_
#
# 0vkyWjqLn1CxlLegVyhRQW
#
# 0vkyWjqLn1CxlLegVyhRQY
#
# 0vkyWjqLn1CxlLegVyhRQb
#
# 0vkyWjqLn1CxlLegVyhRQe
#
# 0vkyWjqLn1CxlLegVyhRQg
#
# 0vkyWjqLn1CxlLegVyhRPG
#
# 0vkyWjqLn1CxlLegVyhRPK
#
# 0vkyWjqLn1CxlLegVyhRPM
#
# 0vkyWjqLn1CxlLegVyhRPO
#
# 0vkyWjqLn1CxlLegVyhRPS
#
# 0vkyWjqLn1CxlLegVyhRP0
#
# 2jO$d2Li5ECB0Bpfl6g$U2
#
# 2jO$d2Li5ECB0Bpfl6g$UU
#
# 2jO$d2Li5ECB0Bpfl6g$UQ
#
# 2jO$d2Li5ECB0Bpfl6g$UP
#
# 2jO$d2Li5ECB0Bpfl6g$UK
#
# 2jO$d2Li5ECB0Bpfl6g$UJ
#
# 2jO$d2Li5ECB0Bpfl6g$Vk
#
# 2jO$d2Li5ECB0Bpfl6g$Vg
#
# 2jO$d2Li5ECB0Bpfl6g$Vf
#
# 2jO$d2Li5ECB0Bpfl6g$Va
#
# 2jO$d2Li5ECB0Bpfl6g$VZ
#
# 2jO$d2Li5ECB0Bpfl6g$V_
#
# 2jO$d2Li5ECB0Bpfl6g$Vz
#
# 2jO$d2Li5ECB0Bpfl6g$Vu
#
# 2jO$d2Li5ECB0Bpfl6g$Vt
#
# 2jO$d2Li5ECB0Bpfl6g$Vo
#
# 2jO$d2Li5ECB0Bpfl6g$Vn
#
# 2jO$d2Li5ECB0Bpfl6g$VC
#
# 2jO$d2Li5ECB0Bpfl6g$VB
#
# 2jO$d2Li5ECB0Bpfl6g$V6
#
# 2jO$d2Li5ECB0Bpfl6g$V5
#
# 2jO$d2Li5ECB0Bpfl6g$V0
#
# 2jO$d2Li5ECB0Bpfl6g$VV
#
# 2jO$d2Li5ECB0Bpfl6g$VQ
#
# 2jO$d2Li5ECB0Bpfl6g$VP
#
# 2jO$d2Li5ECB0Bpfl6g$VK
#
# 2jO$d2Li5ECB0Bpfl6g$VJ
#
# 2jO$d2Li5ECB0Bpfl6g$Sl
#
# 2jO$d2Li5ECB0Bpfl6g$Sg
#
# 2jO$d2Li5ECB0Bpfl6g$Sf
#
# 2jO$d2Li5ECB0Bpfl6g$Sa
#
# 2jO$d2Li5ECB0Bpfl6g$SZ
#
# 2jO$d2Li5ECB0Bpfl6g$S_
#
# 2jO$d2Li5ECB0Bpfl6g$Sz
#
# 2jO$d2Li5ECB0Bpfl6g$Su
#
# 2jO$d2Li5ECB0Bpfl6g$St
#
# 2jO$d2Li5ECB0Bpfl6g$So
#
# 2jO$d2Li5ECB0Bpfl6g$Sn
#
# 2jO$d2Li5ECB0Bpfl6g$SC
#
# 2jO$d2Li5ECB0Bpfl6g$SB
#
# 2jO$d2Li5ECB0Bpfl6g$S6
#
# 2jO$d2Li5ECB0Bpfl6g$S5
#
# 2jO$d2Li5ECB0Bpfl6g$S0
#
# 2jO$d2Li5ECB0Bpfl6g$SV
#
# 2jO$d2Li5ECB0Bpfl6g$SQ
#
# 2jO$d2Li5ECB0Bpfl6g$SP
#
# 2jO$d2Li5ECB0Bpfl6g$SK
#
# 2jO$d2Li5ECB0Bpfl6g$SJ
#
# 2jO$d2Li5ECB0Bpfl6g$Ti
#
# 2jO$d2Li5ECB0Bpfl6g$Te
#
# 2jO$d2Li5ECB0Bpfl6g$Td
#
# 2R1y4oivn6hghSJG$FCYNF
#
# 2R1y4oivn6hghSJG$FCYNC
#
# 2R1y4oivn6hghSJG$FCYN1
#
# 2R1y4oivn6hghSJG$FCYN6
#
# 2R1y4oivn6hghSJG$FCYNR
#
# 2R1y4oivn6hghSJG$FCYNO
#
# 2R1y4oivn6hghSJG$FCYNT
#
# 2R1y4oivn6hghSJG$FCYNI
#
# 2R1y4oivn6hghSJG$FCYNN
#
# 2R1y4oivn6hghSJG$FCYNK
#
# 2R1y4oivn6hghSJG$FCYKf
#
# 2R1y4oivn6hghSJG$FCYKk
#
# 2R1y4oivn6hghSJG$FCYKZ
#
# 2R1y4oivn6hghSJG$FCYKW
#
# 2R1y4oivn6hghSJG$FCYKb
#
# 2R1y4oivn6hghSJG$FCYKw
#
# 2R1y4oivn6hghSJG$FCYK$
#
# 2R1y4oivn6hghSJG$FCYKy
#
# 2R1y4oivn6hghSJG$FCYKn
#
# 2R1y4oivn6hghSJG$FCYKs
#
# 2R1y4oivn6hghSJG$FCYKB
#
# 2R1y4oivn6hghSJG$FCYK8
#
# 2R1y4oivn6hghSJG$FCYKD
#
# 2R1y4oivn6hghSJG$FCYK1
#
# 2R1y4oivn6hghSJG$FCYK6
#
# 2R1y4oivn6hghSJG$FCYKR
#
# 2R1y4oivn6hghSJG$FCYKO
#
# 2R1y4oivn6hghSJG$FCYKT
#
# 2R1y4oivn6hghSJG$FCYKH
#
# 2R1y4oivn6hghSJG$FCYKM
#
# 2R1y4oivn6hghSJG$FCYLh
#
# 2R1y4oivn6hghSJG$FCYLe
#
# 2R1y4oivn6hghSJG$FCYLj
#
# 2R1y4oivn6hghSJG$FCYLY
#
# 2R1y4oivn6hghSJG$FCYLd
#
# 2R1y4oivn6hghSJG$FCYLa
#
# 2R1y4oivn6hghSJG$FCYLv
#
# 2R1y4oivn6hghSJG$FCYL_
#
# 2R1y4oivn6hghSJG$FCYLp
#
# 2R1y4oivn6hghSJG$FCYLm
#
# 2R1y4oivn6hghSJG$FCYLr
#
# 2R1y4oivn6hghSJG$FCYLA
#
# 2dwaBY7dL8M8AzW4i4MG4R
#
# 2dwaBY7dL8M8AzW4i4MG4r
#
# 2dwaBY7dL8M8AzW4i4MG3E
#
# 2dwaBY7dL8M8AzW4i4MG3C
#
# 2dwaBY7dL8M8AzW4i4MG3A
#
# 2dwaBY7dL8M8AzW4i4MG38
#
# 2dwaBY7dL8M8AzW4i4MG36
#
# 2dwaBY7dL8M8AzW4i4MG32
#
# 2dwaBY7dL8M8AzW4i4MG30
#
# 2dwaBY7dL8M8AzW4i4MG3_
#
# 2dwaBY7dL8M8AzW4i4MG3y
#
# 2dwaBY7dL8M8AzW4i4MG3w
#
# 2dwaBY7dL8M8AzW4i4MG2U
#
# 2dwaBY7dL8M8AzW4i4MG2S
#
# 2dwaBY7dL8M8AzW4i4MG2Q
#
# 2dwaBY7dL8M8AzW4i4MG2O
#
# 2dwaBY7dL8M8AzW4i4MG2M
#
# 2dwaBY7dL8M8AzW4i4MG2K
#
# 2dwaBY7dL8M8AzW4i4MG2G
#
# 2dwaBY7dL8M8AzW4i4MG2E
#
# 2dwaBY7dL8M8AzW4i4MG2C
#
# 2dwaBY7dL8M8AzW4i4MG2A
#
# 2dwaBY7dL8M8AzW4i4MG28
#
# 2dwaBY7dL8M8AzW4i4MG26
#
# 2dwaBY7dL8M8AzW4i4MG2q
#
# 2dwaBY7dL8M8AzW4i4MG2o
#
# 2dwaBY7dL8M8AzW4i4MG2m
#
# 2dwaBY7dL8M8AzW4i4MG2k
#
# 2dwaBY7dL8M8AzW4i4MG2i
#
# 2dwaBY7dL8M8AzW4i4MG2g
#
# 2dwaBY7dL8M8AzW4i4MG2c
#
# 2dwaBY7dL8M8AzW4i4MG2a
#
# 2dwaBY7dL8M8AzW4i4MG2Y
#
# 2dwaBY7dL8M8AzW4i4MG2W
#
# 2dwaBY7dL8M8AzW4i4MG1U
#
# 2dwaBY7dL8M8AzW4i4MG1S
#
# 2dwaBY7dL8M8AzW4i4MG12
#
# 2dwaBY7dL8M8AzW4i4MG10
#
# 2dwaBY7dL8M8AzW4i4MG1_
#
# 2dwaBY7dL8M8AzW4i4MG1y
#
# 2dwaBY7dL8M8AzW4i4MG1w
#
# 2dwaBY7dL8M8AzW4i4MG1u
#
# 2dwaBY7dL8M8AzW4i4MG1q
#
# 2dwaBY7dL8M8AzW4i4MG1o
#
# 2dwaBY7dL8M8AzW4i4MG1m
#
# 2dwaBY7dL8M8AzW4i4MG1k
#
# 2dwaBY7dL8M8AzW4i4MG1i
#
# 2dwaBY7dL8M8AzW4i4MG1g
#
# 2dwaBY7dL8M8AzW4i4MGFi
#
# 2dwaBY7dL8M8AzW4i4MGFg
#
# 2dwaBY7dL8M8AzW4i4MGFe
#
# 2dwaBY7dL8M8AzW4i4MGFc
#
# 2dwaBY7dL8M8AzW4i4MGFa
#
# 2dwaBY7dL8M8AzW4i4MGFY
#
# 2dwaBY7dL8M8AzW4i4MGFW
#
# 2dwaBY7dL8M8AzW4i4MGEU
#
# 2dwaBY7dL8M8AzW4i4MGES
#
# 2dwaBY7dL8M8AzW4i4MGEQ
#
# 2dwaBY7dL8M8AzW4i4MGEM
#
# 2dwaBY7dL8M8AzW4i4MGEK
#
# 2dwaBY7dL8M8AzW4i4MGEI
#
# 2dwaBY7dL8M8AzW4i4MGEG
#
# 2dwaBY7dL8M8AzW4i4MGEE
#
# 2dwaBY7dL8M8AzW4i4MGEC
#
# 2dwaBY7dL8M8AzW4i4MGEA
#
# 2dwaBY7dL8M8AzW4i4MGE8
#
# 2dwaBY7dL8M8AzW4i4MGE6
#
# 2dwaBY7dL8M8AzW4i4MGE4
#
# 2dwaBY7dL8M8AzW4i4MGE2
#
# 2dwaBY7dL8M8AzW4i4MGE0
#
# 2dwaBY7dL8M8AzW4i4MGDv
#
# 2dwaBY7dL8M8AzW4i4MGDt
#
# 2dwaBY7dL8M8AzW4i4MGDr
#
# 2dwaBY7dL8M8AzW4i4MGDp
#
# 2dwaBY7dL8M8AzW4i4MGDn
#
# 2dwaBY7dL8M8AzW4i4MGDl
#
# 2dwaBY7dL8M8AzW4i4MGDj
#
# 2dwaBY7dL8M8AzW4i4MGDh
#
# 2dwaBY7dL8M8AzW4i4MGDf
#
# 2dwaBY7dL8M8AzW4i4MGDd
#
# 2dwaBY7dL8M8AzW4i4MGDb
#
# 2dwaBY7dL8M8AzW4i4MGDZ
#
# 2dwaBY7dL8M8AzW4i4MGDX
#
# 2dwaBY7dL8M8AzW4i4MGCV
#
# 2dwaBY7dL8M8AzW4i4MGCT
#
# 2dwaBY7dL8M8AzW4i4MGCR
#
# 2dwaBY7dL8M8AzW4i4MGCP
#
# 2dwaBY7dL8M8AzW4i4MGCN
#
# 2dwaBY7dL8M8AzW4i4MGCL
#
# 2dwaBY7dL8M8AzW4i4MGCJ
#
# 2dwaBY7dL8M8AzW4i4MGCH
#
# 2dwaBY7dL8M8AzW4i4MGCF
#
# 2dwaBY7dL8M8AzW4i4MGCD
#
# 2dwaBY7dL8M8AzW4i4MGCB
#
# 2dwaBY7dL8M8AzW4i4MGC9
#
# 2dwaBY7dL8M8AzW4i4MGC7
#
# 2dwaBY7dL8M8AzW4i4MGC5
#
# 2dwaBY7dL8M8AzW4i4MGC3
#
# 2dwaBY7dL8M8AzW4i4MGC1
#
# 2dwaBY7dL8M8AzW4i4MGC$
#
# 2dwaBY7dL8M8AzW4i4MGCz
#
# 2dwaBY7dL8M8AzW4i4MGCx
#
# 2dwaBY7dL8M8AzW4i4MGCv
#
# 2dwaBY7dL8M8AzW4i4MGCt
#
# 2dwaBY7dL8M8AzW4i4MGCq
#
# 2dwaBY7dL8M8AzW4i4MGCo
#
# 2dwaBY7dL8M8AzW4i4MGCm
#
# 2dwaBY7dL8M8AzW4i4MGCk
#
# 2dwaBY7dL8M8AzW4i4MGCi
#
# 2dwaBY7dL8M8AzW4i4MGCg
#
# 2dwaBY7dL8M8AzW4i4MGCe
#
# 2dwaBY7dL8M8AzW4i4MGCc
#
# 2dwaBY7dL8M8AzW4i4MGCa
#
# 2dwaBY7dL8M8AzW4i4MGCY
#
# 2dwaBY7dL8M8AzW4i4MGCW
#
# 2dwaBY7dL8M8AzW4i4MGBU
#
# 2dwaBY7dL8M8AzW4i4MGBS
#
# 2dwaBY7dL8M8AzW4i4MGBQ
#
# 2dwaBY7dL8M8AzW4i4MGBO
#
# 2dwaBY7dL8M8AzW4i4MGBM
#
# 2dwaBY7dL8M8AzW4i4MGBK
#
# 2dwaBY7dL8M8AzW4i4MGBI
#
# 2dwaBY7dL8M8AzW4i4MGBG
#
# 2dwaBY7dL8M8AzW4i4MGBE
#
# 2dwaBY7dL8M8AzW4i4MGBC
#
# 2dwaBY7dL8M8AzW4i4MGBA
#
# 2dwaBY7dL8M8AzW4i4MGB8
#
# 2dwaBY7dL8M8AzW4i4MGB6
#
# 2dwaBY7dL8M8AzW4i4MGB4
#
# 2dwaBY7dL8M8AzW4i4MGB2
#
# 2dwaBY7dL8M8AzW4i4MGB0
#
# 2dwaBY7dL8M8AzW4i4MGB_
#
# 2dwaBY7dL8M8AzW4i4MGBy
#
# 2dwaBY7dL8M8AzW4i4MGBw
#
# 2dwaBY7dL8M8AzW4i4MGBu
#
# 2dwaBY7dL8M8AzW4i4MGBs
#
# 2dwaBY7dL8M8AzW4i4MGBq
#
# 2dwaBY7dL8M8AzW4i4MGBo
#
# 2dwaBY7dL8M8AzW4i4MGBm
#
# 2dwaBY7dL8M8AzW4i4MGBk
#
# 2dwaBY7dL8M8AzW4i4MG9y
#
# 2dwaBY7dL8M8AzW4i4MG9a
#
# 2dwaBY7dL8M8AzW4i4MG9Y
#
# 2dwaBY7dL8M8AzW4i4MG8t
#
# 2dwaBY7dL8M8AzW4i4MG8r
#
# 2dwaBY7dL8M8AzW4i4MGND
#
# 2dwaBY7dL8M8AzW4i4MGNB
#
# 2dwaBY7dL8M8AzW4i4MGN9
#
# 2dwaBY7dL8M8AzW4i4MGN7
#
# 2dwaBY7dL8M8AzW4i4MGN5
#
# 2dwaBY7dL8M8AzW4i4MGN3
#
# 2dwaBY7dL8M8AzW4i4MGN1
#
# 2dwaBY7dL8M8AzW4i4MGN$
#
# 2dwaBY7dL8M8AzW4i4MGNz
#
# 2dwaBY7dL8M8AzW4i4MGNx
#
# 2dwaBY7dL8M8AzW4i4MGNv
#
# 2dwaBY7dL8M8AzW4i4MGNt
#
# 2dwaBY7dL8M8AzW4i4MGNr
#
# 2dwaBY7dL8M8AzW4i4MGNp
#
# 2dwaBY7dL8M8AzW4i4MGNn
#
# 2dwaBY7dL8M8AzW4i4MGNk
#
# 2dwaBY7dL8M8AzW4i4MGNi
#
# 2dwaBY7dL8M8AzW4i4MGNg
#
# 2dwaBY7dL8M8AzW4i4MGNe
#
# 2dwaBY7dL8M8AzW4i4MGNc
#
# 2dwaBY7dL8M8AzW4i4MGNa
#
# 2dwaBY7dL8M8AzW4i4MGNX
#
# 2dwaBY7dL8M8AzW4i4MGMV
#
# 2dwaBY7dL8M8AzW4i4MGMT
#
# 2dwaBY7dL8M8AzW4i4MGMR
#
# 2dwaBY7dL8M8AzW4i4MGMP
#
# 2dwaBY7dL8M8AzW4i4MGMN
#
# 2dwaBY7dL8M8AzW4i4MGML
#
# 2dwaBY7dL8M8AzW4i4MGMJ
#
# 2dwaBY7dL8M8AzW4i4MGMH
#
# 2dwaBY7dL8M8AzW4i4MGMF
#
# 2dwaBY7dL8M8AzW4i4MGMD
#
# 2dwaBY7dL8M8AzW4i4MGMB
#
# 2dwaBY7dL8M8AzW4i4MGM9
#
# 2dwaBY7dL8M8AzW4i4MGM7
#
# 2dwaBY7dL8M8AzW4i4MGM5
#
# 2dwaBY7dL8M8AzW4i4MGM3
#
# 2dwaBY7dL8M8AzW4i4MGM1
#
# 2dwaBY7dL8M8AzW4i4MGM$
#
# 2dwaBY7dL8M8AzW4i4MGMz

# %% [raw]
# ########### APAGAR
#
#
# ######### PENDENCIA
# # 1. Acrescentar tipo de elemento, para categorizar pilares circulares
#
# # dicionário para armazenar as quantidades dos elementos
# dict_quantitativo = {
#     "pavimento": [],
#     "junta": [],
#     "elemento": [],
#     "codigo": [],
#     "comprimento (cm)": [],
#     "largura (cm)": [],
#     "altura (cm)": [],
#     "área (m²)": [],
#     "volume (m³)": [],
#     "ID": [],
# }
#
# # remove as classes tipos e pavimento
# classe_a_remover = ["IfcBeamType", "IfcColumnType", "IfcBuildingStorey"]
# classes_unicas = [classe for classe in classes_unicas if classe not in classe_a_remover]
#
# # pega as classes IFC que tem no arquivo
# for classe in classes_unicas:
#     elementos = model.by_type(classe)
#     for elemento in elementos:
#         # propriedades e quantidades da classe IFC
#         psets_and_qtos = ifcopenshell.util.element.get_psets(elemento)
#
#         # verifica se existe a propriedades Cotas e se existe volume
#         if 'Cotas' in psets_and_qtos and "Volume" in psets_and_qtos["Cotas"]:
#             pavimento = ifcopenshell.util.element.get_container(elemento)[2]
#             junta = psets_and_qtos["My_Data"]['Junta']
#
#             # iteração sobre os elementos estruturais e verifica os seus tipos
#             if classe == "IfcSlab":
#                 if psets_and_qtos["Dados de identidade"]["Titulo"] == "CORTINA":
#                     dict_quantitativo["pavimento"].append(pavimento)
#                     dict_quantitativo["junta"].append(junta)
#                     dict_quantitativo["elemento"].append("Cortina")
#                     dict_quantitativo["codigo"].append(psets_and_qtos["Dados de identidade"]["Titulo"])
#                     dict_quantitativo["comprimento (cm)"].append("")
#                     dict_quantitativo["largura (cm)"].append("")
#                     dict_quantitativo["altura (cm)"].append("")
#                     dict_quantitativo["área (m²)"].append(psets_and_qtos["Cotas"]["Área"])
#                     dict_quantitativo["volume (m³)"].append(psets_and_qtos["Cotas"]["Volume"])
#                     dict_quantitativo["ID"].append(elemento.GlobalId)
#                 else:
#                     dict_quantitativo["pavimento"].append(pavimento)
#                     dict_quantitativo["junta"].append(junta)
#                     dict_quantitativo["elemento"].append(psets_and_qtos["Dados de identidade"]["Tipo Elemento"])
#                     dict_quantitativo["codigo"].append(psets_and_qtos["Dados de identidade"]["Titulo"])
#                     dict_quantitativo["comprimento (cm)"].append("")
#                     dict_quantitativo["largura (cm)"].append("")
#                     dict_quantitativo["altura (cm)"].append("")
#                     dict_quantitativo["área (m²)"].append(psets_and_qtos["Cotas"]["Área"])
#                     dict_quantitativo["volume (m³)"].append(psets_and_qtos["Cotas"]["Volume"])
#                     dict_quantitativo["ID"].append(elemento.GlobalId)
#
#             elif classe == "IfcBeam":
#                 dict_quantitativo["pavimento"].append(pavimento)
#                 dict_quantitativo["junta"].append(junta)
#                 dict_quantitativo["elemento"].append(psets_and_qtos["Dados de identidade"]["Tipo Elemento"])
#                 dict_quantitativo["codigo"].append(psets_and_qtos["Dados de identidade"]["Titulo"])
#                 dict_quantitativo["comprimento (cm)"].append(psets_and_qtos["Qto_BeamBaseQuantities"]["Length"])
#                 dict_quantitativo["largura (cm)"].append(psets_and_qtos["Dados"]["Largura_cm"])
#                 dict_quantitativo["altura (cm)"].append(psets_and_qtos["Dados"]["Altura_cm"])
#                 dict_quantitativo["área (m²)"].append("")
#                 dict_quantitativo["volume (m³)"].append(psets_and_qtos["Cotas"]["Volume"])
#                 dict_quantitativo["ID"].append(elemento.GlobalId)
#
#             elif classe == "IfcColumn":
#                 if psets_and_qtos["Dados"]["Secao"].startswith("R"):
#                     dict_quantitativo["pavimento"].append(pavimento)
#                     dict_quantitativo["junta"].append(junta)
#                     dict_quantitativo["elemento"].append(psets_and_qtos["Dados de identidade"]["Tipo Elemento"])
#                     dict_quantitativo["codigo"].append(psets_and_qtos["Dados de identidade"]["Titulo"])
#                     dict_quantitativo["comprimento (cm)"].append(psets_and_qtos["Cotas"]["Comprimento"])
#                     dict_quantitativo["largura (cm)"].append(psets_and_qtos["Dados"]["Largura_cm"])
#                     dict_quantitativo["altura (cm)"].append(psets_and_qtos["Dados"]["Altura_cm"])
#                     dict_quantitativo["área (m²)"].append("")
#                     dict_quantitativo["volume (m³)"].append(psets_and_qtos["Cotas"]["Volume"])
#                     dict_quantitativo["ID"].append(elemento.GlobalId)
#
#                 else:
#                     dict_quantitativo["pavimento"].append(pavimento)
#                     dict_quantitativo["junta"].append(junta)
#                     dict_quantitativo["elemento"].append(psets_and_qtos["Dados de identidade"]["Tipo Elemento"])
#                     dict_quantitativo["codigo"].append(psets_and_qtos["Dados de identidade"]["Titulo"])
#                     dict_quantitativo["comprimento (cm)"].append(psets_and_qtos["Cotas"]["Comprimento"])
#                     dict_quantitativo["largura (cm)"].append(psets_and_qtos["Pset_QuantityTakeOff"]["Reference"])
#                     dict_quantitativo["altura (cm)"].append("")
#                     dict_quantitativo["área (m²)"].append("")
#                     dict_quantitativo["volume (m³)"].append(psets_and_qtos["Cotas"]["Volume"])
#                     dict_quantitativo["ID"].append(elemento.GlobalId)
#
#             elif classe == "IfcWallStandardCase":
#                 dict_quantitativo["pavimento"].append(pavimento)
#                 dict_quantitativo["junta"].append(junta)
#                 dict_quantitativo["codigo"].append("")
#                 dict_quantitativo["comprimento (cm)"].append("")
#                 dict_quantitativo["largura (cm)"].append("")
#                 dict_quantitativo["altura (cm)"].append("")
#                 dict_quantitativo["elemento"].append("Cortina")
#                 dict_quantitativo["área (m²)"].append(psets_and_qtos["Cotas"]["Área"])
#                 dict_quantitativo["volume (m³)"].append(psets_and_qtos["Cotas"]["Volume"])
#                 dict_quantitativo["ID"].append(elemento.GlobalId)
#
#             else:
#                 print(classe)
#                 print(elemento.GlobalId)
#                 print("classe não considerada")
#
#         elif 'Cotas' in psets_and_qtos and "Volume" not in psets_and_qtos["Cotas"]:
#             print(classe)
#             print("erro de modelagem GlobalId: ", elemento.GlobalId)
#
# df_quantitativo = pd.DataFrame(dict_quantitativo)

# %%
df_quantitativo
# Out:
#      pavimento    junta elemento tipo codigo comprimento (cm) largura (cm)  \
# 0     Fundacao  Junta D  Cortina                   522.421316         25.0
# 1     Fundacao  Junta D  Cortina                       1511.5         19.0
# 2     Fundacao  Junta D  Cortina                        709.0         19.0
# 3     Fundacao  Junta D  Cortina                  3301.004362         19.0
# 4     Fundacao  Junta B  Cortina                  5002.997283         19.0
# ...        ...      ...      ...  ...    ...              ...          ...
# 1621  Fundacao  Junta F    Pilar        P606             60.0         19.0
# 1622  Fundacao  Junta F    Pilar        P602             60.0         60.0
# 1623  Fundacao  Junta F    Pilar        P605             60.0         60.0
# 1624  Fundacao  Junta F    Pilar        P603             60.0         60.0
# 1625  Fundacao  Junta F    Pilar        P604             60.0         60.0
#
#      altura (cm)   área (m²)  volume (m³)                GlobalID
# 0          480.0   25.076223     6.269056  0$TvfvQWT3UPXp$fNe6P3J
# 1          480.0      72.552    13.784880  0$TvfvQWT3UPXp$fNe6P2Q
# 2          480.0      34.032     6.466080  0$TvfvQWT3UPXp$fNe6P0F
# 3          480.0  158.448209    30.105160  0$TvfvQWT3UPXp$fNe6PV9
# 4          480.0   240.14387    45.627335  0$TvfvQWT3UPXp$fNe6Ond
# ...          ...         ...          ...                     ...
# 1621        60.0       0.632     0.045600  2dwaBY7dL8M8AzW4i4MGM5
# 1622        19.0       0.632     0.045600  2dwaBY7dL8M8AzW4i4MGM3
# 1623        19.0       0.632     0.045600  2dwaBY7dL8M8AzW4i4MGM1
# 1624        19.0       0.632     0.045600  2dwaBY7dL8M8AzW4i4MGM$
# 1625        19.0       0.632     0.045600  2dwaBY7dL8M8AzW4i4MGMz
#
# [1626 rows x 11 columns]

# %%
# todos os elementos não descritos abaixo terão a área de forma igual a área calculada pelo IFC
df_quantitativo["área de forma (m²)"] = df_quantitativo["área (m²)"]

elementos = df_quantitativo["elemento"].unique()
for elemento in elementos:
    # quando cortina, multiplica por 2 para ter a área das 2 faces da parede
    if elemento == "Cortina":
        df_quantitativo.loc[df_quantitativo["elemento"] == elemento, "área de forma (m²)"] = df_quantitativo.loc[df_quantitativo["elemento"] == elemento, "área de forma (m²)"] * 2
    # quando é laje em solo não tem forma
    elif elemento == "Laje":
        df_quantitativo.loc[(df_quantitativo["pavimento"] == "Fundacao") & (df_quantitativo["elemento"] == "Laje"), "área de forma (m²)"] = 0
    # quando viga, multiplica os lados para ter a área de forma estimada
    elif elemento == "Viga":
        viga_mask = df_quantitativo["elemento"] == "Viga"
        L = df_quantitativo.loc[viga_mask, "comprimento (cm)"] / 100
        B = df_quantitativo.loc[viga_mask, "largura (cm)"] / 100
        H = df_quantitativo.loc[viga_mask, "altura (cm)"] / 100
        df_quantitativo.loc[viga_mask, "área de forma (m²)"] = L * B + L * H * 2

# %%
df_quantitativo.to_excel("EST-lista de materiais.xlsx")

# %% [markdown]
# ## IFC REVIT - ARQ

# %%
FILE_PATH = "./modelo/789-ARQ-PE-XXX-MOD-GER-XX-MODELO_IFC_____-R13-IFC4.ifc"
model = ifcopenshell.open(FILE_PATH)

# %%
# Classes IFC
classes_unicas = set()
for entidade in model:
    classes_unicas.add(entidade.is_a())

# %%
classes_unicas
# Out:
# {'IfcActorRole',
#  'IfcApplication',
#  'IfcArbitraryClosedProfileDef',
#  'IfcArbitraryProfileDefWithVoids',
#  'IfcAxis2Placement2D',
#  'IfcAxis2Placement3D',
#  'IfcBeam',
#  'IfcBeamType',
#  'IfcBooleanClippingResult',
#  'IfcBuilding',
#  'IfcBuildingElementProxy',
#  'IfcBuildingElementProxyType',
#  'IfcBuildingStorey',
#  'IfcCartesianPoint',
#  'IfcCartesianTransformationOperator3D',
#  'IfcCircle',
#  'IfcCircleProfileDef',
#  'IfcClassification',
#  'IfcClassificationReference',
#  'IfcClosedShell',
#  'IfcColourRgb',
#  'IfcColumn',
#  'IfcColumnType',
#  'IfcCompositeCurve',
#  'IfcCompositeCurveSegment',
#  'IfcConnectedFaceSet',
#  'IfcConversionBasedUnit',
#  'IfcCovering',
#  'IfcCoveringType',
#  'IfcCurtainWall',
#  'IfcCurtainWallType',
#  'IfcDerivedUnit',
#  'IfcDerivedUnitElement',
#  'IfcDimensionalExponents',
#  'IfcDirection',
#  'IfcDistributionPort',
#  'IfcDoor',
#  'IfcDoorLiningProperties',
#  'IfcDoorPanelProperties',
#  'IfcDoorStyle',
#  'IfcElementAssembly',
#  'IfcElementQuantity',
#  'IfcExtrudedAreaSolid',
#  'IfcFace',
#  'IfcFaceBasedSurfaceModel',
#  'IfcFaceBound',
#  'IfcFaceOuterBound',
#  'IfcFacetedBrep',
#  'IfcFlowTerminal',
#  'IfcFurnishingElement',
#  'IfcFurnitureType',
#  'IfcGeometricRepresentationContext',
#  'IfcGeometricRepresentationSubContext',
#  'IfcGeometricSet',
#  'IfcGroup',
#  'IfcHalfSpaceSolid',
#  'IfcLocalPlacement',
#  'IfcMappedItem',
#  'IfcMaterial',
#  'IfcMaterialDefinitionRepresentation',
#  'IfcMaterialLayer',
#  'IfcMaterialLayerSet',
#  'IfcMaterialLayerSetUsage',
#  'IfcMaterialList',
#  'IfcMeasureWithUnit',
#  'IfcMember',
#  'IfcMemberType',
#  'IfcOpeningElement',
#  'IfcOrganization',
#  'IfcOwnerHistory',
#  'IfcPerson',
#  'IfcPersonAndOrganization',
#  'IfcPlane',
#  'IfcPlate',
#  'IfcPlateType',
#  'IfcPolyLoop',
#  'IfcPolygonalBoundedHalfSpace',
#  'IfcPolyline',
#  'IfcPostalAddress',
#  'IfcPresentationLayerAssignment',
#  'IfcPresentationStyleAssignment',
#  'IfcProductDefinitionShape',
#  'IfcProject',
#  'IfcPropertySet',
#  'IfcPropertySingleValue',
#  'IfcQuantityArea',
#  'IfcQuantityLength',
#  'IfcQuantityVolume',
#  'IfcRailing',
#  'IfcRamp',
#  'IfcRampFlight',
#  'IfcRectangleProfileDef',
#  'IfcRelAggregates',
#  'IfcRelAssignsToGroup',
#  'IfcRelAssociatesClassification',
#  'IfcRelAssociatesMaterial',
#  'IfcRelConnectsPathElements',
#  'IfcRelConnectsPortToElement',
#  'IfcRelContainedInSpatialStructure',
#  'IfcRelDefinesByProperties',
#  'IfcRelDefinesByType',
#  'IfcRelFillsElement',
#  'IfcRelVoidsElement',
#  'IfcRepresentationMap',
#  'IfcRoof',
#  'IfcSIUnit',
#  'IfcShapeRepresentation',
#  'IfcSite',
#  'IfcSlab',
#  'IfcSlabType',
#  'IfcSpace',
#  'IfcStair',
#  'IfcStairFlight',
#  'IfcStyledItem',
#  'IfcStyledRepresentation',
#  'IfcSurfaceStyle',
#  'IfcSurfaceStyleRendering',
#  'IfcTelecomAddress',
#  'IfcTrimmedCurve',
#  'IfcUnitAssignment',
#  'IfcWall',
#  'IfcWallStandardCase',
#  'IfcWallType',
#  'IfcWindow',
#  'IfcWindowLiningProperties',
#  'IfcWindowStyle'}

# %%
elemento = model.by_type("IfcWall")[0]

# %%
elemento.ObjectType
# Out:
# 'Parede básica:ACABAMENTO_SECO_20mm_01'

# %%
ifcopenshell.util.element.get_psets(elemento)
# Out:
# {'Pset_QuantityTakeOff': {'Reference': 'ACABAMENTO_SECO_20mm_01',
#   'id': 1391908},
#  'Pset_ReinforcementBarPitchOfWall': {'Reference': 'ACABAMENTO_SECO_20mm_01',
#   'id': 1420018},
#  'Pset_WallCommon': {'IsExternal': False,
#   'Reference': 'ACABAMENTO_SECO_20mm_01',
#   'id': 1391906,
#   'LoadBearing': False,
#   'ExtendToStructure': False},
#  'Qto_WallBaseQuantities': {'GrossSideArea': 4.38900000000004,
#   'GrossVolume': 0.0877800000000188,
#   'Height': 3.85,
#   'Length': 1.14000000000001,
#   'NetSideArea': 4.21800000000004,
#   'NetVolume': 0.0843600000000181,
#   'Width': 0.0200000000000041,
#   'id': 1656143}}

# %% [raw]
# # dicionário para armazenar as quantidades dos elementos
# dict_quantitativo = {
#     "classe": [],
#     "pavimento": [],
#     "junta": [],
#     "elemento": [],
#     "codigo": [],
#     "comprimento (m)": [],
#     "largura (m)": [],
#     "altura (m)": [],
#     "perimetro (m)": [],
#     "área (m²)": [],
#     "volume (m³)": [],
#     "GlobalID": [],
# }
#
# # classes filtradas
# classes = ["IfcWall", "IfcWallStandardCase", "IfcSlab"]
#
# # função para adicionar os elementos no dicionário
# def add_element_to_dict(classe, pavimento, junta, elemento, codigo, comprimento, largura, altura, perimetro, area, volume, global_id):
#     dict_quantitativo["classe"].append(classe)
#     dict_quantitativo["pavimento"].append(pavimento)
#     dict_quantitativo["junta"].append(junta)
#     dict_quantitativo["elemento"].append(elemento)
#     dict_quantitativo["codigo"].append(codigo)
#     dict_quantitativo["comprimento (m)"].append(comprimento)
#     dict_quantitativo["largura (m)"].append(largura)
#     dict_quantitativo["altura (m)"].append(altura)
#     dict_quantitativo["perimetro (m)"].append(perimetro)
#     dict_quantitativo["área (m²)"].append(area)
#     dict_quantitativo["volume (m³)"].append(volume)
#     dict_quantitativo["GlobalID"].append(global_id)
#
# # mapemaneto dos parâmetros de cada uma das classes para o dicionário
# class_handlers = {
#     "IfcWall": lambda psets_and_qtos, classe, pavimento, junta: (
#         (psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
#          "",
#          psets_and_qtos["Qto_WallBaseQuantities"]["Length"],
#          psets_and_qtos["Qto_WallBaseQuantities"]["Width"],
#          psets_and_qtos["Qto_WallBaseQuantities"]["Height"],
#          "",
#          psets_and_qtos["Qto_WallBaseQuantities"]["NetSideArea"],
#          psets_and_qtos["Qto_WallBaseQuantities"]["NetVolume"])
#     ),
#     "IfcWallStandardCase": lambda psets_and_qtos, classe, pavimento, junta: (
#         (psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
#          "",
#          psets_and_qtos["Qto_WallBaseQuantities"]["Length"],
#          psets_and_qtos["Qto_WallBaseQuantities"]["Width"],
#          psets_and_qtos["Qto_WallBaseQuantities"]["Height"],
#          "",
#          psets_and_qtos["Qto_WallBaseQuantities"]["NetSideArea"],
#          psets_and_qtos["Qto_WallBaseQuantities"]["NetVolume"])
#     ),
#     "IfcSlab": lambda psets_and_qtos, classe, pavimento, junta: (
#         (psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
#          "",
#          "",
#          "",
#          psets_and_qtos["Qto_SlabBaseQuantities"]["Depth"],
#          psets_and_qtos["Qto_SlabBaseQuantities"]["Perimeter"],
#          psets_and_qtos["Qto_SlabBaseQuantities"]["NetArea"],
#          psets_and_qtos["Qto_SlabBaseQuantities"]["NetVolume"])
#     ),
# }
#
# # Processa os elementos
# for classe in classes:
#     elementos = model.by_type(classe)
#     for elemento in elementos:
#         psets_and_qtos = ifcopenshell.util.element.get_psets(elemento)
#         if ifcopenshell.util.element.get_container(elemento) and ifcopenshell.util.element.get_psets(elemento, qtos_only=True): #'Qto_WallBaseQuantities' in psets_and_qtos and "NetVolume" in psets_and_qtos["Qto_WallBaseQuantities"]:
#             pavimento = ifcopenshell.util.element.get_container(elemento)[2]
#             junta = "GERAL"
#             handler = class_handlers.get(classe)
#             results = handler(psets_and_qtos, classe, pavimento, junta)
#             add_element_to_dict(classe, pavimento, junta, *results, elemento.GlobalId)
#
#
# df_quantitativo = pd.DataFrame(dict_quantitativo)

# %%
# dicionário para armazenar as quantidades dos elementos
dict_quantitativo = {
    "classe": [],
    "pavimento": [],
    "junta": [],
    "elemento": [],
    "codigo": [],
    "comprimento (m)": [],
    "largura (m)": [],
    "altura (m)": [],
    "perimetro (m)": [],
    "área (m²)": [],
    "volume (m³)": [],
    "GlobalID": [],
}

# função para adicionar os elementos no dicionário
def add_element_to_dict(classe, pavimento, junta, elemento, codigo, comprimento, largura, altura, perimetro, area, volume, global_id):
    dict_quantitativo["classe"].append(classe)
    dict_quantitativo["pavimento"].append(pavimento)
    dict_quantitativo["junta"].append(junta)
    dict_quantitativo["elemento"].append(elemento)
    dict_quantitativo["codigo"].append(codigo)
    dict_quantitativo["comprimento (m)"].append(comprimento)
    dict_quantitativo["largura (m)"].append(largura)
    dict_quantitativo["altura (m)"].append(altura)
    dict_quantitativo["perimetro (m)"].append(perimetro)
    dict_quantitativo["área (m²)"].append(area)
    dict_quantitativo["volume (m³)"].append(volume)
    dict_quantitativo["GlobalID"].append(global_id)

# mapemaneto dos parâmetros de cada uma das classes para o dicionário
class_handlers = {
    "IfcWall": lambda psets_and_qtos, classe, pavimento, junta: (
        (psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
         "",
         psets_and_qtos["Qto_WallBaseQuantities"]["Length"],
         psets_and_qtos["Qto_WallBaseQuantities"]["Width"],
         psets_and_qtos["Qto_WallBaseQuantities"]["Height"],
         "",
         psets_and_qtos["Qto_WallBaseQuantities"]["NetSideArea"],
         psets_and_qtos["Qto_WallBaseQuantities"]["NetVolume"])
    ),
    "IfcWallStandardCase": lambda psets_and_qtos, classe, pavimento, junta: (
        (psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
         "",
         psets_and_qtos["Qto_WallBaseQuantities"]["Length"],
         psets_and_qtos["Qto_WallBaseQuantities"]["Width"],
         psets_and_qtos["Qto_WallBaseQuantities"]["Height"],
         "",
         psets_and_qtos["Qto_WallBaseQuantities"]["NetSideArea"],
         psets_and_qtos["Qto_WallBaseQuantities"]["NetVolume"])
    ),
    "IfcSlab": lambda psets_and_qtos, classe, pavimento, junta: (
        (psets_and_qtos["Pset_QuantityTakeOff"]["Reference"],
         "",
         "",
         "",
         psets_and_qtos["Qto_SlabBaseQuantities"]["Depth"],
         psets_and_qtos["Qto_SlabBaseQuantities"]["Perimeter"],         
         psets_and_qtos["Qto_SlabBaseQuantities"]["NetArea"],
         psets_and_qtos["Qto_SlabBaseQuantities"]["NetVolume"])
    ),        
}

# Processa os elementos
elementos = ifcopenshell.util.selector.filter_elements(model, "IfcElement")
for elemento in elementos:
    if ifcopenshell.util.element.get_container(elemento) and ifcopenshell.util.element.get_psets(elemento, qtos_only=True):
        classe = elemento.is_a()
        psets_and_qtos = ifcopenshell.util.element.get_psets(elemento)
        pavimento = ifcopenshell.util.element.get_container(elemento)[2]
        junta = "GERAL"
        handler = class_handlers.get(classe)
    
        if handler:
            results = handler(psets_and_qtos, classe, pavimento, junta)
            add_element_to_dict(classe, pavimento, junta, *results, elemento.GlobalId)
    
        else:
            print(f"Classe não considerada: {classe}, GlobalId: {elemento.GlobalId}")

df_quantitativo = pd.DataFrame(dict_quantitativo)
# Out:
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$nv
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_EQ
# Classe não considerada: IfcMember, GlobalId: 249YOfh35Fwhe4TbOrg$ja
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIFG
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKww
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_2M
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ee2
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_7t
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHWP
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONX$i
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmV_
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqnmqI
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnm7d
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_7c
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0I2
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehPU9
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzdi
# Classe não considerada: IfcPlate, GlobalId: 3wLHDG7s98RuaNklONpbkT
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrgC
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$n7
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQTs
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrA6
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_7u
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHW2
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONX$h
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrv0
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_3j
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmre
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGgQ
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntm2
# Classe não considerada: IfcMember, GlobalId: 0bC52ZHCzEX8D8CPBOSGe8
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONX$O
# Classe não considerada: IfcColumn, GlobalId: 0wKT$GLMLBfvNhbnx7fEIL
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQU0
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnm78
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrAM
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpH$9
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fwf
# Classe não considerada: IfcPlate, GlobalId: 2$$pw1mJn1E9MmPiRW6hiU
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HG6
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmtp
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmKT
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIKw
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrCk
# Classe não considerada: IfcPlate, GlobalId: 0RSWh65sv7Y8HKEnRj2oxJ
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGrH
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQIyn
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcr_s
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ee7
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnty4
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrLp
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONX$Y
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntoq
# Classe não considerada: IfcMember, GlobalId: 0PLpgCR1f6JBcd_odgd9oQ
# Classe não considerada: IfcPlate, GlobalId: 2PWn_p2Ir7EvtkgXQmQIzT
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$eeS
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXylV
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIJS
# Classe não considerada: IfcMember, GlobalId: 062UEHKDbCz8yJTIoBr5o9
# Classe não considerada: IfcMember, GlobalId: 0oAY_KD7n9VeRmvbPB6VXt
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHxe
# Classe não considerada: IfcMember, GlobalId: 1WCYZBl5L5$8ahIgjUnlN6
# Classe não considerada: IfcMember, GlobalId: 1Ok6y5wwHEWOKQHxuQZLuq
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt$F
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHx6
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqV8
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmqo
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92IoC
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHyz
# Classe não considerada: IfcMember, GlobalId: 1Z0LZeNrX3r8AuVcJip$8k
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr8t
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGqW
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr7s
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2oxm
# Classe não considerada: IfcMember, GlobalId: 0wHtsR$lb1K91EBpSL6jlF
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIHU
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHz6
# Classe não considerada: IfcPlate, GlobalId: 07JwA$xdz1c95eH4$1W0Jp
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0IT
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrxR
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrx0
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQTj
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92Iah
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFEMN
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI90
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQIyt
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$efq
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKzZ
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyj1
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHzF
# Classe não considerada: IfcPlate, GlobalId: 07JwA$xdz1c95eH4$1W0JU
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KKej
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQJ5
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnm7m
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lzm
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI9h
# Classe não considerada: IfcMember, GlobalId: 2Ypwj6Jsb3KArW8EAfT8sV
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92InY
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHoy
# Classe não considerada: IfcPlate, GlobalId: 1Z0LZeNrX3r8AuVcJip$8O
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehMaP
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrxL
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrxz
# Classe não considerada: IfcPlate, GlobalId: 1CLgykRJLCFA$skNKxIQJh
# Classe não considerada: IfcPlate, GlobalId: 2wk9U5gBD0QR0GDRrUc4Jv
# Classe não considerada: IfcMember, GlobalId: 062UEHKDbCz8yJTIoBrAjV
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyu8
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHxa
# Classe não considerada: IfcMember, GlobalId: 1Z0LZeNrX3r8AuVcJip$8y
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKzc
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KL3_
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGii
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmps
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONXZB
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$pC
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyuF
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrTu
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lz_
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrC$
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7a9
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92IZj
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzdM
# Classe não considerada: IfcMember, GlobalId: 1WCYZBl5L5$8ahIgjUnlNF
# Classe não considerada: IfcMember, GlobalId: 0T34JiWc9BZQC2Bd4LHdcO
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KL4j
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyuM
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_7i
# Classe não considerada: IfcMember, GlobalId: 0eXQTFhY95fBavGlcbsA4S
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfx$
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0Jt
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfu7
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI9g
# Classe não considerada: IfcPlate, GlobalId: 0zvP7Q3Pj8f9m$FZwMNKzW
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONXZv
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_6L
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_3x
# Classe não considerada: IfcMember, GlobalId: 0eXQTFhY95fBavGlcbsA4R
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGYi
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0JE
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzdY
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIka4h
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrDe
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmph
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyuS
# Classe não considerada: IfcPlate, GlobalId: 1eQH5USUnDIOGM5UETzupm
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQIyL
# Classe não considerada: IfcMember, GlobalId: 2fY36_sk58juZZX8q8ZC0B
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmUF
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGYb
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0J1
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGoM
# Classe não considerada: IfcMember, GlobalId: 3CxiD_Mm9Fj91PH3ubdx8A
# Classe não considerada: IfcColumn, GlobalId: 1joGBEqi5DvQ8CN9wcXy$N
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnmnh
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHWs
# Classe não considerada: IfcMember, GlobalId: 0Cil9oXXz8UA37f90WVBUM
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrD6
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGcA
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkao0
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqntmJ
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQVS
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmu2
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhvv_e
# Classe não considerada: IfcStairFlight, GlobalId: 0rMiBVJhD4qfTjyMM7EkkY
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqnmvQ
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnmn$
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt$Y
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQYz
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqnmsI
# Classe não considerada: IfcMember, GlobalId: 1eQH5USUnDIOGM5UETzupa
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQIzA
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQZT
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvJQ
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHZV
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqV$
# Classe não considerada: IfcPlate, GlobalId: 2$$pw1mJn1E9MmPiRW6hiM
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHic
# Classe não considerada: IfcMember, GlobalId: 2ID58ffTLEYPYK14Vl99mL
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGoz
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmvl
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_r3
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHpfF
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHi_
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhvv_y
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmqj
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIJB
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvKk
# Classe não considerada: IfcPlate, GlobalId: 2$55uK$oPCK86Z2mSq9lI7
# Classe não considerada: IfcMember, GlobalId: 1kd6lnhlL958MqVp82ZHJF
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGqN
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQXe
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr7n
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_6E
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHW0
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHzL
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvKY
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8F
# Classe não considerada: IfcPlate, GlobalId: 2PfOAqdHTEkeSFt3zvJoP_
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHzU
# Classe não considerada: IfcPlate, GlobalId: 2$$pw1mJn1E9MmPiRW6eJI
# Classe não considerada: IfcMember, GlobalId: 3hq9_SdynA7fFQWHOtoJdl
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHwT
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGqJ
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VqT
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_rd
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGio
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lyk
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfxX
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfxD
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntnm
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$0
# Classe não considerada: IfcPlate, GlobalId: 1Z0LZeNrX3r8AuVcJip$8f
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fWL
# Classe não considerada: IfcPlate, GlobalId: 2$55uK$oPCK86Z2mSq9lsw
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrrt
# Classe não considerada: IfcMember, GlobalId: 3bMhcuwnfDDPOzh3faOBia
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfxr
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrB8
# Classe não considerada: IfcPlate, GlobalId: 1YfvkLSdbFgOT$6RTc6fZj
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_rx
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrTr
# Classe não considerada: IfcCovering, GlobalId: 1dc14_vnnDcxGGCoBnYpB2
# Classe não considerada: IfcPlate, GlobalId: 3tYyyNKFT9S8HlU2QbAV6F
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIKR
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfxh
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$py
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrAy
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrTa
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQYN
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzc6
# Classe não considerada: IfcMember, GlobalId: 3wLHDG7s98RuaNklONpbli
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_sp
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrCC
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHke
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHpgw
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$mG
# Classe não considerada: IfcPlate, GlobalId: 3CE51L9p13OPsSiRQ4KL43
# Classe não considerada: IfcPlate, GlobalId: 2seDFdsuX8RQl3EZIIkaVn
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_sq
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmKJ
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGZY
# Classe não considerada: IfcPlate, GlobalId: 3uHTTQS71AzBNlbFbH5Whi
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQXY
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHjz
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fdJ
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQYr
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrBQ
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGok
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_sz
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrSX
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGZI
# Classe não considerada: IfcMember, GlobalId: 062UEHKDbCz8yJTIoBrAtn
# Classe não considerada: IfcPlate, GlobalId: 3CE51L9p13OPsSiRQ4KL4G
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fa_
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fII5
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQZb
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrBL
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr9N
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQX4
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrT8
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGZB
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGp4
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyWa
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrD1
# Classe não considerada: IfcMember, GlobalId: 3N7AQpHRv5zxcGRQ2xwje2
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fbh
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIIz
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0Ja
# Classe não considerada: IfcPlate, GlobalId: 062UEHKDbCz8yJTIoBr5LQ
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQXq
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr6u
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHZL
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4SqnmpB
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyWY
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFDBJ
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$ek_
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7bw
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr6p
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHpS
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXy$v
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fI0U
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4SqntzT
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI0b
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFDBQ
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_69
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHzr
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fwk
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$yw
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXydK
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_EA
# Classe não considerada: IfcPlate, GlobalId: 0RSWh65sv7Y8HKEnRj2oyr
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrBA
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQY5
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntyh
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7b_
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VqP
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFDB1
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMeS
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXy$7
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHwi
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehMdb
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmSC
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQYa
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_67
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHlb
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHZ9
# Classe não considerada: IfcMember, GlobalId: 2qAXTMAQP2iP4kXQxFhFCu
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_E5
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONX_E
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONX_K
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7bn
# Classe não considerada: IfcPlate, GlobalId: 1YfvkLSdbFgOT$6RTc6fa8
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXy$D
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$o_
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIKI
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$elj
# Classe não considerada: IfcColumn, GlobalId: 1joGBEqi5DvQ8CN9wcX$tp
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_6T
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpH$S
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2LzP
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzbw
# Classe não considerada: IfcMember, GlobalId: 2SypDrroL56B3KVCpdDVWT
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmvc
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fbJ
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmtF
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHlj
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$o4
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr47
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGZf
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIKr
# Classe não considerada: IfcMember, GlobalId: 2U9ReMyWP7WwKyaD5gCi79
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnm76
# Classe não considerada: IfcMember, GlobalId: 0DipRizRzFp8Y1tHlQo1B5
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmsB
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$ef4
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHu5
# Classe não considerada: IfcMember, GlobalId: 3wLHDG7s98RuaNklONpbk7
# Classe não considerada: IfcMember, GlobalId: 2PfOAqdHTEkeSFt3zvJoPE
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGY3
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpGy$
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmt8
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGgC
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrgM
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VXf
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhvv$O
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqntz9
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHwC
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmvw
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RsZK
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHe1
# Classe não considerada: IfcStairFlight, GlobalId: 2p$HJS5l95RuDr_WRKDZMF
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_3e
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrT2
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHu9
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGg5
# Classe não considerada: IfcPlate, GlobalId: 0eXQTFhY95fBavGlcbsA5I
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONX_N
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqUT
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIHo
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HGO
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ejr
# Classe não considerada: IfcMember, GlobalId: 0wHtsR$lb1K91EBpSL6jlU
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2LzI
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHoL
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrHS
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQJE
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQIm
# Classe não considerada: IfcMember, GlobalId: 2$55uK$oPCK86Z2mSq9lHt
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGh8
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcr$5
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_3c
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2owM
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmpv
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr79
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqntqL
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrCS
# Classe não considerada: IfcMember, GlobalId: 1Z0LZeNrX3r8AuVcJip$9C
# Classe não considerada: IfcMember, GlobalId: 1WCYZBl5L5$8ahIgjUnlIK
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ejN
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HGK
# Classe não considerada: IfcMember, GlobalId: 0wHtsR$lb1K91EBpSL6jlT
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFENm
# Classe não considerada: IfcPlate, GlobalId: 3uHTTQS71AzBNlbFbH5Whg
# Classe não considerada: IfcMember, GlobalId: 1svAuT25P0K8o9R3MHEXMI
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmVa
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKzf
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmUU
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr9n
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr6Y
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyZs
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehMa8
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8E
# Classe não considerada: IfcPlate, GlobalId: 1Z0LZeNrX3r8AuVcJip$8U
# Classe não considerada: IfcMember, GlobalId: 1kd6lnhlL958MqVp82ZHJ0
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrx5
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ekg
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIIr
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFEN$
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr81
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntqe
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvKP
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQJ1
# Classe não considerada: IfcMember, GlobalId: 2ID58ffTLEYPYK14Vl99my
# Classe não considerada: IfcMember, GlobalId: 1WCYZBl5L5$8ahIgjUnlN4
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqS7
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPPY
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr9g
# Classe não considerada: IfcPlate, GlobalId: 1YfvkLSdbFgOT$6RTc6fYG
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyc3
# Classe não considerada: IfcPlate, GlobalId: 0Ng8dZrar0PgNMp_56Rq6q
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHnZ
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkaDj
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyc6
# Classe não considerada: IfcMember, GlobalId: 2F5L0qSf134fOVidzmBMfZ
# Classe não considerada: IfcMember, GlobalId: 0KBvHBLBf0BuNltKk5OEKi
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzc_
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHnm
# Classe não considerada: IfcMember, GlobalId: 12kS8_$$D2UxPz9$UsNfqK
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7aT
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56Rq4b
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyc9
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$p3
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ekZ
# Classe não considerada: IfcMember, GlobalId: 2F5L0qSf134fOVidzmBMfg
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPP$
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpG$i
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGoR
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrCm
# Classe não considerada: IfcMember, GlobalId: 1eQH5USUnDIOGM5UETzupD
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnm7I
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzdA
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8l
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXycN
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$p9
# Classe não considerada: IfcMember, GlobalId: 0eXQTFhY95fBavGlcbsA4M
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIFL
# Classe não considerada: IfcPlate, GlobalId: 07JwA$xdz1c95eH4$1W0It
# Classe não considerada: IfcMember, GlobalId: 2WHfxP4kDAHAk$EI6Fkk4V
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI8Q
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrCt
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpJEv
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPUH
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnmp3
# Classe não considerada: IfcMember, GlobalId: 0dOCb5nbP2v8wByvXzBrmJ
# Classe não considerada: IfcMember, GlobalId: 3N7AQpHRv5zxcGRQ2xwjhX
# Classe não considerada: IfcMember, GlobalId: 0eXQTFhY95fBavGlcbsA5j
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQZ6
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzd6
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7aB
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhvv_m
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$no
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIKX
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrrW
# Classe não considerada: IfcMember, GlobalId: 2PfOAqdHTEkeSFt3zvJo66
# Classe não considerada: IfcMember, GlobalId: 2OvcoRUPH7DgGk6LQR6L1I
# Classe não considerada: IfcMember, GlobalId: 0eXQTFhY95fBavGlcbsA5a
# Classe não considerada: IfcMember, GlobalId: 0Cil9oXXz8UA37f90WVBSg
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkaVD
# Classe não considerada: IfcPlate, GlobalId: 0zvP7Q3Pj8f9m$FZwMNKzr
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvOv
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2L_R
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQVH
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONXZH
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr71
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrrz
# Classe não considerada: IfcMember, GlobalId: 1ohEZRjFzFARKIJGznHcUx
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONXZX
# Classe não considerada: IfcPlate, GlobalId: 07JwA$xdz1c95eH4$1W0J5
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehPUx
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_3h
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhvv_E
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGqr
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHv_
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQVM
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIKb
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnmnd
# Classe não considerada: IfcMember, GlobalId: 2U9ReMyWP7WwKyaD5gCiM9
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RsZP
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4SqnmnZ
# Classe não considerada: IfcMember, GlobalId: 1emKrYj$b4_hQ2q6p0FXh9
# Classe não considerada: IfcPlate, GlobalId: 0Cil9oXXz8UA37f90WVBU2
# Classe não considerada: IfcCovering, GlobalId: 2Nfhm6zub5iBagvCAW$JWU
# Classe não considerada: IfcPlate, GlobalId: 0Cil9oXXz8UA37f90WVBUx
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$efl
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4SqnmoZ
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnto0
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGqo
# Classe não considerada: IfcPlate, GlobalId: 3FqrN3TdrBxOShHBqONXZR
# Classe não considerada: IfcPlate, GlobalId: 3wLHDG7s98RuaNklONpblq
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQWE
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr6y
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcr_f
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHeE
# Classe não considerada: IfcPlate, GlobalId: 18GVTiO_b0IxKvQRqLI0n4
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqS6
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_3X
# Classe não considerada: IfcPlate, GlobalId: 1bCNDUrrDFxekHK5d6JIej
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0Je
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHzj
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIKZ
# Classe não considerada: IfcMember, GlobalId: 0oAY_KD7n9VeRmvbPB6VXF
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqntmP
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr7j
# Classe não considerada: IfcPlate, GlobalId: 1CLgykRJLCFA$skNKxIQJS
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnmnr
# Classe não considerada: IfcPlate, GlobalId: 249YOfh35Fwhe4TbOrg$WU
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$eeG
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyjN
# Classe não considerada: IfcColumn, GlobalId: 0wKT$GLMLBfvNhbnx7fEIN
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt_l
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$eew
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQIu
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGt5
# Classe não considerada: IfcPlate, GlobalId: 3Yntl042jAKxCHjoljpw7T
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56Rq7M
# Classe não considerada: IfcPlate, GlobalId: 2PfOAqdHTEkeSFt3zvJoPs
# Classe não considerada: IfcStairFlight, GlobalId: 12V$GhoTz0hhZIMDhYHaPO
# Classe não considerada: IfcMember, GlobalId: 2OvcoRUPH7DgGk6LQR6LNn
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt$U
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyjE
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvKa
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrwz
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HVz
# Classe não considerada: IfcPlate, GlobalId: 1bCNDUrrDFxekHK5d6JIea
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrA1
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrwH
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKwT
# Classe não considerada: IfcMember, GlobalId: 1Z0LZeNrX3r8AuVcJip$8b
# Classe não considerada: IfcPlate, GlobalId: 1YfvkLSdbFgOT$6RTc6fZ0
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92Ios
# Classe não considerada: IfcPlate, GlobalId: 2OvcoRUPH7DgGk6LQR6LDS
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92Inm
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92HU7
# Classe não considerada: IfcMember, GlobalId: 2$$pw1mJn1E9MmPiRW6eQy
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$5
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0Jd
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHuI
# Classe não considerada: IfcMember, GlobalId: 2OvcoRUPH7DgGk6LQR6LPo
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrTp
# Classe não considerada: IfcMember, GlobalId: 2$$pw1mJn1E9MmPiRW6eKn
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHo4
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7a1
# Classe não considerada: IfcMember, GlobalId: 1WCYZBl5L5$8ahIgjUnlN3
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56Rq4g
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92Inv
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92HUC
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$Q
# Classe não considerada: IfcPlate, GlobalId: 2seDFdsuX8RQl3EZIIkaDB
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KL4g
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyvW
# Classe não considerada: IfcPlate, GlobalId: 3tYyyNKFT9S8HlU2QbAV6C
# Classe não considerada: IfcCovering, GlobalId: 2Nfhm6zub5iBagvCAW$JWz
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fILk
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGY_
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQXv
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpJEk
# Classe não considerada: IfcMember, GlobalId: 3Yntl042jAKxCHjoljpw7Q
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KKex
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrBh
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrxM
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHoh
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrIK
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrDP
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI9v
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fILv
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGYt
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KKfl
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrs8
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHu0
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyvk
# Classe não considerada: IfcPlate, GlobalId: 2fY36_sk58juZZX8q8ZC0i
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrDC
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrBZ
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fILE
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzH$J
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqnmsE
# Classe não considerada: IfcPlate, GlobalId: 0zvP7Q3Pj8f9m$FZwMNKzO
# Classe não considerada: IfcPlate, GlobalId: 12kS8_$$D2UxPz9$UsNfuR
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHm55
# Classe não considerada: IfcMember, GlobalId: 0eXQTFhY95fBavGlcbsA5_
# Classe não considerada: IfcMember, GlobalId: 2$55uK$oPCK86Z2mSq9lBd
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQZp
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrsH
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrCj
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr9C
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KKem
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMfK
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_sY
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI9$
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8f
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_sh
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrCc
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHlp
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHkZ
# Classe não considerada: IfcMember, GlobalId: 0dOCb5nbP2v8wByvXzBro0
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQWO
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvK8
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMe7
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQH7H
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPP9
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvzV
# Classe não considerada: IfcMember, GlobalId: 3tYyyNKFT9S8HlU2QbAV79
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQWH
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2owx
# Classe não considerada: IfcMember, GlobalId: 0zvP7Q3Pj8f9m$FZwMNKz3
# Classe não considerada: IfcMember, GlobalId: 2tkK3GEWDFZPpYiFctBA9r
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIJ0
# Classe não considerada: IfcMember, GlobalId: 3tYyyNKFT9S8HlU2QbAV7H
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7bt
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQXJ
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_r8
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmre
# Classe não considerada: IfcPlate, GlobalId: 0Ng8dZrar0PgNMp_56Rq7q
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54NhvvzM
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGpl
# Classe não considerada: IfcMember, GlobalId: 3tYyyNKFT9S8HlU2QbAV7P
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8v
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqnmrH
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQH7J
# Classe não considerada: IfcMember, GlobalId: 0zvP7Q3Pj8f9m$FZwMNKz0
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntmj
# Classe não considerada: IfcMember, GlobalId: 1ohEZRjFzFARKIJGznHcUm
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_r6
# Classe não considerada: IfcPlate, GlobalId: 0Ng8dZrar0PgNMp_56RqU3
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56Rq4G
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmut
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntmg
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4SqntzN
# Classe não considerada: IfcPlate, GlobalId: 2$55uK$oPCK86Z2mSq9lI9
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHjf
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$y7
# Classe não considerada: IfcPlate, GlobalId: 2PfOAqdHTEkeSFt3zvJo61
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92HUo
# Classe não considerada: IfcPlate, GlobalId: 3bMhcuwnfDDPOzh3faOBic
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt$f
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmGJ
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqUM
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpG$M
# Classe não considerada: IfcPlate, GlobalId: 0dOCb5nbP2v8wByvXzBriz
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXy$0
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$f
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmVo
# Classe não considerada: IfcMember, GlobalId: 1emKrYj$b4_hQ2q6p0FXh$
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONX_7
# Classe não considerada: IfcPlate, GlobalId: 0RSWh65sv7Y8HKEnRj2ow1
# Classe não considerada: IfcMember, GlobalId: 062UEHKDbCz8yJTIoBrAqZ
# Classe não considerada: IfcPlate, GlobalId: 2$55uK$oPCK86Z2mSq9lI5
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$yD
# Classe não considerada: IfcPlate, GlobalId: 0dOCb5nbP2v8wByvXzBrmY
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzba
# Classe não considerada: IfcPlate, GlobalId: 2PfOAqdHTEkeSFt3zvJoPI
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fILT
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGfw
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$o
# Classe não considerada: IfcMember, GlobalId: 3wLHDG7s98RuaNklONpblL
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHuM
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehMdk
# Classe não considerada: IfcMember, GlobalId: 1svAuT25P0K8o9R3MHEXP0
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehMdA
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VqQ
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHpeU
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkaDX
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQX6
# Classe não considerada: IfcPlate, GlobalId: 2$55uK$oPCK86Z2mSq9lIJ
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HVW
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGyr
# Classe não considerada: IfcMember, GlobalId: 2PfOAqdHTEkeSFt3zvJoP3
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGfp
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkaDQ
# Classe não considerada: IfcMember, GlobalId: 1svAuT25P0K8o9R3MHEXPB
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpH$E
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fWR
# Classe não considerada: IfcPlate, GlobalId: 3wLHDG7s98RuaNklONpbkS
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr9M
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzbm
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrH9
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvKR
# Classe não considerada: IfcMember, GlobalId: 3wLHDG7s98RuaNklONpbbv
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr6h
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHWU
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkadU
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HVd
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2LzH
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvLj
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr94
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmtd
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrH6
# Classe não considerada: IfcPlate, GlobalId: 2seDFdsuX8RQl3EZIIkaV0
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KL45
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VXT
# Classe não considerada: IfcPlate, GlobalId: 1CLgykRJLCFA$skNKxIQJV
# Classe não considerada: IfcCovering, GlobalId: 1ktfzpY95EmuhcNWdLmAQ2
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzcC
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvKM
# Classe não considerada: IfcPlate, GlobalId: 2ID58ffTLEYPYK14Vl99no
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lzv
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnm7g
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehMaL
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HV_
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fZt
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_rQ
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHYM
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntmw
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHuD
# Classe não considerada: IfcMember, GlobalId: 2OvcoRUPH7DgGk6LQR6LDO
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzH$E
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VX2
# Classe não considerada: IfcPlate, GlobalId: 12kS8_$$D2UxPz9$UsNfqS
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$ekw
# ...
# Classe não considerada: IfcMember, GlobalId: 2OvcoRUPH7DgGk6LQR6LPl
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI9_
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzHo7
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7a4
# Classe não considerada: IfcMember, GlobalId: 2PfOAqdHTEkeSFt3zvJo6a
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92Iny
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92HU3
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKzw
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$L
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr8R
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQId
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_34
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGXA
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fI9X
# Classe não considerada: IfcMember, GlobalId: 2rbEtlxbb2y9$PwhqMJgSs
# Classe não considerada: IfcMember, GlobalId: 1CLgykRJLCFA$skNKxIQIg
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KL4z
# Classe não considerada: IfcPlate, GlobalId: 12kS8_$$D2UxPz9$UsNfuQ
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrDQ
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fILo
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGYw
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGrS
# Classe não considerada: IfcMember, GlobalId: 1WCYZBl5L5$8ahIgjUnlJI
# Classe não considerada: IfcPlate, GlobalId: 0eXQTFhY95fBavGlcbsA5E
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fI98
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIAc
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrBa
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrDH
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPPc
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIL2
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KL3s
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56Rq4t
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQZs
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmsf
# Classe não considerada: IfcPlate, GlobalId: 3CE51L9p13OPsSiRQ4KL4V
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02RrD8
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr8G
# Classe não considerada: IfcMember, GlobalId: 3CE51L9p13OPsSiRQ4KKei
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0IX
# Classe não considerada: IfcPlate, GlobalId: 1YfvkLSdbFgOT$6RTc6fZh
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQZJ
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehMdB
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_r0
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQa2
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4SqnmoT
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_sc
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKwm
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIka3K
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhvv_c
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqntzh
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIJk
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7bd
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQW7
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHvu
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMe3
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQH7j
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPPF
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56RqVL
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGo$
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXydJ
# Classe não considerada: IfcMember, GlobalId: 0p$neDhdjDlRg2vhTvPAHJ
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_rU
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQWS
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGh6
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_qL
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2owu
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGhu
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr6M
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMfx
# Classe não considerada: IfcMember, GlobalId: 0LYqlXswT9mB8LHQL_yKw5
# Classe não considerada: IfcPlate, GlobalId: 0zvP7Q3Pj8f9m$FZwMNKzT
# Classe não considerada: IfcPlate, GlobalId: 3bMhcuwnfDDPOzh3faOBir
# Classe não considerada: IfcCovering, GlobalId: 1ALxoIuKP2UfEP5egp1aZ$
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGrl
# Classe não considerada: IfcMember, GlobalId: 3tYyyNKFT9S8HlU2QbAV7L
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQXQ
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMeM
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_6S
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnmrl
# Classe não considerada: IfcMember, GlobalId: 0Ng8dZrar0PgNMp_56Rq4d
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrg$
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXydP
# Classe não considerada: IfcMember, GlobalId: 1O_PnHqafFtByp_05EvEeD
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehMaK
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrBv
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehMdn
# Classe não considerada: IfcColumn, GlobalId: 1joGBEqi5DvQ8CN9wcXy_X
# Classe não considerada: IfcMember, GlobalId: 3tYyyNKFT9S8HlU2QbAV7S
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnms2
# Classe não considerada: IfcMember, GlobalId: 2h$gjL33198vIIuysvIQXN
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8q
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqnmrK
# Classe não considerada: IfcPlate, GlobalId: 0oAY_KD7n9VeRmvbPB6VqI
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHpeX
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_rf
# Classe não considerada: IfcMember, GlobalId: 062UEHKDbCz8yJTIoBrAqj
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHiH
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGoY
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$elp
# Classe não considerada: IfcPlate, GlobalId: 0eXQTFhY95fBavGlcbsA5D
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_Ew
# Classe não considerada: IfcColumn, GlobalId: 3Uy4mARMn94A1wNWeU50F7
# Classe não considerada: IfcPlate, GlobalId: 0Ng8dZrar0PgNMp_56RqUt
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpG$N
# Classe não considerada: IfcPlate, GlobalId: 33_v3Hr296PeGA45nkcrgr
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzbq
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHpM
# Classe não considerada: IfcMember, GlobalId: 1JYovp3LDCZvzIn69T483J
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHpen
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_rz
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntmf
# Classe não considerada: IfcMember, GlobalId: 2PWn_p2Ir7EvtkgXQmQIyY
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92HUn
# Classe não considerada: IfcPlate, GlobalId: 2PfOAqdHTEkeSFt3zvJoPL
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lwx
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$o3
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_Em
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehMd9
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpG$K
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzc0
# Classe não considerada: IfcMember, GlobalId: 2rbEtlxbb2y9$PwhqMJgSw
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr4I
# Classe não considerada: IfcMember, GlobalId: 02HADy6Dv5VR_4Mnv92HUx
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpHYe
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$a
# Classe não considerada: IfcMember, GlobalId: 3FqrN3TdrBxOShHBqONX_4
# Classe não considerada: IfcMember, GlobalId: 1emKrYj$b4_hQ2q6p0FXh8
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fWP
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HVi
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkaea
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$eeR
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fILP
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGfv
# Classe não considerada: IfcPlate, GlobalId: 1TIPEEGiTDHfOn2mFyx7bL
# Classe não considerada: IfcMember, GlobalId: 1TIPEEGiTDHfOn2mFyx7aF
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIJK
# Classe não considerada: IfcMember, GlobalId: 1Gs5i5M4X33ROCw6razS6u
# Classe não considerada: IfcMember, GlobalId: 2y5234X9b6m8_LMP3Oqdni
# Classe não considerada: IfcMember, GlobalId: 3LgwrbT6P2NQzosXIWzH$j
# Classe não considerada: IfcMember, GlobalId: 1svAuT25P0K8o9R3MHEXPT
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGfs
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHuC
# Classe não considerada: IfcMember, GlobalId: 1svAuT25P0K8o9R3MHEXP4
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkaEi
# Classe não considerada: IfcMember, GlobalId: 3wLHDG7s98RuaNklONpblH
# Classe não considerada: IfcMember, GlobalId: 0YXKqSAvr8IgfKN$KPwrrb
# Classe não considerada: IfcPlate, GlobalId: 2$55uK$oPCK86Z2mSq9ls_
# Classe não considerada: IfcPlate, GlobalId: 02HADy6Dv5VR_4Mnv92HGM
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr8Y
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrHC
# Classe não considerada: IfcMember, GlobalId: 0VNi8vdcDCmuCa27XONRm0
# Classe não considerada: IfcMember, GlobalId: 1O_PnHqafFtByp_05EvFz1
# Classe não considerada: IfcMember, GlobalId: 1guvs5$yv9FRpyX5o$dGgm
# Classe não considerada: IfcMember, GlobalId: 2seDFdsuX8RQl3EZIIkadI
# Classe não considerada: IfcMember, GlobalId: 062UEHKDbCz8yJTIoBrAts
# Classe não considerada: IfcCovering, GlobalId: 02MgZBIKPCyhWD8eVSgfTl
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvLe
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr99
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQWI
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrH5
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQUM
# Classe não considerada: IfcPlate, GlobalId: 0UFhjKWVn2RRSWFvbZHmtM
# Classe não considerada: IfcPlate, GlobalId: 2OvcoRUPH7DgGk6LQR6LFp
# Classe não considerada: IfcPlate, GlobalId: 0eXQTFhY95fBavGlcbsA54
# Classe não considerada: IfcCovering, GlobalId: 1ktfzpY95EmuhcNWdLmARW
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$efC
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvKH
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr9y
# Classe não considerada: IfcPlate, GlobalId: 3N7AQpHRv5zxcGRQ2xwkNj
# Classe não considerada: IfcMember, GlobalId: 33_v3Hr296PeGA45nkcrH2
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02Rr7t
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lzq
# Classe não considerada: IfcMember, GlobalId: 2Gorm7e1PAlBQzwFL7Ya2j
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fZo
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_rL
# Classe não considerada: IfcPlate, GlobalId: 2F5L0qSf134fOVidzmBMh_
# Classe não considerada: IfcColumn, GlobalId: 2VGeAY8on3lBlEgzSvtUh9
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqntqV
# Classe não considerada: IfcPlate, GlobalId: 2G9oBZ7vr3NP5_kKNa$efk
# Classe não considerada: IfcPlate, GlobalId: 2h$gjL33198vIIuysvIQWd
# Classe não considerada: IfcMember, GlobalId: 0fWgNKWcb80eY8bf02Rr83
# Classe não considerada: IfcPlate, GlobalId: 1ejmjhRo17Xe0Zzy8LpHkn
# Classe não considerada: IfcMember, GlobalId: 1ejmjhRo17Xe0Zzy8LpGow
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXyWX
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ekd
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fav
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHpQ
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHmUM
# Classe não considerada: IfcMember, GlobalId: 3uHTTQS71AzBNlbFbH5Wb1
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntmc
# Classe não considerada: IfcStairFlight, GlobalId: 0As_LcBd59ru2GBnRG764L
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFD4f
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2owO
# Classe não considerada: IfcPlate, GlobalId: 0WUFfBF_5D1gigi2a8fIIZ
# Classe não considerada: IfcMember, GlobalId: 0WUFfBF_5D1gigi2a8fIHH
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54NhvvOR
# Classe não considerada: IfcPlate, GlobalId: 1YfvkLSdbFgOT$6RTc6fdp
# Classe não considerada: IfcPlate, GlobalId: 1guvs5$yv9FRpyX5o$dGhW
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0Jk
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2oxd
# Classe não considerada: IfcPlate, GlobalId: 0LYqlXswT9mB8LHQL_yKz8
# Classe não considerada: IfcMember, GlobalId: 1YfvkLSdbFgOT$6RTc6fbD
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcXycK
# Classe não considerada: IfcMember, GlobalId: 0lII7MToT6sv$itpQi2Lwr
# Classe não considerada: IfcPlate, GlobalId: 3HFgCWMzbFRA$y54Nhv_64
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt_t
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ejQ
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFENc
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqntyb
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ejw
# Classe não considerada: IfcMember, GlobalId: 0RSWh65sv7Y8HKEnRj2oxk
# Classe não considerada: IfcPlate, GlobalId: 0fWgNKWcb80eY8bf02RrDW
# Classe não considerada: IfcPlate, GlobalId: 0gte2lRXX42RcSk_CehM91
# Classe não considerada: IfcPlate, GlobalId: 1Z0LZeNrX3r8AuVcJip$92
# Classe não considerada: IfcCovering, GlobalId: 1jo167gMTDIgvU7LRzhkiS
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehPPC
# Classe não considerada: IfcMember, GlobalId: 2G9oBZ7vr3NP5_kKNa$ekj
# Classe não considerada: IfcMember, GlobalId: 2tZwZGkHPFtgEkZqOJFENj
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzd4
# Classe não considerada: IfcMember, GlobalId: 0UFhjKWVn2RRSWFvbZHpej
# Classe não considerada: IfcCovering, GlobalId: 1jo167gMTDIgvU7LRzhkb7
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHpA
# Classe não considerada: IfcMember, GlobalId: 0gte2lRXX42RcSk_CehM8d
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$oz
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4SqntnQ
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnt$6
# Classe não considerada: IfcPlate, GlobalId: 3CE51L9p13OPsSiRQ4KL3p
# Classe não considerada: IfcPlate, GlobalId: 3LgwrbT6P2NQzosXIWzHyj
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnmoz
# Classe não considerada: IfcMember, GlobalId: 3HFgCWMzbFRA$y54Nhv_EH
# Classe não considerada: IfcMember, GlobalId: 2SypDrroL56B3KVCpdDVW1
# Classe não considerada: IfcMember, GlobalId: 2abrad_yTAk8FTs4Sqnm7w
# Classe não considerada: IfcPlate, GlobalId: 2abrad_yTAk8FTs4Sqnty2
# Classe não considerada: IfcBeam, GlobalId: 2n72bXf05C5eQQ0WzyBzdG
# Classe não considerada: IfcMember, GlobalId: 07JwA$xdz1c95eH4$1W0Ib
# Classe não considerada: IfcMember, GlobalId: 1joGBEqi5DvQ8CN9wcX$ox

# %%
df_quantitativo = pd.DataFrame(dict_quantitativo)

# %%
df_quantitativo.describe()
# Out:
#         altura (m)     área (m²)  volume (m³)
# count  2404.000000   2404.000000  2404.000000
# mean      2.644414     42.406989     6.903952
# std       1.441678    440.285675    93.902252
# min       0.004000      0.001171     0.000031
# 25%       1.800000      2.289000     0.133591
# 50%       3.030000      6.266897     0.424871
# 75%       3.520000     14.175000     1.030281
# max      17.740000  16705.498889  3341.099778

# %%
df_quantitativo.to_excel("ARQ-lista de materiais-Paredes e Pisos.xlsx")

# %% [markdown]
# # SINAPI

# %% [markdown]
# ## Acesso ao arquivo

# %%
# Acessa o arquivo
SUFIXO = "SINAPI_ref_Insumos_Composicoes"
estado = "DF"
ano = "2024"
mes = "09"
tipo = "Desonerado"
SUFIXO_ARQ = "SINAPI_Custo_Ref_Composicoes_Analitico"
#ARQUIVO = "SINAPI_Custo_Ref_Composicoes_Analitico_DF_202408_Desonerado.xlsx"

dc = "./SINAPI/" + SUFIXO + "_" + estado + "_" + ano + mes + "_" + tipo
arq = dc + "/" + SUFIXO_ARQ + "_" + estado + "_" + ano + mes + "_" + tipo + ".xlsx"

# %%
sinapi = pd.read_excel(arq, header=5)

# %% [markdown]
# ## Trabalhando com o arquivo

# %%
sinapi[sinapi["CODIGO DA COMPOSICAO"] == 92265]
# Out:
#           DESCRICAO DA CLASSE SIGLA DA CLASSE  \
# 14209  FUNDACOES E ESTRUTURAS            FUES
# 14210  FUNDACOES E ESTRUTURAS            FUES
# 14211  FUNDACOES E ESTRUTURAS            FUES
# 14212  FUNDACOES E ESTRUTURAS            FUES
# 14213  FUNDACOES E ESTRUTURAS            FUES
# 14214  FUNDACOES E ESTRUTURAS            FUES
# 14215  FUNDACOES E ESTRUTURAS            FUES
# 14216  FUNDACOES E ESTRUTURAS            FUES
# 14217  FUNDACOES E ESTRUTURAS            FUES
#
#                     DESCRICAO DO TIPO 1  SIGLA DO TIPO 1  CODIGO DO AGRUPADOR  \
# 14209  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14210  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14211  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14212  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14213  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14214  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14215  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14216  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
# 14217  FORMAS/CIMBRAMENTOS/ESCORAMENTOS             41.0                  NaN
#
#        DESCRICAO DO AGRUPADOR  CODIGO DA COMPOSICAO  \
# 14209                     NaN               92265.0
# 14210                     NaN               92265.0
# 14211                     NaN               92265.0
# 14212                     NaN               92265.0
# 14213                     NaN               92265.0
# 14214                     NaN               92265.0
# 14215                     NaN               92265.0
# 14216                     NaN               92265.0
# 14217                     NaN               92265.0
#
#                                  DESCRICAO DA COMPOSICAO UNIDADE  \
# 14209  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14210  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14211  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14212  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14213  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14214  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14215  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14216  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
# 14217  FABRICAÇÃO DE FÔRMA PARA VIGAS, EM CHAPA DE MA...      M2
#
#                          ORIGEM DE PREÇO  ... % MAO DE OBRA CUSTO MATERIAL  \
# 14209  COEFICIENTE DE REPRESENTATIVIDADE  ...    24,4798407          75,92
# 14210  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14211  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14212  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14213  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14214  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14215  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14216  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
# 14217  COEFICIENTE DE REPRESENTATIVIDADE  ...           NaN            NaN
#
#        % MATERIAL CUSTO EQUIPAMENTO % EQUIPAMENTO CUSTO SERVICOS TERCEIROS  \
# 14209  75,4504729              0,02     0,0199104                     0,00
# 14210         NaN               NaN           NaN                      NaN
# 14211         NaN               NaN           NaN                      NaN
# 14212         NaN               NaN           NaN                      NaN
# 14213         NaN               NaN           NaN                      NaN
# 14214         NaN               NaN           NaN                      NaN
# 14215         NaN               NaN           NaN                      NaN
# 14216         NaN               NaN           NaN                      NaN
# 14217         NaN               NaN           NaN                      NaN
#
#       % SERVICOS TERCEIROS CUSTO OUTROS   % OUTROS            VINCULO
# 14209            0,0000000         0,05  0,0497760  CAIXA REFERENCIAL
# 14210                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14211                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14212                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14213                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14214                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14215                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14216                  NaN          NaN        NaN  CAIXA REFERENCIAL
# 14217                  NaN          NaN        NaN  CAIXA REFERENCIAL
#
# [9 rows x 30 columns]

# %%
# Muda a categoria de código para string ao invés de número
sinapi["CODIGO DA COMPOSICAO"] = sinapi["CODIGO DA COMPOSICAO"].astype(str)
sinapi["CODIGO DA COMPOSICAO"] = sinapi["CODIGO DA COMPOSICAO"].str.replace('.0', '') # remove o .0 que fica após o número
sinapi["CODIGO ITEM"] = sinapi["CODIGO ITEM"].astype(str)
sinapi["CODIGO ITEM"] = sinapi["CODIGO ITEM"].str.replace('.0', '')

# %%
for column in sinapi:
    print(column)
# Out:
# DESCRICAO DA CLASSE
# SIGLA DA CLASSE
# DESCRICAO DO TIPO 1
# SIGLA DO TIPO 1
# CODIGO DO AGRUPADOR
# DESCRICAO DO AGRUPADOR
# CODIGO DA COMPOSICAO
# DESCRICAO DA COMPOSICAO
# UNIDADE
# ORIGEM DE PREÇO
# CUSTO TOTAL
# TIPO ITEM
# CODIGO ITEM
# DESCRIÇÃO ITEM
# UNIDADE ITEM
# ORIGEM DE PREÇO ITEM
# COEFICIENTE
# PRECO UNITARIO
# CUSTO TOTAL.1
# CUSTO MAO DE OBRA
# % MAO DE OBRA
# CUSTO MATERIAL
# % MATERIAL
# CUSTO EQUIPAMENTO
# % EQUIPAMENTO
# CUSTO SERVICOS TERCEIROS
# % SERVICOS TERCEIROS
# CUSTO OUTROS
# % OUTROS
# VINCULO

# %% [markdown]
# NOMES DAS COLUNAS - FUNÇÃO
# * CODIGO DA COMPOSICAO - código da composição do SINAPI
# * DESCRICAO DA COMPOSICAO - descrição da composição do SINAPI
# * UNIDADE - unidade da composição
# * CUSTO TOTAL - custo total da composição
# * TIPO ITEM - tipo do item da composição, para saber se é INSUMO ou COMPOSICAO (se COMPOSICAO abrir até o nível de insumo)
# * CODIGO ITEM - código do item da composição
# * DESCRIÇÃO ITEM - descrição do item da composição
# * UNIDADE ITEM - unidade do item da composição
# * COEFICIENTE - coeficiente da composição (ex: 0,235 h/m²)
# * PRECO UNITARIO - preço unitário do item
# * CUSTO TOTAL.1 - custo total do item (o ".1" é criado porque está com mesmo nome do CUSTO TOTAL da composição)

# %% [markdown]
# Não tem coluna que identifica se o insumo é material, mão de obra ou equipamento. Criar uma coluna CLASSE, que identifique isto

# %%
COLUMNS = ["CODIGO DA COMPOSICAO",
           "DESCRICAO DA COMPOSICAO",
           "UNIDADE",
           "CUSTO TOTAL",
           "TIPO ITEM",
           "CODIGO ITEM",
           "DESCRIÇÃO ITEM",
           "UNIDADE ITEM",
           "COEFICIENTE",
           "PRECO UNITARIO",
           "CUSTO TOTAL.1",
           "CATEGORIA COMPOSICAO"]

# %%
# Convertendo as vírgulas para ponto para o pandas ler como número e removendo o separador de milhar
sinapi["CUSTO TOTAL"] = sinapi["CUSTO TOTAL"].str.replace('.', '')
sinapi["CUSTO TOTAL"] = sinapi["CUSTO TOTAL"].str.replace(',', '.').astype(float)
sinapi["COEFICIENTE"] = sinapi["COEFICIENTE"].str.replace('.', '')
sinapi["COEFICIENTE"] = sinapi["COEFICIENTE"].str.replace(',', '.').astype(float)
sinapi["PRECO UNITARIO"] = sinapi["PRECO UNITARIO"].str.replace('.', '')
sinapi["PRECO UNITARIO"] = sinapi["PRECO UNITARIO"].str.replace(',', '.').astype(float)

# %%
# categorização dos itens em equipamento, mão de obra e material para o nível de composição
# QUESTÃO: é necessário??
# PROBLEMA: nem toda unidade H e MÊS refere-se à mão de obra, alguns são locações de equipamento

condicoes = [
    sinapi["UNIDADE"] == "CHP",
    sinapi["UNIDADE"] == "CHI",
    sinapi["UNIDADE"] == "H",
    sinapi["UNIDADE"] == "MÊS",
]

valores = [
    "EQUIPAMENTO",
    "EQUIPAMENTO",
    "MÃO DE OBRA",
    "MÃO DE OBRA",
]

sinapi["CATEGORIA COMPOSICAO"] = np.select(condicoes, valores, default="MATERIAL")

# %% [markdown]
# ## Simulação

# %%
COLUMNS_DF_PLAN = COLUMNS + ["ID", "EAP", "QNTD"]
df_plan = pd.DataFrame(columns = COLUMNS_DF_PLAN)

# %%
sinapi[sinapi["CODIGO DA COMPOSICAO"] == "103327"][COLUMNS]
# Out:
#       CODIGO DA COMPOSICAO                            DESCRICAO DA COMPOSICAO  \
# 36974               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 36975               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 36976               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 36977               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 36978               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 36979               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 36980               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
#
#       UNIDADE  CUSTO TOTAL   TIPO ITEM CODIGO ITEM  \
# 36974      M2       102.44         NaN         nan
# 36975      M2       102.44      INSUMO       34548
# 36976      M2       102.44      INSUMO       37395
# 36977      M2       102.44      INSUMO       37594
# 36978      M2       102.44  COMPOSICAO       87369
# 36979      M2       102.44  COMPOSICAO       88309
# 36980      M2       102.44  COMPOSICAO       88316
#
#                                           DESCRIÇÃO ITEM UNIDADE ITEM  \
# 36974                                                NaN          NaN
# 36975  TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 36976  PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 36977  BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 36978  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...           M3
# 36979               PEDREIRO COM ENCARGOS COMPLEMENTARES            H
# 36980               SERVENTE COM ENCARGOS COMPLEMENTARES            H
#
#        COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1 CATEGORIA COMPOSICAO
# 36974          NaN             NaN           NaN             MATERIAL
# 36975       0.4200            6.05          2,54             MATERIAL
# 36976       0.0100           43.74          0,43             MATERIAL
# 36977      13.6000            3.64         49,50             MATERIAL
# 36978       0.0138          843.36         11,63             MATERIAL
# 36979       0.9900           28.05         27,76          MÃO DE OBRA
# 36980       0.4950           21.38         10,58          MÃO DE OBRA

# %% [markdown]
# ### 1° elemento

# %%
# simulação alvenaria
ID = 1
QS = 200
EAP = 4.1

# %%
temp = sinapi[sinapi["CODIGO DA COMPOSICAO"] == "103327"][COLUMNS]
temp["ID"] = ID
temp["EAP"] = EAP
temp["Qs"] = QS

# %%
df_plan = pd.concat([df_plan if not df_plan.empty else None, temp], ignore_index=True)

# %%
df_plan
# Out:
#   CODIGO DA COMPOSICAO                            DESCRICAO DA COMPOSICAO  \
# 0               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 1               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 2               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 3               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 4               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 5               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 6               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
#
#   UNIDADE  CUSTO TOTAL   TIPO ITEM CODIGO ITEM  \
# 0      M2       102.44         NaN         nan
# 1      M2       102.44      INSUMO       34548
# 2      M2       102.44      INSUMO       37395
# 3      M2       102.44      INSUMO       37594
# 4      M2       102.44  COMPOSICAO       87369
# 5      M2       102.44  COMPOSICAO       88309
# 6      M2       102.44  COMPOSICAO       88316
#
#                                       DESCRIÇÃO ITEM UNIDADE ITEM  \
# 0                                                NaN          NaN
# 1  TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 2  PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 3  BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 4  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...           M3
# 5               PEDREIRO COM ENCARGOS COMPLEMENTARES            H
# 6               SERVENTE COM ENCARGOS COMPLEMENTARES            H
#
#    COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1 CATEGORIA COMPOSICAO  ID  EAP  \
# 0          NaN             NaN           NaN             MATERIAL   1  4.1
# 1       0.4200            6.05          2,54             MATERIAL   1  4.1
# 2       0.0100           43.74          0,43             MATERIAL   1  4.1
# 3      13.6000            3.64         49,50             MATERIAL   1  4.1
# 4       0.0138          843.36         11,63             MATERIAL   1  4.1
# 5       0.9900           28.05         27,76          MÃO DE OBRA   1  4.1
# 6       0.4950           21.38         10,58          MÃO DE OBRA   1  4.1
#
#     Qs
# 0  200
# 1  200
# 2  200
# 3  200
# 4  200
# 5  200
# 6  200

# %% [markdown]
# ### 2° elemento

# %%
# simulação alvenaria
ID = 2
QS = 400
EAP = 4.2

# %%
temp = sinapi[sinapi["CODIGO DA COMPOSICAO"] == "103327"][COLUMNS]
temp["ID"] = ID
temp["EAP"] = EAP
temp["Qs"] = QS

# %%
df_plan = pd.concat([df_plan if not df_plan.empty else None, temp], ignore_index=True)

# %% [markdown]
# ### Quantidades auxiliares

# %% [markdown]
# As quantidades auxiliares são utilizadas pois existem composições auxiliares dentro das composições principais, e esta quantidade que é utilizada nos insumos das composições auxiliares.
# Se dentro da composição tiver insumo direto, a quantidade auxiliar corresponde à quantidade total

# %%
# Cálculo das quantidades totais das composições auxiliares e insumos
df_plan["QNTD AUX"] = df_plan["COEFICIENTE"] * df_plan["Qs"]
df_plan["QNTD"] = df_plan["COEFICIENTE"] * df_plan["Qs"]
df_plan["RUP"] = ""
df_plan["HISTORICO"] = ""

# %% [markdown]
# ### Abrindo as composições

# %%
df_plan
# Out:
#    CODIGO DA COMPOSICAO                            DESCRICAO DA COMPOSICAO  \
# 0                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 1                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 2                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 3                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 4                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 5                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 6                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 7                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 8                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 9                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 10               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 11               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 12               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 13               103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
#
#    UNIDADE  CUSTO TOTAL   TIPO ITEM CODIGO ITEM  \
# 0       M2       102.44         NaN         nan
# 1       M2       102.44      INSUMO       34548
# 2       M2       102.44      INSUMO       37395
# 3       M2       102.44      INSUMO       37594
# 4       M2       102.44  COMPOSICAO       87369
# 5       M2       102.44  COMPOSICAO       88309
# 6       M2       102.44  COMPOSICAO       88316
# 7       M2       102.44         NaN         nan
# 8       M2       102.44      INSUMO       34548
# 9       M2       102.44      INSUMO       37395
# 10      M2       102.44      INSUMO       37594
# 11      M2       102.44  COMPOSICAO       87369
# 12      M2       102.44  COMPOSICAO       88309
# 13      M2       102.44  COMPOSICAO       88316
#
#                                        DESCRIÇÃO ITEM UNIDADE ITEM  \
# 0                                                 NaN          NaN
# 1   TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 2   PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 3   BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 4   ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...           M3
# 5                PEDREIRO COM ENCARGOS COMPLEMENTARES            H
# 6                SERVENTE COM ENCARGOS COMPLEMENTARES            H
# 7                                                 NaN          NaN
# 8   TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 9   PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 10  BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 11  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...           M3
# 12               PEDREIRO COM ENCARGOS COMPLEMENTARES            H
# 13               SERVENTE COM ENCARGOS COMPLEMENTARES            H
#
#     COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1 CATEGORIA COMPOSICAO  ID  EAP  \
# 0           NaN             NaN           NaN             MATERIAL   1  4.1
# 1        0.4200            6.05          2,54             MATERIAL   1  4.1
# 2        0.0100           43.74          0,43             MATERIAL   1  4.1
# 3       13.6000            3.64         49,50             MATERIAL   1  4.1
# 4        0.0138          843.36         11,63             MATERIAL   1  4.1
# 5        0.9900           28.05         27,76          MÃO DE OBRA   1  4.1
# 6        0.4950           21.38         10,58          MÃO DE OBRA   1  4.1
# 7           NaN             NaN           NaN             MATERIAL   2  4.2
# 8        0.4200            6.05          2,54             MATERIAL   2  4.2
# 9        0.0100           43.74          0,43             MATERIAL   2  4.2
# 10      13.6000            3.64         49,50             MATERIAL   2  4.2
# 11       0.0138          843.36         11,63             MATERIAL   2  4.2
# 12       0.9900           28.05         27,76          MÃO DE OBRA   2  4.2
# 13       0.4950           21.38         10,58          MÃO DE OBRA   2  4.2
#
#      Qs  QNTD AUX     QNTD RUP HISTORICO
# 0   200       NaN      NaN
# 1   200     84.00    84.00
# 2   200      2.00     2.00
# 3   200   2720.00  2720.00
# 4   200      2.76     2.76
# 5   200    198.00   198.00
# 6   200     99.00    99.00
# 7   400       NaN      NaN
# 8   400    168.00   168.00
# 9   400      4.00     4.00
# 10  400   5440.00  5440.00
# 11  400      5.52     5.52
# 12  400    396.00   396.00
# 13  400    198.00   198.00

# %%
# Abre as composições
while df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"].size > 0:
    i = 0
    index_abertos = []
    
    df_item_com_composicao = df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"]
    composicao_abertas = pd.DataFrame()
    
    while i < df_item_com_composicao.shape[0]:
        temp = sinapi[sinapi["CODIGO DA COMPOSICAO"] == df_item_com_composicao.iloc[i, 5]][COLUMNS]
        temp["ID"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("ID")]
        temp["EAP"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("EAP")]
        temp["Qs"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("Qs")]
        temp["QNTD AUX"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("QNTD")] # QNTD da composição auxiliar vira quantidade do insumo aberto
        temp["HISTORICO"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("CODIGO DA COMPOSICAO")] + "_" + df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("HISTORICO")]
        temp["RUP"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("COEFICIENTE")]
        
        composicao_abertas = pd.concat([composicao_abertas if not composicao_abertas.empty else None, temp], ignore_index=True)
        index_abertos.append(df_item_com_composicao.iloc[i, :].name) # remove a composição que já foi aberta
       
        i += 1
        
    # Exclui as composições abertas
    df_plan.drop(index_abertos, inplace=True)
    
    # Joga as composições abertas no dataframe principal
    df_plan = pd.concat([df_plan if not df_plan.empty else None, composicao_abertas], ignore_index=True)

    # Cálculo das quantidades totais das composições auxiliares e insumos
    df_plan["QNTD"] = df_plan["COEFICIENTE"] * df_plan["QNTD AUX"] # atualiza o valor da QNTD AUX caso tenha mais composições auxiliares (c.a.) dentro da c.a.

# %% [markdown]
# ### Categorização dos insumos

# %%
df_plan.dropna(inplace=True)

# %%
# categorização dos itens em equipamento, mão de obra e material

condicoes = [
    df_plan["UNIDADE ITEM"] == "CHP",
    df_plan["UNIDADE ITEM"] == "CHI",
    df_plan["DESCRICAO DA COMPOSICAO"].str.startswith('CURSO'), # O curso de capacitação é categorizado como mão de obra conforme o SINAPI, mas ele não vai ser utilizado como recurso no planejamento
    df_plan["DESCRIÇÃO ITEM"].str.startswith('AJUDANTE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ASSENTADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('AUXILIAR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('AZULEJISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('CALCETEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('CAVOUQUEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('CARPINTEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ELETRICISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ENCANADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ELETROTECNICO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('GESSEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('IMPERMEABILIZADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('INSTALADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('JARDINEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MACARIQUEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MARCENEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MARMORISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MECANICO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MONTADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MOTORISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('NIVELADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('OPERADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('PASTILHEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('PEDREIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('PINTOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('POCEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('SERRALHEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('SERVENTE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('SOLDADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('TOPOGRAFO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('VIDRACEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('VIGIA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ALMOXARIFE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('APONTADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ARQUITETO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('DESENHISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ENCARREGADO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ENGENHEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MESTRE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('TECNICO'), 
]

valores = ["EQUIPAMENTO"]*2 + ["MÃO DE OBRA_CURSO"] + ["MÃO DE OBRA"]*40

df_plan["CATEGORIA INSUMO"] = np.select(condicoes, valores, default="MATERIAL")

# %%
df_plan
# Out:
#    CODIGO DA COMPOSICAO                            DESCRICAO DA COMPOSICAO  \
# 1                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 2                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 3                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 5                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 6                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 7                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 9                 87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 10                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 11                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 13                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 14                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 15                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 16                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 17                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 18                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 19                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 21                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 22                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 23                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 24                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 25                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 26                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 27                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 29                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 30                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 31                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 33                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 34                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 35                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 36                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 37                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 38                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 39                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 41                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 42                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 43                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 44                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 45                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 46                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 47                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 49                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 50                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 51                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 52                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 53                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 54                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 55                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 57                95371  CURSO DE CAPACITAÇÃO PARA PEDREIRO (ENCARGOS C...
# 59                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
# 61                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 62                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 63                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 64                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 65                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 66                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 67                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 69                95371  CURSO DE CAPACITAÇÃO PARA PEDREIRO (ENCARGOS C...
# 71                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
# 73                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
# 75                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
#
#    UNIDADE  CUSTO TOTAL TIPO ITEM CODIGO ITEM  \
# 1       M2       102.44    INSUMO       34548
# 2       M2       102.44    INSUMO       37395
# 3       M2       102.44    INSUMO       37594
# 5       M2       102.44    INSUMO       34548
# 6       M2       102.44    INSUMO       37395
# 7       M2       102.44    INSUMO       37594
# 9       M3       843.36    INSUMO         370
# 10      M3       843.36    INSUMO        1106
# 11      M3       843.36    INSUMO        1379
# 13       H        28.05    INSUMO        4750
# 14       H        28.05    INSUMO       37370
# 15       H        28.05    INSUMO       37371
# 16       H        28.05    INSUMO       37372
# 17       H        28.05    INSUMO       37373
# 18       H        28.05    INSUMO       43465
# 19       H        28.05    INSUMO       43489
# 21       H        21.38    INSUMO        6111
# 22       H        21.38    INSUMO       37370
# 23       H        21.38    INSUMO       37371
# 24       H        21.38    INSUMO       37372
# 25       H        21.38    INSUMO       37373
# 26       H        21.38    INSUMO       43467
# 27       H        21.38    INSUMO       43491
# 29      M3       843.36    INSUMO         370
# 30      M3       843.36    INSUMO        1106
# 31      M3       843.36    INSUMO        1379
# 33       H        28.05    INSUMO        4750
# 34       H        28.05    INSUMO       37370
# 35       H        28.05    INSUMO       37371
# 36       H        28.05    INSUMO       37372
# 37       H        28.05    INSUMO       37373
# 38       H        28.05    INSUMO       43465
# 39       H        28.05    INSUMO       43489
# 41       H        21.38    INSUMO        6111
# 42       H        21.38    INSUMO       37370
# 43       H        21.38    INSUMO       37371
# 44       H        21.38    INSUMO       37372
# 45       H        21.38    INSUMO       37373
# 46       H        21.38    INSUMO       43467
# 47       H        21.38    INSUMO       43491
# 49       H        21.38    INSUMO        6111
# 50       H        21.38    INSUMO       37370
# 51       H        21.38    INSUMO       37371
# 52       H        21.38    INSUMO       37372
# 53       H        21.38    INSUMO       37373
# 54       H        21.38    INSUMO       43467
# 55       H        21.38    INSUMO       43491
# 57       H         0.46    INSUMO        4750
# 59       H         0.30    INSUMO        6111
# 61       H        21.38    INSUMO        6111
# 62       H        21.38    INSUMO       37370
# 63       H        21.38    INSUMO       37371
# 64       H        21.38    INSUMO       37372
# 65       H        21.38    INSUMO       37373
# 66       H        21.38    INSUMO       43467
# 67       H        21.38    INSUMO       43491
# 69       H         0.46    INSUMO        4750
# 71       H         0.30    INSUMO        6111
# 73       H         0.30    INSUMO        6111
# 75       H         0.30    INSUMO        6111
#
#                                        DESCRIÇÃO ITEM UNIDADE ITEM  \
# 1   TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 2   PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 3   BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 5   TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 6   PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 7   BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 9   AREIA MEDIA - POSTO JAZIDA/FORNECEDOR (RETIRAD...           M3
# 10                 CAL HIDRATADA CH-I PARA ARGAMASSAS           KG
# 11                 CIMENTO PORTLAND COMPOSTO CP II-32           KG
# 13                                 PEDREIRO (HORISTA)            H
# 14  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 15  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 16  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 17  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 18  FERRAMENTAS - FAMILIA PEDREIRO - HORISTA (ENCA...            H
# 19  EPI - FAMILIA PEDREIRO - HORISTA (ENCARGOS COM...            H
# 21                        SERVENTE DE OBRAS (HORISTA)            H
# 22  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 23  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 24  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 25  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 26  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 27  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 29  AREIA MEDIA - POSTO JAZIDA/FORNECEDOR (RETIRAD...           M3
# 30                 CAL HIDRATADA CH-I PARA ARGAMASSAS           KG
# 31                 CIMENTO PORTLAND COMPOSTO CP II-32           KG
# 33                                 PEDREIRO (HORISTA)            H
# 34  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 35  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 36  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 37  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 38  FERRAMENTAS - FAMILIA PEDREIRO - HORISTA (ENCA...            H
# 39  EPI - FAMILIA PEDREIRO - HORISTA (ENCARGOS COM...            H
# 41                        SERVENTE DE OBRAS (HORISTA)            H
# 42  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 43  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 44  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 45  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 46  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 47  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 49                        SERVENTE DE OBRAS (HORISTA)            H
# 50  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 51  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 52  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 53  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 54  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 55  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 57                                 PEDREIRO (HORISTA)            H
# 59                        SERVENTE DE OBRAS (HORISTA)            H
# 61                        SERVENTE DE OBRAS (HORISTA)            H
# 62  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 63  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 64  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 65  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 66  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 67  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 69                                 PEDREIRO (HORISTA)            H
# 71                        SERVENTE DE OBRAS (HORISTA)            H
# 73                        SERVENTE DE OBRAS (HORISTA)            H
# 75                        SERVENTE DE OBRAS (HORISTA)            H
#
#     COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1 CATEGORIA COMPOSICAO  ID  EAP  \
# 1       0.42000            6.05          2,54             MATERIAL   1  4.1
# 2       0.01000           43.74          0,43             MATERIAL   1  4.1
# 3      13.60000            3.64         49,50             MATERIAL   1  4.1
# 5       0.42000            6.05          2,54             MATERIAL   2  4.2
# 6       0.01000           43.74          0,43             MATERIAL   2  4.2
# 7      13.60000            3.64         49,50             MATERIAL   2  4.2
# 9       1.14000          195.00        222,30             MATERIAL   1  4.1
# 10    171.13000            1.50        256,69             MATERIAL   1  4.1
# 11    192.52000            0.66        127,06             MATERIAL   1  4.1
# 13      1.00000           18.85         18,85          MÃO DE OBRA   1  4.1
# 14      1.00000            3.80          3,80          MÃO DE OBRA   1  4.1
# 15      1.00000            1.50          1,50          MÃO DE OBRA   1  4.1
# 16      1.00000            1.34          1,34          MÃO DE OBRA   1  4.1
# 17      1.00000            0.04          0,04          MÃO DE OBRA   1  4.1
# 18      1.00000            0.82          0,82          MÃO DE OBRA   1  4.1
# 19      1.00000            1.24          1,24          MÃO DE OBRA   1  4.1
# 21      1.00000           12.46         12,46          MÃO DE OBRA   1  4.1
# 22      1.00000            3.80          3,80          MÃO DE OBRA   1  4.1
# 23      1.00000            1.50          1,50          MÃO DE OBRA   1  4.1
# 24      1.00000            1.34          1,34          MÃO DE OBRA   1  4.1
# 25      1.00000            0.04          0,04          MÃO DE OBRA   1  4.1
# 26      1.00000            0.61          0,61          MÃO DE OBRA   1  4.1
# 27      1.00000            1.33          1,33          MÃO DE OBRA   1  4.1
# 29      1.14000          195.00        222,30             MATERIAL   2  4.2
# 30    171.13000            1.50        256,69             MATERIAL   2  4.2
# 31    192.52000            0.66        127,06             MATERIAL   2  4.2
# 33      1.00000           18.85         18,85          MÃO DE OBRA   2  4.2
# 34      1.00000            3.80          3,80          MÃO DE OBRA   2  4.2
# 35      1.00000            1.50          1,50          MÃO DE OBRA   2  4.2
# 36      1.00000            1.34          1,34          MÃO DE OBRA   2  4.2
# 37      1.00000            0.04          0,04          MÃO DE OBRA   2  4.2
# 38      1.00000            0.82          0,82          MÃO DE OBRA   2  4.2
# 39      1.00000            1.24          1,24          MÃO DE OBRA   2  4.2
# 41      1.00000           12.46         12,46          MÃO DE OBRA   2  4.2
# 42      1.00000            3.80          3,80          MÃO DE OBRA   2  4.2
# 43      1.00000            1.50          1,50          MÃO DE OBRA   2  4.2
# 44      1.00000            1.34          1,34          MÃO DE OBRA   2  4.2
# 45      1.00000            0.04          0,04          MÃO DE OBRA   2  4.2
# 46      1.00000            0.61          0,61          MÃO DE OBRA   2  4.2
# 47      1.00000            1.33          1,33          MÃO DE OBRA   2  4.2
# 49      1.00000           12.46         12,46          MÃO DE OBRA   1  4.1
# 50      1.00000            3.80          3,80          MÃO DE OBRA   1  4.1
# 51      1.00000            1.50          1,50          MÃO DE OBRA   1  4.1
# 52      1.00000            1.34          1,34          MÃO DE OBRA   1  4.1
# 53      1.00000            0.04          0,04          MÃO DE OBRA   1  4.1
# 54      1.00000            0.61          0,61          MÃO DE OBRA   1  4.1
# 55      1.00000            1.33          1,33          MÃO DE OBRA   1  4.1
# 57      0.02442           18.85          0,46          MÃO DE OBRA   1  4.1
# 59      0.02442           12.46          0,30          MÃO DE OBRA   1  4.1
# 61      1.00000           12.46         12,46          MÃO DE OBRA   2  4.2
# 62      1.00000            3.80          3,80          MÃO DE OBRA   2  4.2
# 63      1.00000            1.50          1,50          MÃO DE OBRA   2  4.2
# 64      1.00000            1.34          1,34          MÃO DE OBRA   2  4.2
# 65      1.00000            0.04          0,04          MÃO DE OBRA   2  4.2
# 66      1.00000            0.61          0,61          MÃO DE OBRA   2  4.2
# 67      1.00000            1.33          1,33          MÃO DE OBRA   2  4.2
# 69      0.02442           18.85          0,46          MÃO DE OBRA   2  4.2
# 71      0.02442           12.46          0,30          MÃO DE OBRA   2  4.2
# 73      0.02442           12.46          0,30          MÃO DE OBRA   1  4.1
# 75      0.02442           12.46          0,30          MÃO DE OBRA   2  4.2
#
#      Qs  QNTD AUX          QNTD     RUP            HISTORICO  \
# 1   200    84.000     35.280000
# 2   200     2.000      0.020000
# 3   200  2720.000  36992.000000
# 5   400   168.000     70.560000
# 6   400     4.000      0.040000
# 7   400  5440.000  73984.000000
# 9   200     2.760      3.146400  0.0138              103327_
# 10  200     2.760    472.318800  0.0138              103327_
# 11  200     2.760    531.355200  0.0138              103327_
# 13  200   198.000    198.000000    0.99              103327_
# 14  200   198.000    198.000000    0.99              103327_
# 15  200   198.000    198.000000    0.99              103327_
# 16  200   198.000    198.000000    0.99              103327_
# 17  200   198.000    198.000000    0.99              103327_
# 18  200   198.000    198.000000    0.99              103327_
# 19  200   198.000    198.000000    0.99              103327_
# 21  200    99.000     99.000000   0.495              103327_
# 22  200    99.000     99.000000   0.495              103327_
# 23  200    99.000     99.000000   0.495              103327_
# 24  200    99.000     99.000000   0.495              103327_
# 25  200    99.000     99.000000   0.495              103327_
# 26  200    99.000     99.000000   0.495              103327_
# 27  200    99.000     99.000000   0.495              103327_
# 29  400     5.520      6.292800  0.0138              103327_
# 30  400     5.520    944.637600  0.0138              103327_
# 31  400     5.520   1062.710400  0.0138              103327_
# 33  400   396.000    396.000000    0.99              103327_
# 34  400   396.000    396.000000    0.99              103327_
# 35  400   396.000    396.000000    0.99              103327_
# 36  400   396.000    396.000000    0.99              103327_
# 37  400   396.000    396.000000    0.99              103327_
# 38  400   396.000    396.000000    0.99              103327_
# 39  400   396.000    396.000000    0.99              103327_
# 41  400   198.000    198.000000   0.495              103327_
# 42  400   198.000    198.000000   0.495              103327_
# 43  400   198.000    198.000000   0.495              103327_
# 44  400   198.000    198.000000   0.495              103327_
# 45  400   198.000    198.000000   0.495              103327_
# 46  400   198.000    198.000000   0.495              103327_
# 47  400   198.000    198.000000   0.495              103327_
# 49  200    30.636     30.636000    11.1        87369_103327_
# 50  200    30.636     30.636000    11.1        87369_103327_
# 51  200    30.636     30.636000    11.1        87369_103327_
# 52  200    30.636     30.636000    11.1        87369_103327_
# 53  200    30.636     30.636000    11.1        87369_103327_
# 54  200    30.636     30.636000    11.1        87369_103327_
# 55  200    30.636     30.636000    11.1        87369_103327_
# 57  200   198.000      4.835160     1.0        88309_103327_
# 59  200    99.000      2.417580     1.0        88316_103327_
# 61  400    61.272     61.272000    11.1        87369_103327_
# 62  400    61.272     61.272000    11.1        87369_103327_
# 63  400    61.272     61.272000    11.1        87369_103327_
# 64  400    61.272     61.272000    11.1        87369_103327_
# 65  400    61.272     61.272000    11.1        87369_103327_
# 66  400    61.272     61.272000    11.1        87369_103327_
# 67  400    61.272     61.272000    11.1        87369_103327_
# 69  400   396.000      9.670320     1.0        88309_103327_
# 71  400   198.000      4.835160     1.0        88316_103327_
# 73  200    30.636      0.748131     1.0  88316_87369_103327_
# 75  400    61.272      1.496262     1.0  88316_87369_103327_
#
#      CATEGORIA INSUMO
# 1            MATERIAL
# 2            MATERIAL
# 3            MATERIAL
# 5            MATERIAL
# 6            MATERIAL
# 7            MATERIAL
# 9            MATERIAL
# 10           MATERIAL
# 11           MATERIAL
# 13        MÃO DE OBRA
# 14           MATERIAL
# 15           MATERIAL
# 16           MATERIAL
# 17           MATERIAL
# 18           MATERIAL
# 19           MATERIAL
# 21        MÃO DE OBRA
# 22           MATERIAL
# 23           MATERIAL
# 24           MATERIAL
# 25           MATERIAL
# 26           MATERIAL
# 27           MATERIAL
# 29           MATERIAL
# 30           MATERIAL
# 31           MATERIAL
# 33        MÃO DE OBRA
# 34           MATERIAL
# 35           MATERIAL
# 36           MATERIAL
# 37           MATERIAL
# 38           MATERIAL
# 39           MATERIAL
# 41        MÃO DE OBRA
# 42           MATERIAL
# 43           MATERIAL
# 44           MATERIAL
# 45           MATERIAL
# 46           MATERIAL
# 47           MATERIAL
# 49        MÃO DE OBRA
# 50           MATERIAL
# 51           MATERIAL
# 52           MATERIAL
# 53           MATERIAL
# 54           MATERIAL
# 55           MATERIAL
# 57  MÃO DE OBRA_CURSO
# 59  MÃO DE OBRA_CURSO
# 61        MÃO DE OBRA
# 62           MATERIAL
# 63           MATERIAL
# 64           MATERIAL
# 65           MATERIAL
# 66           MATERIAL
# 67           MATERIAL
# 69  MÃO DE OBRA_CURSO
# 71  MÃO DE OBRA_CURSO
# 73  MÃO DE OBRA_CURSO
# 75  MÃO DE OBRA_CURSO

# %% [markdown]
# ### Avaliação dos resultados

# %%
df_plan
# Out:
#    CODIGO DA COMPOSICAO                            DESCRICAO DA COMPOSICAO  \
# 1                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 2                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 3                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 5                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 6                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 7                103327  ALVENARIA DE VEDAÇÃO DE BLOCOS CERÂMICOS FURAD...
# 9                 87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 10                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 11                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 13                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 14                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 15                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 16                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 17                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 18                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 19                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 21                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 22                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 23                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 24                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 25                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 26                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 27                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 29                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 30                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 31                87369  ARGAMASSA TRAÇO 1:2:8 (EM VOLUME DE CIMENTO, C...
# 33                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 34                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 35                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 36                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 37                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 38                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 39                88309               PEDREIRO COM ENCARGOS COMPLEMENTARES
# 41                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 42                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 43                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 44                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 45                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 46                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 47                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 49                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 50                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 51                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 52                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 53                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 54                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 55                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 57                95371  CURSO DE CAPACITAÇÃO PARA PEDREIRO (ENCARGOS C...
# 59                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
# 61                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 62                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 63                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 64                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 65                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 66                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 67                88316               SERVENTE COM ENCARGOS COMPLEMENTARES
# 69                95371  CURSO DE CAPACITAÇÃO PARA PEDREIRO (ENCARGOS C...
# 71                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
# 73                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
# 75                95378  CURSO DE CAPACITAÇÃO PARA SERVENTE (ENCARGOS C...
#
#    UNIDADE  CUSTO TOTAL TIPO ITEM CODIGO ITEM  \
# 1       M2       102.44    INSUMO       34548
# 2       M2       102.44    INSUMO       37395
# 3       M2       102.44    INSUMO       37594
# 5       M2       102.44    INSUMO       34548
# 6       M2       102.44    INSUMO       37395
# 7       M2       102.44    INSUMO       37594
# 9       M3       843.36    INSUMO         370
# 10      M3       843.36    INSUMO        1106
# 11      M3       843.36    INSUMO        1379
# 13       H        28.05    INSUMO        4750
# 14       H        28.05    INSUMO       37370
# 15       H        28.05    INSUMO       37371
# 16       H        28.05    INSUMO       37372
# 17       H        28.05    INSUMO       37373
# 18       H        28.05    INSUMO       43465
# 19       H        28.05    INSUMO       43489
# 21       H        21.38    INSUMO        6111
# 22       H        21.38    INSUMO       37370
# 23       H        21.38    INSUMO       37371
# 24       H        21.38    INSUMO       37372
# 25       H        21.38    INSUMO       37373
# 26       H        21.38    INSUMO       43467
# 27       H        21.38    INSUMO       43491
# 29      M3       843.36    INSUMO         370
# 30      M3       843.36    INSUMO        1106
# 31      M3       843.36    INSUMO        1379
# 33       H        28.05    INSUMO        4750
# 34       H        28.05    INSUMO       37370
# 35       H        28.05    INSUMO       37371
# 36       H        28.05    INSUMO       37372
# 37       H        28.05    INSUMO       37373
# 38       H        28.05    INSUMO       43465
# 39       H        28.05    INSUMO       43489
# 41       H        21.38    INSUMO        6111
# 42       H        21.38    INSUMO       37370
# 43       H        21.38    INSUMO       37371
# 44       H        21.38    INSUMO       37372
# 45       H        21.38    INSUMO       37373
# 46       H        21.38    INSUMO       43467
# 47       H        21.38    INSUMO       43491
# 49       H        21.38    INSUMO        6111
# 50       H        21.38    INSUMO       37370
# 51       H        21.38    INSUMO       37371
# 52       H        21.38    INSUMO       37372
# 53       H        21.38    INSUMO       37373
# 54       H        21.38    INSUMO       43467
# 55       H        21.38    INSUMO       43491
# 57       H         0.46    INSUMO        4750
# 59       H         0.30    INSUMO        6111
# 61       H        21.38    INSUMO        6111
# 62       H        21.38    INSUMO       37370
# 63       H        21.38    INSUMO       37371
# 64       H        21.38    INSUMO       37372
# 65       H        21.38    INSUMO       37373
# 66       H        21.38    INSUMO       43467
# 67       H        21.38    INSUMO       43491
# 69       H         0.46    INSUMO        4750
# 71       H         0.30    INSUMO        6111
# 73       H         0.30    INSUMO        6111
# 75       H         0.30    INSUMO        6111
#
#                                        DESCRIÇÃO ITEM UNIDADE ITEM  \
# 1   TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 2   PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 3   BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 5   TELA DE ACO SOLDADA GALVANIZADA/ZINCADA PARA A...            M
# 6   PINO DE ACO COM FURO, HASTE = 27 MM (ACAO DIRETA)        CENTO
# 7   BLOCO CERAMICO / TIJOLO VAZADO PARA ALVENARIA ...           UN
# 9   AREIA MEDIA - POSTO JAZIDA/FORNECEDOR (RETIRAD...           M3
# 10                 CAL HIDRATADA CH-I PARA ARGAMASSAS           KG
# 11                 CIMENTO PORTLAND COMPOSTO CP II-32           KG
# 13                                 PEDREIRO (HORISTA)            H
# 14  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 15  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 16  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 17  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 18  FERRAMENTAS - FAMILIA PEDREIRO - HORISTA (ENCA...            H
# 19  EPI - FAMILIA PEDREIRO - HORISTA (ENCARGOS COM...            H
# 21                        SERVENTE DE OBRAS (HORISTA)            H
# 22  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 23  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 24  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 25  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 26  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 27  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 29  AREIA MEDIA - POSTO JAZIDA/FORNECEDOR (RETIRAD...           M3
# 30                 CAL HIDRATADA CH-I PARA ARGAMASSAS           KG
# 31                 CIMENTO PORTLAND COMPOSTO CP II-32           KG
# 33                                 PEDREIRO (HORISTA)            H
# 34  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 35  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 36  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 37  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 38  FERRAMENTAS - FAMILIA PEDREIRO - HORISTA (ENCA...            H
# 39  EPI - FAMILIA PEDREIRO - HORISTA (ENCARGOS COM...            H
# 41                        SERVENTE DE OBRAS (HORISTA)            H
# 42  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 43  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 44  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 45  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 46  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 47  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 49                        SERVENTE DE OBRAS (HORISTA)            H
# 50  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 51  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 52  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 53  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 54  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 55  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 57                                 PEDREIRO (HORISTA)            H
# 59                        SERVENTE DE OBRAS (HORISTA)            H
# 61                        SERVENTE DE OBRAS (HORISTA)            H
# 62  ALIMENTACAO - HORISTA (COLETADO CAIXA - ENCARG...            H
# 63  TRANSPORTE - HORISTA (COLETADO CAIXA - ENCARGO...            H
# 64  EXAMES - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 65  SEGURO - HORISTA (COLETADO CAIXA - ENCARGOS CO...            H
# 66  FERRAMENTAS - FAMILIA SERVENTE - HORISTA (ENCA...            H
# 67  EPI - FAMILIA SERVENTE - HORISTA (ENCARGOS COM...            H
# 69                                 PEDREIRO (HORISTA)            H
# 71                        SERVENTE DE OBRAS (HORISTA)            H
# 73                        SERVENTE DE OBRAS (HORISTA)            H
# 75                        SERVENTE DE OBRAS (HORISTA)            H
#
#     COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1 CATEGORIA COMPOSICAO  ID  EAP  \
# 1       0.42000            6.05          2,54             MATERIAL   1  4.1
# 2       0.01000           43.74          0,43             MATERIAL   1  4.1
# 3      13.60000            3.64         49,50             MATERIAL   1  4.1
# 5       0.42000            6.05          2,54             MATERIAL   2  4.2
# 6       0.01000           43.74          0,43             MATERIAL   2  4.2
# 7      13.60000            3.64         49,50             MATERIAL   2  4.2
# 9       1.14000          195.00        222,30             MATERIAL   1  4.1
# 10    171.13000            1.50        256,69             MATERIAL   1  4.1
# 11    192.52000            0.66        127,06             MATERIAL   1  4.1
# 13      1.00000           18.85         18,85          MÃO DE OBRA   1  4.1
# 14      1.00000            3.80          3,80          MÃO DE OBRA   1  4.1
# 15      1.00000            1.50          1,50          MÃO DE OBRA   1  4.1
# 16      1.00000            1.34          1,34          MÃO DE OBRA   1  4.1
# 17      1.00000            0.04          0,04          MÃO DE OBRA   1  4.1
# 18      1.00000            0.82          0,82          MÃO DE OBRA   1  4.1
# 19      1.00000            1.24          1,24          MÃO DE OBRA   1  4.1
# 21      1.00000           12.46         12,46          MÃO DE OBRA   1  4.1
# 22      1.00000            3.80          3,80          MÃO DE OBRA   1  4.1
# 23      1.00000            1.50          1,50          MÃO DE OBRA   1  4.1
# 24      1.00000            1.34          1,34          MÃO DE OBRA   1  4.1
# 25      1.00000            0.04          0,04          MÃO DE OBRA   1  4.1
# 26      1.00000            0.61          0,61          MÃO DE OBRA   1  4.1
# 27      1.00000            1.33          1,33          MÃO DE OBRA   1  4.1
# 29      1.14000          195.00        222,30             MATERIAL   2  4.2
# 30    171.13000            1.50        256,69             MATERIAL   2  4.2
# 31    192.52000            0.66        127,06             MATERIAL   2  4.2
# 33      1.00000           18.85         18,85          MÃO DE OBRA   2  4.2
# 34      1.00000            3.80          3,80          MÃO DE OBRA   2  4.2
# 35      1.00000            1.50          1,50          MÃO DE OBRA   2  4.2
# 36      1.00000            1.34          1,34          MÃO DE OBRA   2  4.2
# 37      1.00000            0.04          0,04          MÃO DE OBRA   2  4.2
# 38      1.00000            0.82          0,82          MÃO DE OBRA   2  4.2
# 39      1.00000            1.24          1,24          MÃO DE OBRA   2  4.2
# 41      1.00000           12.46         12,46          MÃO DE OBRA   2  4.2
# 42      1.00000            3.80          3,80          MÃO DE OBRA   2  4.2
# 43      1.00000            1.50          1,50          MÃO DE OBRA   2  4.2
# 44      1.00000            1.34          1,34          MÃO DE OBRA   2  4.2
# 45      1.00000            0.04          0,04          MÃO DE OBRA   2  4.2
# 46      1.00000            0.61          0,61          MÃO DE OBRA   2  4.2
# 47      1.00000            1.33          1,33          MÃO DE OBRA   2  4.2
# 49      1.00000           12.46         12,46          MÃO DE OBRA   1  4.1
# 50      1.00000            3.80          3,80          MÃO DE OBRA   1  4.1
# 51      1.00000            1.50          1,50          MÃO DE OBRA   1  4.1
# 52      1.00000            1.34          1,34          MÃO DE OBRA   1  4.1
# 53      1.00000            0.04          0,04          MÃO DE OBRA   1  4.1
# 54      1.00000            0.61          0,61          MÃO DE OBRA   1  4.1
# 55      1.00000            1.33          1,33          MÃO DE OBRA   1  4.1
# 57      0.02442           18.85          0,46          MÃO DE OBRA   1  4.1
# 59      0.02442           12.46          0,30          MÃO DE OBRA   1  4.1
# 61      1.00000           12.46         12,46          MÃO DE OBRA   2  4.2
# 62      1.00000            3.80          3,80          MÃO DE OBRA   2  4.2
# 63      1.00000            1.50          1,50          MÃO DE OBRA   2  4.2
# 64      1.00000            1.34          1,34          MÃO DE OBRA   2  4.2
# 65      1.00000            0.04          0,04          MÃO DE OBRA   2  4.2
# 66      1.00000            0.61          0,61          MÃO DE OBRA   2  4.2
# 67      1.00000            1.33          1,33          MÃO DE OBRA   2  4.2
# 69      0.02442           18.85          0,46          MÃO DE OBRA   2  4.2
# 71      0.02442           12.46          0,30          MÃO DE OBRA   2  4.2
# 73      0.02442           12.46          0,30          MÃO DE OBRA   1  4.1
# 75      0.02442           12.46          0,30          MÃO DE OBRA   2  4.2
#
#      Qs  QNTD AUX          QNTD     RUP            HISTORICO  \
# 1   200    84.000     35.280000
# 2   200     2.000      0.020000
# 3   200  2720.000  36992.000000
# 5   400   168.000     70.560000
# 6   400     4.000      0.040000
# 7   400  5440.000  73984.000000
# 9   200     2.760      3.146400  0.0138              103327_
# 10  200     2.760    472.318800  0.0138              103327_
# 11  200     2.760    531.355200  0.0138              103327_
# 13  200   198.000    198.000000    0.99              103327_
# 14  200   198.000    198.000000    0.99              103327_
# 15  200   198.000    198.000000    0.99              103327_
# 16  200   198.000    198.000000    0.99              103327_
# 17  200   198.000    198.000000    0.99              103327_
# 18  200   198.000    198.000000    0.99              103327_
# 19  200   198.000    198.000000    0.99              103327_
# 21  200    99.000     99.000000   0.495              103327_
# 22  200    99.000     99.000000   0.495              103327_
# 23  200    99.000     99.000000   0.495              103327_
# 24  200    99.000     99.000000   0.495              103327_
# 25  200    99.000     99.000000   0.495              103327_
# 26  200    99.000     99.000000   0.495              103327_
# 27  200    99.000     99.000000   0.495              103327_
# 29  400     5.520      6.292800  0.0138              103327_
# 30  400     5.520    944.637600  0.0138              103327_
# 31  400     5.520   1062.710400  0.0138              103327_
# 33  400   396.000    396.000000    0.99              103327_
# 34  400   396.000    396.000000    0.99              103327_
# 35  400   396.000    396.000000    0.99              103327_
# 36  400   396.000    396.000000    0.99              103327_
# 37  400   396.000    396.000000    0.99              103327_
# 38  400   396.000    396.000000    0.99              103327_
# 39  400   396.000    396.000000    0.99              103327_
# 41  400   198.000    198.000000   0.495              103327_
# 42  400   198.000    198.000000   0.495              103327_
# 43  400   198.000    198.000000   0.495              103327_
# 44  400   198.000    198.000000   0.495              103327_
# 45  400   198.000    198.000000   0.495              103327_
# 46  400   198.000    198.000000   0.495              103327_
# 47  400   198.000    198.000000   0.495              103327_
# 49  200    30.636     30.636000    11.1        87369_103327_
# 50  200    30.636     30.636000    11.1        87369_103327_
# 51  200    30.636     30.636000    11.1        87369_103327_
# 52  200    30.636     30.636000    11.1        87369_103327_
# 53  200    30.636     30.636000    11.1        87369_103327_
# 54  200    30.636     30.636000    11.1        87369_103327_
# 55  200    30.636     30.636000    11.1        87369_103327_
# 57  200   198.000      4.835160     1.0        88309_103327_
# 59  200    99.000      2.417580     1.0        88316_103327_
# 61  400    61.272     61.272000    11.1        87369_103327_
# 62  400    61.272     61.272000    11.1        87369_103327_
# 63  400    61.272     61.272000    11.1        87369_103327_
# 64  400    61.272     61.272000    11.1        87369_103327_
# 65  400    61.272     61.272000    11.1        87369_103327_
# 66  400    61.272     61.272000    11.1        87369_103327_
# 67  400    61.272     61.272000    11.1        87369_103327_
# 69  400   396.000      9.670320     1.0        88309_103327_
# 71  400   198.000      4.835160     1.0        88316_103327_
# 73  200    30.636      0.748131     1.0  88316_87369_103327_
# 75  400    61.272      1.496262     1.0  88316_87369_103327_
#
#      CATEGORIA INSUMO
# 1            MATERIAL
# 2            MATERIAL
# 3            MATERIAL
# 5            MATERIAL
# 6            MATERIAL
# 7            MATERIAL
# 9            MATERIAL
# 10           MATERIAL
# 11           MATERIAL
# 13        MÃO DE OBRA
# 14           MATERIAL
# 15           MATERIAL
# 16           MATERIAL
# 17           MATERIAL
# 18           MATERIAL
# 19           MATERIAL
# 21        MÃO DE OBRA
# 22           MATERIAL
# 23           MATERIAL
# 24           MATERIAL
# 25           MATERIAL
# 26           MATERIAL
# 27           MATERIAL
# 29           MATERIAL
# 30           MATERIAL
# 31           MATERIAL
# 33        MÃO DE OBRA
# 34           MATERIAL
# 35           MATERIAL
# 36           MATERIAL
# 37           MATERIAL
# 38           MATERIAL
# 39           MATERIAL
# 41        MÃO DE OBRA
# 42           MATERIAL
# 43           MATERIAL
# 44           MATERIAL
# 45           MATERIAL
# 46           MATERIAL
# 47           MATERIAL
# 49        MÃO DE OBRA
# 50           MATERIAL
# 51           MATERIAL
# 52           MATERIAL
# 53           MATERIAL
# 54           MATERIAL
# 55           MATERIAL
# 57  MÃO DE OBRA_CURSO
# 59  MÃO DE OBRA_CURSO
# 61        MÃO DE OBRA
# 62           MATERIAL
# 63           MATERIAL
# 64           MATERIAL
# 65           MATERIAL
# 66           MATERIAL
# 67           MATERIAL
# 69  MÃO DE OBRA_CURSO
# 71  MÃO DE OBRA_CURSO
# 73  MÃO DE OBRA_CURSO
# 75  MÃO DE OBRA_CURSO

# %%
df_plan[df_plan["CATEGORIA INSUMO"] == "MÃO DE OBRA"]
# Out:
#    CODIGO DA COMPOSICAO               DESCRICAO DA COMPOSICAO UNIDADE  \
# 13                88309  PEDREIRO COM ENCARGOS COMPLEMENTARES       H
# 21                88316  SERVENTE COM ENCARGOS COMPLEMENTARES       H
# 33                88309  PEDREIRO COM ENCARGOS COMPLEMENTARES       H
# 41                88316  SERVENTE COM ENCARGOS COMPLEMENTARES       H
# 49                88316  SERVENTE COM ENCARGOS COMPLEMENTARES       H
# 61                88316  SERVENTE COM ENCARGOS COMPLEMENTARES       H
#
#     CUSTO TOTAL TIPO ITEM CODIGO ITEM               DESCRIÇÃO ITEM  \
# 13        28.05    INSUMO        4750           PEDREIRO (HORISTA)
# 21        21.38    INSUMO        6111  SERVENTE DE OBRAS (HORISTA)
# 33        28.05    INSUMO        4750           PEDREIRO (HORISTA)
# 41        21.38    INSUMO        6111  SERVENTE DE OBRAS (HORISTA)
# 49        21.38    INSUMO        6111  SERVENTE DE OBRAS (HORISTA)
# 61        21.38    INSUMO        6111  SERVENTE DE OBRAS (HORISTA)
#
#    UNIDADE ITEM  COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1  \
# 13            H          1.0           18.85         18,85
# 21            H          1.0           12.46         12,46
# 33            H          1.0           18.85         18,85
# 41            H          1.0           12.46         12,46
# 49            H          1.0           12.46         12,46
# 61            H          1.0           12.46         12,46
#
#    CATEGORIA COMPOSICAO  ID  EAP   Qs  QNTD AUX     QNTD    RUP  \
# 13          MÃO DE OBRA   1  4.1  200   198.000  198.000   0.99
# 21          MÃO DE OBRA   1  4.1  200    99.000   99.000  0.495
# 33          MÃO DE OBRA   2  4.2  400   396.000  396.000   0.99
# 41          MÃO DE OBRA   2  4.2  400   198.000  198.000  0.495
# 49          MÃO DE OBRA   1  4.1  200    30.636   30.636   11.1
# 61          MÃO DE OBRA   2  4.2  400    61.272   61.272   11.1
#
#         HISTORICO CATEGORIA INSUMO
# 13        103327_      MÃO DE OBRA
# 21        103327_      MÃO DE OBRA
# 33        103327_      MÃO DE OBRA
# 41        103327_      MÃO DE OBRA
# 49  87369_103327_      MÃO DE OBRA
# 61  87369_103327_      MÃO DE OBRA

# %% [markdown]
# # Associar SINAPI ao IFC

# %% [markdown]
# ## IFC-Revit-TQS

# %% [markdown]
# Não se tem projeto de forma, de armação e de escoramento, estas quantidades vão ser estimadas pelo projeto de estrutura somente

# %% [markdown]
# ### Criação da EAP

# %%
# separadores
SEPARADOR_DESCRICAO = " - "
SEPARADOR_EAP = "."

# %% [markdown]
# ### Etiquetagem dos elementos com a EAP concretagem

# %%
df_concreto = df_quantitativo.copy()

# %%
# criação de colunas para identificar os itens e padronizar a organização
df_concreto["ID"] = ""
df_concreto["EAP"] = ""
df_concreto["descrição"] = ""
df_concreto["local"] = "Edifício"
df_concreto["serviço"] = "Concretagem"

# agrupa os elementos em pilares e mãos francesas, vigas e lajes, e cortina
df_concreto["elemento_agrupado"] = df_concreto["elemento"]
df_concreto.loc[(df_concreto["elemento"] == "Laje") | (df_concreto["elemento"] == "Capitel") | (df_concreto["elemento"] == "Viga"), "elemento_agrupado"] = "Lajes e Vigas"

# %%
# a divisão da EAP será dada por juntas - elementos - pavimentos

locais = np.array(["Edifício"]) #### PENDENCIA criar este parâmetro de local no IFC como fiz com as juntas
serviços = np.array(["Concretagem"])

juntas = np.sort(df_concreto["junta"].unique())
elementos = np.sort(df_concreto["elemento_agrupado"].unique())
pavimentos = np.sort(df_concreto["pavimento"].unique())

# Cria um DataFrame auxiliar com todas as combinações que serão dados o número de EAP e descrição
combinacoes = pd.MultiIndex.from_product(
    [locais, juntas, elementos, serviços, pavimentos],
    names=["local", "junta", "elemento_agrupado", "serviço", "pavimento"]
).to_frame(index=False)

# Cria a coluna EAP
combinacoes["EAP"] = (
    combinacoes["local"].apply(lambda x: str(np.where(locais == x)[0][0] + 1)) + SEPARADOR_EAP +
    combinacoes["junta"].apply(lambda x: str(np.where(juntas == x)[0][0] + 1)) + SEPARADOR_EAP +
    combinacoes["elemento_agrupado"].apply(lambda x: str(np.where(elementos == x)[0][0] + 1)) + SEPARADOR_EAP +
    combinacoes["serviço"].apply(lambda x: str(np.where(serviços == x)[0][0] + 1)) + SEPARADOR_EAP +
    combinacoes["pavimento"].apply(lambda x: str(np.where(pavimentos == x)[0][0] + 1))
)

# Gera as descrições e EAPs para cada combinação
combinacoes["descrição"] = (
    combinacoes["local"] + SEPARADOR_DESCRICAO +
    combinacoes["junta"] + SEPARADOR_DESCRICAO +
    combinacoes["elemento_agrupado"] + SEPARADOR_DESCRICAO +
    combinacoes["serviço"] + SEPARADOR_DESCRICAO +
    combinacoes["pavimento"]
)


# Atualiza o DataFrame
for idx, row in combinacoes.iterrows():
    df_concreto.loc[
        (df_concreto["local"] == row["local"]) &
        (df_concreto["junta"] == row["junta"]) &
        (df_concreto["elemento_agrupado"] == row["elemento_agrupado"]) &
        (df_concreto["serviço"] == row["serviço"]) &
        (df_concreto["pavimento"] == row["pavimento"]),
        ["descrição", "EAP"]
    ] = row["descrição"], row["EAP"]

# %%
# EAP em cada um dos elementos para ser inserido no IFC
eap_plan = df_concreto[["GlobalID", "EAP", "descrição"]]

# %%
eap_plan.to_excel("EST-EAP.xlsx")

# %% [markdown]
# ### Associação ao SINAPI

# %% [markdown]
# ### Criação do cronograma

# %%
# a divisão da EAP será dada por juntas - elementos - pavimentos

locais = np.array(["Edifício"]) #### PENDENCIA criar este parâmetro de local no IFC como fiz com as juntas
serviços = np.array(["Concretagem"])

juntas = np.sort(df_concreto["junta"].unique())
elementos = np.sort(df_concreto["elemento_agrupado"].unique())
pavimentos = np.sort(df_concreto["pavimento"].unique())

# Nível 2 EAP
combinacoes_2 = criar_combinacoes(["local", "junta"], locais, juntas)

# Nível 3 EAP
combinacoes_3 = criar_combinacoes(["local", "junta", "elemento_agrupado"], locais, juntas, elementos)

# Nível 4 EAP
combinacoes_4 = criar_combinacoes(["local", "junta", "elemento_agrupado", "serviço"], locais, juntas, elementos, serviços)

# Nível 5 EAP
### Especifico para a POE 789, pois tem juntas com quantidade diferentes de pavimento
### MELHORIA: verificar como automatizar a verificação para não ser feita a separação de juntas com quantidade diferentes de pavimento manualmente
combinacoes_5a = criar_combinacoes(["local", "junta", "elemento_agrupado", "serviço", "pavimento"], locais, juntas[:-2], elementos, serviços, pavimentos) # exclui as juntas E e F
combinacoes_5b = criar_combinacoes(["local", "junta", "elemento_agrupado", "serviço", "pavimento"],
                                   locais, juntas[-2:], elementos, serviços, np.array([pavimentos[0]])) # inclui as juntas E e F

# incrementar o nível da EAP na posição 1 de junta somando 4
### Especifico para a POE 789
combinacoes_5b["EAP"] = combinacoes_5b["EAP"].apply(lambda x: incrementar_eap(x, 1, 4))

# Concatena todos os DataFrames de EAP
df_eap = pd.concat([combinacoes_2[["EAP", "descrição"]],
                 combinacoes_3[["EAP", "descrição"]],
                 combinacoes_4[["EAP", "descrição"]],
                 combinacoes_5a[["EAP", "descrição"]],
                 combinacoes_5b[["EAP", "descrição"]]])

# Ordena o resultado final com base na numeração da EAP
df_eap.sort_values(by=["EAP"], inplace=True, ignore_index=True)

# %%
df_eap
# Out:
#            EAP                                          descrição
# 0          1.1                                 Edifício - Junta A
# 1        1.1.1                       Edifício - Junta A - Cortina
# 2      1.1.1.1         Edifício - Junta A - Cortina - Concretagem
# 3    1.1.1.1.1  Edifício - Junta A - Cortina - Concretagem - 0...
# 4    1.1.1.1.2  Edifício - Junta A - Cortina - Concretagem - 0...
# ..         ...                                                ...
# 151    1.6.2.1   Edifício - Junta F - Lajes e Vigas - Concretagem
# 152  1.6.2.1.1  Edifício - Junta F - Lajes e Vigas - Concretag...
# 153      1.6.3                         Edifício - Junta F - Pilar
# 154    1.6.3.1           Edifício - Junta F - Pilar - Concretagem
# 155  1.6.3.1.1  Edifício - Junta F - Pilar - Concretagem - 01_...
#
# [156 rows x 2 columns]

# %%
# exporta a eap
df_eap.to_excel("teste.xlsx")

# %%
# criação do plano de trabalho e cronograma
construction_work_plan = ifcopenshell.api.sequence.add_work_plan(model, name="Construction", predefined_type="PLANNED")
construction_work_schedule = ifcopenshell.api.sequence.add_work_schedule(model, name="POE 789_Construção_Planejado",
                                                                    work_plan=construction_work_plan, predefined_type="PLANNED")

# criação da tarefa resumo
summary_task = ifcopenshell.api.sequence.add_task(model, work_schedule=construction_work_schedule,
                                       name = "POE 789 - Construção",
                                       identification = "1")

# %%
# Criação do calendário
calendar_default = ifcopenshell.api.sequence.add_work_calendar(model, name="5 dias")

# Horários de trabalho na semana
work_time = ifcopenshell.api.sequence.add_work_time(model, work_calendar=calendar_default, time_type="WorkingTimes")

# Criação da recorrência semanal de trabalho
pattern = ifcopenshell.api.sequence.assign_recurrence_pattern(model, parent=work_time, recurrence_type="WEEKLY")

# Estabelece os horários e dias de trabalho
# Segunda a quinta de 07:00 às 17:00 e sexta 07:00 às 16:00
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"WeekdayComponent": [1, 2, 3, 4]})
ifcopenshell.api.sequence.add_time_period(model, recurrence_pattern=pattern, start_time="07:00", end_time="17:00")
#ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"WeekdayComponent": [5]})
#ifcopenshell.api.sequence.add_time_period(model, recurrence_pattern=pattern, start_time="07:00", end_time="16:00")
# Out:
# #167503=IfcTimePeriod('07:00:00','17:00:00')

# %%
# Feriados
holidays = ifcopenshell.api.sequence.add_work_time(model, work_calendar=calendar_default, time_type="ExceptionTimes")

# Criação da recorrência anual por dia do mês
pattern = ifcopenshell.api.sequence.assign_recurrence_pattern(model, parent=work_time, recurrence_type="YEARLY_BY_DAY_OF_MONTH")

# Feriado dia 1° de Janeiro - 01/01
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [1], "MonthComponent": [1]})

# Feriado Dia de Tiradentes / Aniversário de Brasília - 21/04
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [21], "MonthComponent": [4]})

# Feriado Dia Mundial do Trabalho (feriado nacional) - 01/05
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [1], "MonthComponent": [5]})

# Dia da Independência do Brasil (feriado nacional) - 07/09
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [7], "MonthComponent": [9]})

# Dia de N. Sª. Aparecida (padroeira do Brasil) - 12/10
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [12], "MonthComponent": [10]})

# Dia de Finados (feriado nacional) - 02/11
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [2], "MonthComponent": [11]})

# Proclamação da República (feriado nacional) - 15/11
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [15], "MonthComponent": [11]})

# Dia Nacional de Zumbi e da Consciência Negra (feriado nacional) - 20/11
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [20], "MonthComponent": [11]})

# Dia do Evangélico (feriado local) - 30/11
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [30], "MonthComponent": [11]})

# Natal (feriado nacional) - 25/12
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"DayComponent": [25], "MonthComponent": [12]})


# Criação da recorrência anual por posição
pattern = ifcopenshell.api.sequence.assign_recurrence_pattern(model, parent=work_time, recurrence_type="YEARLY_BY_POSITION")

# Feriado Dia de São José – Padroeiro da Construção Civil – comemorado na segunda-feira de Carnaval (data móvel) - 12/02 Segunda-feira
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 1, "WeekdayComponent": [2], "MonthComponent": [2]})

# Feriado Paixão de Cristo (data móvel) - 29/03/2024 Sexta-feira
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 5, "WeekdayComponent": [4], "MonthComponent": [3]})

# Feriado Corpus Christi (data móvel) - 30/05/2024 Quinta-feira
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 4, "WeekdayComponent": [4], "MonthComponent": [5]})

# Férias coletivas PO (data móvel) - quarta 18/12/2024 a domingo 05/01/2025
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 3, "WeekdayComponent": [3], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 4, "WeekdayComponent": [3], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 5, "WeekdayComponent": [3], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 6, "WeekdayComponent": [3], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 7, "WeekdayComponent": [3], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 1, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 2, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 3, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 4, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 5, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 6, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 7, "WeekdayComponent": [4], "MonthComponent": [12]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 1, "WeekdayComponent": [1], "MonthComponent": [1]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 2, "WeekdayComponent": [1], "MonthComponent": [1]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 3, "WeekdayComponent": [1], "MonthComponent": [1]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 4, "WeekdayComponent": [1], "MonthComponent": [1]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 5, "WeekdayComponent": [1], "MonthComponent": [1]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 6, "WeekdayComponent": [1], "MonthComponent": [1]})
ifcopenshell.api.sequence.edit_recurrence_pattern(model, recurrence_pattern=pattern, attributes={"Position": 7, "WeekdayComponent": [1], "MonthComponent": [1]})

# %%
# Adiciona o calendário na tarefa resumo e este calendário é herdado para todas as tarefas
ifcopenshell.api.control.assign_control(model, relating_control=calendar_default, related_object=summary_task)
# Out:
# #167508=IfcRelAssignsToControl('0KJn_i_sj9rxW7IXly0Gqz',#167507,$,$,(#167496),$,#167500)

# %%
# criação das tarefas e subtarefas associadas entre si de acordo com a eap
for eap in df_eap["EAP"]:
    eap_superior = '.'.join(eap.split('.')[:-1])
    parent_task = ifcopenshell.util.selector.filter_elements(model, 'IfcTask, Identification="{}"'.format(eap_superior)).pop()
    ifcopenshell.api.sequence.add_task(model,
                                       name = df_eap.loc[df_eap["EAP"] == eap, "descrição"].to_numpy()[0],
                                       identification = eap,
                                       parent_task = parent_task,
                                       predefined_type="CONSTRUCTION"
                                      )

# %%
# escreve o modelo IFC em um novo arquivo
model.write("./modelo_teste/est_eap.ifc")

# %% [markdown]
# ## QiBuilder

# %%
df_quantitativo
# Out:
#      pavimento                       rede  \
# 0       TER NA  Alimentação (Piscina-FIL)
# 1       TER NA  Alimentação (Piscina-FIL)
# 2       TER NA  Alimentação (Piscina-FIL)
# 3       TER NA  Alimentação (Piscina-FIL)
# 4       TER NA  Alimentação (Piscina-FIL)
# ..         ...                        ...
# 552  COBERTURA                Água quente
# 553  COBERTURA                Água quente
# 554  COBERTURA                Água quente
# 555     TER NA                 Ventilação
# 556     TER NA                 Ventilação
#
#                                                   item  quantidade  \
# 0    Metais - Registro esfera VS compacto soldável ...         1.0
# 1    Metais - Registro esfera VS compacto soldável ...         1.0
# 2       Metais - Valvula de retenção vertical - 1.1/2"         1.0
# 3    PVC rígido soldável - Adapt sold.curto c/bolsa...         2.0
# 4    Metais - Registro esfera VS compacto soldável ...         1.0
# ..                                                 ...         ...
# 552            Placa Solar - Solis - New Trópicos 2000         1.0
# 553            Placa Solar - Solis - New Trópicos 2000         1.0
# 554            Placa Solar - Solis - New Trópicos 2000         1.0
# 555        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 556        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
#
#                          ID
# 0    1yH6iSt2HEAwhBHmpEW48R
# 1    23vghV9i5E69JyH8cCXCzC
# 2    3Xe7iW2cXEUfq5MHSwOCQP
# 3    3Xe7iW2cXEUfq5MHSwOCQP
# 4    3mVMY5yAD9uAhX6Sme9ohP
# ..                      ...
# 552  1K8ErAvxDEhuVB3L0$rilu
# 553  2gUdsZucfD09_ho9YhCYi8
# 554  1HEBKtuuD6PhkNQxhOCT7h
# 555  2c8JUCCDjFr8EWB5NyNC1Q
# 556  3hPDKMePT1yAVb4qJWCNuJ
#
# [557 rows x 5 columns]

# %%
######## PENDENCIA
######## Categorizar os itens entre prumada, ramal, subcoletor, reservação, etc.
# itens únicos dentro do dataframe
df_quantitativo["item"].sort_values().unique()
# Out:
# array(['Acessórios para Piscina - Dispositivo de Aspiração - Disp. de Aspiração p/ Pisc. de Concreto e Fibra - Qmáx = 9m³/h',
#        'Acessórios para Piscina - Dispositivo de Retorno - Disp. Retorno p/ Pisc. de Concreto ou Fibra - Qmín = 1,4 m³/h e Qmáx = 2,3 m³/h',
#        'Acessórios para Piscina - Dispositivo de Retorno - Disp. Retorno p/ Pisc. de Concreto ou Fibra - Qmín = 2,2m³/h e Qmáx = 3,8 m³/h',
#        'Acessórios para Piscina - Dreno de Fundo - Dreno c/ Tampa FSB Piscina de Concreto ou Fibra - Qmáx = 30m³/h',
#        'Acessórios para Piscina - Skimmer - Skimmer BL p/ Piscina de Concreto ou Vinil',
#        "Bomba Hidráulica - Piscina - Autoescorvante com Pré Filtro 1 1/2'' x 1 1/2'' - PF-17 0.33CV R96",
#        "Bomba Hidráulica - Piscina - Autoescorvante com Pré Filtro 1 1/2'' x 1 1/2'' - PF-17 0.5CV R100",
#        'Caixas de Passagem - Caixa de areia pluvial - CA 60x60x50cm',
#        'Filtro de piscina - Série TP - 15-TP',
#        'Metais - Filtro em Y - 1.1/2"',
#        'Metais - Registro esfera VS compacto soldável PVC - 50 mm',
#        'Metais - Registro esfera VS compacto soldável PVC - 60 mm',
#        'Metais - Valvula de retenção vertical - 1.1/2"',
#        'Metais - Valvula de retenção vertical - 2"',
#        'PVC Acessórios - Válvula ventosa combinada - 1.1/2"',
#        'PVC Esgoto - Anel de borracha - 100mm - 4"',
#        'PVC Esgoto - Anel de borracha - 50mm - 2"',
#        'PVC Esgoto - Curva 90 longa - 50 mm',
#        'PVC Esgoto - Joelho 90 - 100 mm',
#        'PVC Esgoto - Luva simples - 100 mm',
#        'PVC Esgoto - Luva simples - 50 mm',
#        'PVC Esgoto - Terminal de ventilação - 50 mm',
#        'PVC Esgoto - Tubo rígido c/ ponta lisa - 100 mm - 4"',
#        'PVC Esgoto - Tubo rígido c/ ponta lisa - 50 mm - 2"',
#        'PVC rígido soldável - Adapt sold.curto c/bolsa-rosca p registro - 50 mm - 1.1/2"',
#        'PVC rígido soldável - Adapt sold.curto c/bolsa-rosca p registro - 60 mm - 2"',
#        'PVC rígido soldável - Bucha de redução sold. curta - 60 mm - 50 mm',
#        'PVC rígido soldável - Bucha de redução sold. longa - 50 mm - 25 mm',
#        'PVC rígido soldável - Curva 45 soldável - 50 mm',
#        'PVC rígido soldável - Curva 45 soldável - 60 mm',
#        'PVC rígido soldável - Curva 90 soldável - 50 mm',
#        'PVC rígido soldável - Curva 90 soldável - 60 mm',
#        'PVC rígido soldável - Joelho 45 soldável - 60 mm',
#        'PVC rígido soldável - Joelho 90º soldável - 50 mm',
#        'PVC rígido soldável - Joelho 90º soldável - 60 mm',
#        'PVC rígido soldável - Luva soldável - 50 mm',
#        'PVC rígido soldável - Luva soldável - 60 mm',
#        'PVC rígido soldável - Tubos - 25 mm',
#        'PVC rígido soldável - Tubos - 50 mm',
#        'PVC rígido soldável - Tubos - 60 mm',
#        'PVC rígido soldável - Tê 90 soldável - 50 mm',
#        'PVC rígido soldável - Tê 90 soldável - 60 mm',
#        'PVC rígido soldável - União soldável - 50 mm',
#        'PVC rígido soldável - União soldável - 60 mm',
#        'Placa Solar - Solis - New Trópicos 2000',
#        'Trocador de calor - Nautilus - TermaMax 4'], dtype=object)

# %%
mapeamento= {
    'Bomba Hidráulica - Piscina - Autoescorvante com Pré Filtro 1 1/2'' x 1 1/2'' - PF-17 0.33CV R96': "102111",
    'Bomba Hidráulica - Piscina - Autoescorvante com Pré Filtro 1 1/2'' x 1 1/2'' - PF-17 0.5CV R100': "102111",
    'Caixas de Passagem - Caixa de areia pluvial - CA 60x60x50cm': "99260",
    'Metais - Registro esfera VS compacto soldável PVC - 50 mm': "94492",
    'Metais - Registro esfera VS compacto soldável PVC - 60 mm': "94493",
    'Metais - Valvula de retenção vertical - 1.1/2"': "99631",
    'Metais - Valvula de retenção vertical - 2"': "99632",
    'PVC Esgoto - Anel de borracha - 100mm - 4"': "Insumo de composição",
    'PVC Esgoto - Anel de borracha - 50mm - 2"': "Insumo de composição",
    'Curva 90 longa - 50 mm': "89735",
    'PVC Esgoto - Joelho 90 - 100 mm': "89744",
    'PVC Esgoto - Luva simples - 100 mm': "89778",
    'PVC Esgoto - Luva simples - 50 mm': "89753",
    'PVC Esgoto - Terminal de ventilação - 50 mm': "104348",
    'PVC Esgoto - Tubo rígido c/ ponta lisa - 100 mm - 4"': "89714",
    'PVC Esgoto - Tubo rígido c/ ponta lisa - 50 mm - 2"': "89712",
    'PVC rígido soldável - Adapt sold.curto c/bolsa-rosca p registro - 50 mm - 1.1/2"': "94662",
    'PVC rígido soldável - Adapt sold.curto c/bolsa-rosca p registro - 60 mm - 2"': "94664",
    'PVC rígido soldável - Bucha de redução sold. curta - 60 mm - 50 mm': "103959",
    'PVC rígido soldável - Bucha de redução sold. longa - 50 mm - 25 mm': "105234",
    'PVC rígido soldável - Curva 45 soldável - 50 mm': "103987",
    'PVC rígido soldável - Curva 45 soldável - 60 mm': "89510",
    'PVC rígido soldável - Curva 90 soldável - 50 mm': "94679",
    'PVC rígido soldável - Curva 90 soldável - 60 mm': "94681",
    'PVC rígido soldável - Joelho 45 soldável - 60 mm': "89506",
    'PVC rígido soldável - Joelho 90º soldável - 50 mm': "94678",
    'PVC rígido soldável - Joelho 90º soldável - 60 mm': "94680",
    'PVC rígido soldável - Luva soldável - 50 mm': "94663",
    'PVC rígido soldável - Luva soldável - 60 mm': "94665",
    'PVC rígido soldável - Tubos - 25 mm': "89402",
    'PVC rígido soldável - Tubos - 50 mm': "94651",
    'PVC rígido soldável - Tubos - 60 mm': "94652",
    'PVC rígido soldável - Tê 90 soldável - 50 mm': "94694",
    'PVC rígido soldável - Tê 90 soldável - 60 mm': "94696",
    'PVC rígido soldável - União soldável - 50 mm': "103997",
    'PVC rígido soldável - União soldável - 60 mm': "89609"  
}

df_quantitativo["CODIGO DA COMPOSICAO"] = df_quantitativo["item"].map(mapeamento).fillna("não associado")

# %%
df_quantitativo
# Out:
#      pavimento                       rede  \
# 0       TER NA  Alimentação (Piscina-FIL)
# 1       TER NA  Alimentação (Piscina-FIL)
# 2       TER NA  Alimentação (Piscina-FIL)
# 3       TER NA  Alimentação (Piscina-FIL)
# 4       TER NA  Alimentação (Piscina-FIL)
# ..         ...                        ...
# 552  COBERTURA                Água quente
# 553  COBERTURA                Água quente
# 554  COBERTURA                Água quente
# 555     TER NA                 Ventilação
# 556     TER NA                 Ventilação
#
#                                                   item  quantidade  \
# 0    Metais - Registro esfera VS compacto soldável ...         1.0
# 1    Metais - Registro esfera VS compacto soldável ...         1.0
# 2       Metais - Valvula de retenção vertical - 1.1/2"         1.0
# 3    PVC rígido soldável - Adapt sold.curto c/bolsa...         2.0
# 4    Metais - Registro esfera VS compacto soldável ...         1.0
# ..                                                 ...         ...
# 552            Placa Solar - Solis - New Trópicos 2000         1.0
# 553            Placa Solar - Solis - New Trópicos 2000         1.0
# 554            Placa Solar - Solis - New Trópicos 2000         1.0
# 555        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 556        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
#
#                          ID CODIGO DA COMPOSICAO
# 0    1yH6iSt2HEAwhBHmpEW48R                94492
# 1    23vghV9i5E69JyH8cCXCzC                94492
# 2    3Xe7iW2cXEUfq5MHSwOCQP                99631
# 3    3Xe7iW2cXEUfq5MHSwOCQP                94662
# 4    3mVMY5yAD9uAhX6Sme9ohP                94492
# ..                      ...                  ...
# 552  1K8ErAvxDEhuVB3L0$rilu        não associado
# 553  2gUdsZucfD09_ho9YhCYi8        não associado
# 554  1HEBKtuuD6PhkNQxhOCT7h        não associado
# 555  2c8JUCCDjFr8EWB5NyNC1Q               104348
# 556  3hPDKMePT1yAVb4qJWCNuJ               104348
#
# [557 rows x 6 columns]

# %%
# Associar os quantidades com os códigos do sinapi
df_plan = df_quantitativo.merge(sinapi[COLUMNS], on="CODIGO DA COMPOSICAO", how="left")

# %%
df_plan
# Out:
#      pavimento                       rede  \
# 0       TER NA  Alimentação (Piscina-FIL)
# 1       TER NA  Alimentação (Piscina-FIL)
# 2       TER NA  Alimentação (Piscina-FIL)
# 3       TER NA  Alimentação (Piscina-FIL)
# 4       TER NA  Alimentação (Piscina-FIL)
# ...        ...                        ...
# 3005    TER NA                 Ventilação
# 3006    TER NA                 Ventilação
# 3007    TER NA                 Ventilação
# 3008    TER NA                 Ventilação
# 3009    TER NA                 Ventilação
#
#                                                    item  quantidade  \
# 0     Metais - Registro esfera VS compacto soldável ...         1.0
# 1     Metais - Registro esfera VS compacto soldável ...         1.0
# 2     Metais - Registro esfera VS compacto soldável ...         1.0
# 3     Metais - Registro esfera VS compacto soldável ...         1.0
# 4     Metais - Registro esfera VS compacto soldável ...         1.0
# ...                                                 ...         ...
# 3005        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3006        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3007        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3008        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3009        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
#
#                           ID CODIGO DA COMPOSICAO  \
# 0     1yH6iSt2HEAwhBHmpEW48R                94492
# 1     1yH6iSt2HEAwhBHmpEW48R                94492
# 2     1yH6iSt2HEAwhBHmpEW48R                94492
# 3     1yH6iSt2HEAwhBHmpEW48R                94492
# 4     1yH6iSt2HEAwhBHmpEW48R                94492
# ...                      ...                  ...
# 3005  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3006  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3007  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3008  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3009  3hPDKMePT1yAVb4qJWCNuJ               104348
#
#                                 DESCRICAO DA COMPOSICAO UNIDADE  CUSTO TOTAL  \
# 0     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 1     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 2     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 3     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 4     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# ...                                                 ...     ...          ...
# 3005  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3006  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3007  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3008  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3009  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
#
#        TIPO ITEM CODIGO ITEM  \
# 0            NaN         nan
# 1         INSUMO       11677
# 2         INSUMO       20080
# 3         INSUMO       20083
# 4         INSUMO       38383
# ...          ...         ...
# 3005      INSUMO       20083
# 3006      INSUMO       38383
# 3007      INSUMO       39319
# 3008  COMPOSICAO       88248
# 3009  COMPOSICAO       88267
#
#                                          DESCRIÇÃO ITEM UNIDADE ITEM  \
# 0                                                   NaN          NaN
# 1     REGISTRO DE ESFERA, PVC, COM VOLANTE, VS, SOLD...           UN
# 2          ADESIVO PLASTICO PARA PVC, FRASCO COM 175 GR           UN
# 3     SOLUCAO PREPARADORA / LIMPADORA PARA PVC, FRAS...           UN
# 4                        LIXA D'AGUA EM FOLHA, GRAO 100           UN
# ...                                                 ...          ...
# 3005  SOLUCAO PREPARADORA / LIMPADORA PARA PVC, FRAS...           UN
# 3006                     LIXA D'AGUA EM FOLHA, GRAO 100           UN
# 3007  TERMINAL DE VENTILACAO, 50 MM, SERIE NORMAL, E...           UN
# 3008  AUXILIAR DE ENCANADOR OU BOMBEIRO HIDRÁULICO C...            H
# 3009  ENCANADOR OU BOMBEIRO HIDRÁULICO COM ENCARGOS ...            H
#
#       COEFICIENTE  PRECO UNITARIO CUSTO TOTAL.1 CATEGORIA COMPOSICAO
# 0             NaN             NaN           NaN             MATERIAL
# 1          1.0000           66.05         66,05             MATERIAL
# 2          0.0714           21.37          1,52             MATERIAL
# 3          0.0180           74.18          1,33             MATERIAL
# 4          0.0114            2.51          0,02             MATERIAL
# ...           ...             ...           ...                  ...
# 3005       0.0110           74.18          0,81             MATERIAL
# 3006       0.0080            2.51          0,02             MATERIAL
# 3007       1.0000            8.36          8,36             MATERIAL
# 3008       0.0114           21.51          0,24          MÃO DE OBRA
# 3009       0.0114           27.29          0,31          MÃO DE OBRA
#
# [3010 rows x 17 columns]

# %% [markdown]
# # APAGAR SE OS CÓDIGOS ACIMA DEREM CERTO

# %% [markdown]
# ### Quantidades auxiliares

# %% [markdown]
# As quantidades auxiliares são utilizadas pois existem composições auxiliares dentro das composições principais, e esta quantidade que é utilizada nos insumos das composições auxiliares.
# Se dentro da composição tiver insumo direto, a quantidade auxiliar corresponde à quantidade total

# %%
# Cálculo das quantidades totais das composições auxiliares e insumos
df_plan["QNTD AUX"] = df_plan["COEFICIENTE"] * df_plan["quantidade"]
df_plan["QNTD"] = df_plan["COEFICIENTE"] * df_plan["quantidade"]
df_plan["EAP"] = ""
df_plan["RUP"] = ""
df_plan["HISTORICO"] = ""

# %% [markdown]
# ### Abrindo as composições

# %%
df_plan
# Out:
#      pavimento                       rede  \
# 0       TER NA  Alimentação (Piscina-FIL)
# 1       TER NA  Alimentação (Piscina-FIL)
# 2       TER NA  Alimentação (Piscina-FIL)
# 3       TER NA  Alimentação (Piscina-FIL)
# 4       TER NA  Alimentação (Piscina-FIL)
# ...        ...                        ...
# 3005    TER NA                 Ventilação
# 3006    TER NA                 Ventilação
# 3007    TER NA                 Ventilação
# 3008    TER NA                 Ventilação
# 3009    TER NA                 Ventilação
#
#                                                    item  quantidade  \
# 0     Metais - Registro esfera VS compacto soldável ...         1.0
# 1     Metais - Registro esfera VS compacto soldável ...         1.0
# 2     Metais - Registro esfera VS compacto soldável ...         1.0
# 3     Metais - Registro esfera VS compacto soldável ...         1.0
# 4     Metais - Registro esfera VS compacto soldável ...         1.0
# ...                                                 ...         ...
# 3005        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3006        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3007        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3008        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
# 3009        PVC Esgoto - Terminal de ventilação - 50 mm         1.0
#
#                           ID CODIGO DA COMPOSICAO  \
# 0     1yH6iSt2HEAwhBHmpEW48R                94492
# 1     1yH6iSt2HEAwhBHmpEW48R                94492
# 2     1yH6iSt2HEAwhBHmpEW48R                94492
# 3     1yH6iSt2HEAwhBHmpEW48R                94492
# 4     1yH6iSt2HEAwhBHmpEW48R                94492
# ...                      ...                  ...
# 3005  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3006  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3007  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3008  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3009  3hPDKMePT1yAVb4qJWCNuJ               104348
#
#                                 DESCRICAO DA COMPOSICAO UNIDADE  CUSTO TOTAL  \
# 0     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 1     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 2     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 3     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 4     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# ...                                                 ...     ...          ...
# 3005  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3006  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3007  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3008  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3009  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
#
#        TIPO ITEM  ... UNIDADE ITEM COEFICIENTE PRECO UNITARIO  CUSTO TOTAL.1  \
# 0            NaN  ...          NaN         NaN            NaN            NaN
# 1         INSUMO  ...           UN      1.0000          66.05          66,05
# 2         INSUMO  ...           UN      0.0714          21.37           1,52
# 3         INSUMO  ...           UN      0.0180          74.18           1,33
# 4         INSUMO  ...           UN      0.0114           2.51           0,02
# ...          ...  ...          ...         ...            ...            ...
# 3005      INSUMO  ...           UN      0.0110          74.18           0,81
# 3006      INSUMO  ...           UN      0.0080           2.51           0,02
# 3007      INSUMO  ...           UN      1.0000           8.36           8,36
# 3008  COMPOSICAO  ...            H      0.0114          21.51           0,24
# 3009  COMPOSICAO  ...            H      0.0114          27.29           0,31
#
#       CATEGORIA COMPOSICAO QNTD AUX    QNTD  EAP  RUP HISTORICO
# 0                 MATERIAL      NaN     NaN
# 1                 MATERIAL   1.0000  1.0000
# 2                 MATERIAL   0.0714  0.0714
# 3                 MATERIAL   0.0180  0.0180
# 4                 MATERIAL   0.0114  0.0114
# ...                    ...      ...     ...  ...  ...       ...
# 3005              MATERIAL   0.0110  0.0110
# 3006              MATERIAL   0.0080  0.0080
# 3007              MATERIAL   1.0000  1.0000
# 3008           MÃO DE OBRA   0.0114  0.0114
# 3009           MÃO DE OBRA   0.0114  0.0114
#
# [3010 rows x 22 columns]

# %%
df_item_com_composicao = df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"]

# %%
df_item_com_composicao
# Out:
#       pavimento                       rede  \
# 5        TER NA  Alimentação (Piscina-FIL)
# 6        TER NA  Alimentação (Piscina-FIL)
# 12       TER NA  Alimentação (Piscina-FIL)
# 13       TER NA  Alimentação (Piscina-FIL)
# 17       TER NA  Alimentação (Piscina-FIL)
# ...         ...                        ...
# 2979  COBERTURA   Alimentação (Piscina-AQ)
# 3001     TER NA                 Ventilação
# 3002     TER NA                 Ventilação
# 3008     TER NA                 Ventilação
# 3009     TER NA                 Ventilação
#
#                                                    item  quantidade  \
# 5     Metais - Registro esfera VS compacto soldável ...    1.000000
# 6     Metais - Registro esfera VS compacto soldável ...    1.000000
# 12    Metais - Registro esfera VS compacto soldável ...    1.000000
# 13    Metais - Registro esfera VS compacto soldável ...    1.000000
# 17       Metais - Valvula de retenção vertical - 1.1/2"    1.000000
# ...                                                 ...         ...
# 2979                PVC rígido soldável - Tubos - 60 mm  110.457159
# 3001        PVC Esgoto - Terminal de ventilação - 50 mm    1.000000
# 3002        PVC Esgoto - Terminal de ventilação - 50 mm    1.000000
# 3008        PVC Esgoto - Terminal de ventilação - 50 mm    1.000000
# 3009        PVC Esgoto - Terminal de ventilação - 50 mm    1.000000
#
#                           ID CODIGO DA COMPOSICAO  \
# 5     1yH6iSt2HEAwhBHmpEW48R                94492
# 6     1yH6iSt2HEAwhBHmpEW48R                94492
# 12    23vghV9i5E69JyH8cCXCzC                94492
# 13    23vghV9i5E69JyH8cCXCzC                94492
# 17    3Xe7iW2cXEUfq5MHSwOCQP                99631
# ...                      ...                  ...
# 2979  0$zGCv7zb4nAlDpBS3I3Np                94652
# 3001  2c8JUCCDjFr8EWB5NyNC1Q               104348
# 3002  2c8JUCCDjFr8EWB5NyNC1Q               104348
# 3008  3hPDKMePT1yAVb4qJWCNuJ               104348
# 3009  3hPDKMePT1yAVb4qJWCNuJ               104348
#
#                                 DESCRICAO DA COMPOSICAO UNIDADE  CUSTO TOTAL  \
# 5     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 6     REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 12    REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 13    REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN        74.44
# 17    VÁLVULA DE RETENÇÃO VERTICAL, DE BRONZE, ROSCÁ...      UN       154.72
# ...                                                 ...     ...          ...
# 2979  TUBO, PVC, SOLDÁVEL, DE 60MM, INSTALADO EM RES...       M        32.77
# 3001  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3002  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3008  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
# 3009  TERMINAL DE VENTILAÇÃO, PVC, SÉRIE NORMAL, ESG...      UN        10.21
#
#        TIPO ITEM  ... UNIDADE ITEM COEFICIENTE PRECO UNITARIO  CUSTO TOTAL.1  \
# 5     COMPOSICAO  ...            H      0.1133          21.51           2,43
# 6     COMPOSICAO  ...            H      0.1133          27.29           3,09
# 12    COMPOSICAO  ...            H      0.1133          21.51           2,43
# 13    COMPOSICAO  ...            H      0.1133          27.29           3,09
# 17    COMPOSICAO  ...            H      0.2633          21.51           5,66
# ...          ...  ...          ...         ...            ...            ...
# 2979  COMPOSICAO  ...            H      0.1517          27.29           4,13
# 3001  COMPOSICAO  ...            H      0.0114          21.51           0,24
# 3002  COMPOSICAO  ...            H      0.0114          27.29           0,31
# 3008  COMPOSICAO  ...            H      0.0114          21.51           0,24
# 3009  COMPOSICAO  ...            H      0.0114          27.29           0,31
#
#       CATEGORIA COMPOSICAO   QNTD AUX       QNTD  EAP  RUP HISTORICO
# 5              MÃO DE OBRA   0.113300   0.113300
# 6              MÃO DE OBRA   0.113300   0.113300
# 12             MÃO DE OBRA   0.113300   0.113300
# 13             MÃO DE OBRA   0.113300   0.113300
# 17             MÃO DE OBRA   0.263300   0.263300
# ...                    ...        ...        ...  ...  ...       ...
# 2979           MÃO DE OBRA  16.756351  16.756351
# 3001           MÃO DE OBRA   0.011400   0.011400
# 3002           MÃO DE OBRA   0.011400   0.011400
# 3008           MÃO DE OBRA   0.011400   0.011400
# 3009           MÃO DE OBRA   0.011400   0.011400
#
# [1001 rows x 22 columns]

# %% [markdown]
# # Abre as composições
# while df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"].size > 0:
#     i = 0
#     index_abertos = []
#
#     df_item_com_composicao = df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"]
#     composicao_abertas = pd.DataFrame()
#
#     while i < df_item_com_composicao.shape[0]:
#         temp = sinapi[sinapi["CODIGO DA COMPOSICAO"] == df_item_com_composicao.iloc[i, 5]][COLUMNS]
#         temp["ID"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("ID")]
#         temp["EAP"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("EAP")]
#         temp["pavimento"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("pavimento")]
#         temp["rede"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("rede")]
#         temp["quantidade"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("quantidade")]
#         temp["QNTD AUX"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("QNTD")] # QNTD da composição auxiliar vira quantidade do insumo aberto
#         temp["HISTORICO"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("CODIGO DA COMPOSICAO")] + "_" + df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("HISTORICO")]
#         temp["RUP"] = df_item_com_composicao.iloc[i, df_item_com_composicao.columns.get_loc("COEFICIENTE")]
#
#         composicao_abertas = pd.concat([composicao_abertas if not composicao_abertas.empty else None, temp], ignore_index=True)
#         index_abertos.append(df_item_com_composicao.iloc[i, :].name) # remove a composição que já foi aberta
#
#         i += 1
#
#     # Exclui as composições abertas
#     df_plan.drop(index_abertos, inplace=True)
#
#     # Joga as composições abertas no dataframe principal
#     df_plan = pd.concat([df_plan if not df_plan.empty else None, composicao_abertas], ignore_index=True)
#
#     # Cálculo das quantidades totais das composições auxiliares e insumos
#     df_plan["QNTD"] = df_plan["COEFICIENTE"] * df_plan["QNTD AUX"] # atualiza o valor da QNTD AUX caso tenha mais composições auxiliares (c.a.) dentro da c.a.

# %%
# Abre as composições
while not df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"].empty:
    df_item_com_composicao = df_plan[df_plan["TIPO ITEM"] == "COMPOSICAO"]
    
    # Extraindo as colunas relevantes apenas uma vez
    codigos_composicao = df_item_com_composicao["CODIGO DA COMPOSICAO"].values
    ids = df_item_com_composicao["ID"].values
    eaps = df_item_com_composicao["EAP"].values
    pavimentos = df_item_com_composicao["pavimento"].values
    redes = df_item_com_composicao["rede"].values
    quantidades = df_item_com_composicao["quantidade"].values
    qntd_auxs = df_item_com_composicao["QNTD"].values
    coeficientes = df_item_com_composicao["COEFICIENTE"].values
    
    # Buscando dados no sinapi uma única vez
    temp_data = sinapi[sinapi["CODIGO DA COMPOSICAO"].isin(codigos_composicao)][COLUMNS]

    # Criando uma nova DataFrame para as composições abertas
    composicao_abertas = pd.DataFrame({
        "ID": ids,
        "EAP": eaps,
        "pavimento": pavimentos,
        "rede": redes,
        "quantidade": quantidades,
        "QNTD AUX": qntd_auxs,
        "HISTORICO": [f"{cod}_{hist}" for cod, hist in zip(codigos_composicao, df_item_com_composicao["HISTORICO"].values)],
        "RUP": coeficientes
    })

    # Atualiza df_plan excluindo as composições abertas
    df_plan = df_plan[~df_plan.index.isin(df_item_com_composicao.index)]

    # Joga as composições abertas no dataframe principal
    df_plan = pd.concat([df_plan, composicao_abertas], ignore_index=True)

    # Cálculo das quantidades totais das composições auxiliares e insumos
    df_plan["QNTD"] = df_plan["COEFICIENTE"] * df_plan["QNTD AUX"]

# %%
df_plan
# Out:
#         pavimento                       rede  \
# 0          TER NA  Alimentação (Piscina-FIL)
# 1          TER NA  Alimentação (Piscina-FIL)
# 2          TER NA  Alimentação (Piscina-FIL)
# 3          TER NA  Alimentação (Piscina-FIL)
# 4          TER NA  Alimentação (Piscina-FIL)
# ...           ...                        ...
# 1150596    TER NA                 Ventilação
# 1150597    TER NA                 Ventilação
# 1150598    TER NA                 Ventilação
# 1150599    TER NA                 Ventilação
# 1150600    TER NA                 Ventilação
#
#                                                       item  quantidade  \
# 0        Metais - Registro esfera VS compacto soldável ...         1.0
# 1        Metais - Registro esfera VS compacto soldável ...         1.0
# 2        Metais - Registro esfera VS compacto soldável ...         1.0
# 3        Metais - Registro esfera VS compacto soldável ...         1.0
# 4        Metais - Registro esfera VS compacto soldável ...         1.0
# ...                                                    ...         ...
# 1150596                                                NaN         1.0
# 1150597                                                NaN         1.0
# 1150598                                                NaN         1.0
# 1150599                                                NaN         1.0
# 1150600                                                NaN         1.0
#
#                              ID CODIGO DA COMPOSICAO  \
# 0        1yH6iSt2HEAwhBHmpEW48R                94492
# 1        1yH6iSt2HEAwhBHmpEW48R                94492
# 2        1yH6iSt2HEAwhBHmpEW48R                94492
# 3        1yH6iSt2HEAwhBHmpEW48R                94492
# 4        1yH6iSt2HEAwhBHmpEW48R                94492
# ...                         ...                  ...
# 1150596  3hPDKMePT1yAVb4qJWCNuJ                  NaN
# 1150597  3hPDKMePT1yAVb4qJWCNuJ                  NaN
# 1150598  3hPDKMePT1yAVb4qJWCNuJ                  NaN
# 1150599  3hPDKMePT1yAVb4qJWCNuJ                  NaN
# 1150600  3hPDKMePT1yAVb4qJWCNuJ                  NaN
#
#                                    DESCRICAO DA COMPOSICAO UNIDADE  \
# 0        REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN
# 1        REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN
# 2        REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN
# 3        REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN
# 4        REGISTRO DE ESFERA, PVC, SOLDÁVEL, COM VOLANTE...      UN
# ...                                                    ...     ...
# 1150596                                                NaN     NaN
# 1150597                                                NaN     NaN
# 1150598                                                NaN     NaN
# 1150599                                                NaN     NaN
# 1150600                                                NaN     NaN
#
#          CUSTO TOTAL TIPO ITEM  ... UNIDADE ITEM COEFICIENTE PRECO UNITARIO  \
# 0              74.44       NaN  ...          NaN         NaN            NaN
# 1              74.44    INSUMO  ...           UN      1.0000          66.05
# 2              74.44    INSUMO  ...           UN      0.0714          21.37
# 3              74.44    INSUMO  ...           UN      0.0180          74.18
# 4              74.44    INSUMO  ...           UN      0.0114           2.51
# ...              ...       ...  ...          ...         ...            ...
# 1150596          NaN       NaN  ...          NaN         NaN            NaN
# 1150597          NaN       NaN  ...          NaN         NaN            NaN
# 1150598          NaN       NaN  ...          NaN         NaN            NaN
# 1150599          NaN       NaN  ...          NaN         NaN            NaN
# 1150600          NaN       NaN  ...          NaN         NaN            NaN
#
#          CUSTO TOTAL.1  CATEGORIA COMPOSICAO      QNTD AUX      QNTD  EAP  \
# 0                  NaN              MATERIAL           NaN       NaN
# 1                66,05              MATERIAL  1.000000e+00  1.000000
# 2                 1,52              MATERIAL  7.140000e-02  0.005098
# 3                 1,33              MATERIAL  1.800000e-02  0.000324
# 4                 0,02              MATERIAL  1.140000e-02  0.000130
# ...                ...                   ...           ...       ...  ...
# 1150596            NaN                   NaN  2.194973e-12       NaN
# 1150597            NaN                   NaN  2.194973e-12       NaN
# 1150598            NaN                   NaN  2.194973e-12       NaN
# 1150599            NaN                   NaN  2.194973e-12       NaN
# 1150600            NaN                   NaN  2.194973e-12       NaN
#
#             RUP                                   HISTORICO
# 0
# 1
# 2
# 3
# 4
# ...         ...                                         ...
# 1150596  0.0114  104348_104348_104348_104348_104348_104348_
# 1150597  0.0114  104348_104348_104348_104348_104348_104348_
# 1150598  0.0114  104348_104348_104348_104348_104348_104348_
# 1150599  0.0114  104348_104348_104348_104348_104348_104348_
# 1150600  0.0114  104348_104348_104348_104348_104348_104348_
#
# [1150601 rows x 22 columns]

# %% [markdown]
# ### Categorização dos insumos

# %%
df_plan.dropna(inplace=True)

# %%
# categorização dos itens em equipamento, mão de obra e material

condicoes = [
    df_plan["UNIDADE ITEM"] == "CHP",
    df_plan["UNIDADE ITEM"] == "CHI",
    df_plan["DESCRICAO DA COMPOSICAO"].str.startswith('CURSO'), # O curso de capacitação é categorizado como mão de obra conforme o SINAPI, mas ele não vai ser utilizado como recurso no planejamento
    df_plan["DESCRIÇÃO ITEM"].str.startswith('AJUDANTE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ASSENTADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('AUXILIAR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('AZULEJISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('CALCETEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('CAVOUQUEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('CARPINTEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ELETRICISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ENCANADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ELETROTECNICO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('GESSEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('IMPERMEABILIZADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('INSTALADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('JARDINEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MACARIQUEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MARCENEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MARMORISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MECANICO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MONTADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MOTORISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('NIVELADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('OPERADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('PASTILHEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('PEDREIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('PINTOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('POCEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('SERRALHEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('SERVENTE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('SOLDADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('TOPOGRAFO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('VIDRACEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('VIGIA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ALMOXARIFE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('APONTADOR'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ARQUITETO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('DESENHISTA'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ENCARREGADO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('ENGENHEIRO'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('MESTRE'),
    df_plan["DESCRIÇÃO ITEM"].str.startswith('TECNICO'), 
]

valores = ["EQUIPAMENTO"]*2 + ["MÃO DE OBRA_CURSO"] + ["MÃO DE OBRA"]*40

df_plan["CATEGORIA INSUMO"] = np.select(condicoes, valores, default="MATERIAL")

# %%
df_plan

# %% [markdown]
# ### Avaliação dos resultados

# %%
df_plan

# %%
df_plan[df_plan["CATEGORIA INSUMO"] == "MÃO DE OBRA"]
